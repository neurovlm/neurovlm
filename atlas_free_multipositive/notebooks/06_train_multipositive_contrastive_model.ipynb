# %% [markdown]
# # 06 Train Multipositive Contrastive Model

# %%
# !python -m atlas_free_multipositive.training.train_contrastive --jsonl atlas_free_multipositive/cache/unified_jsonl/splits/train.jsonl --text-embeddings atlas_free_multipositive/cache/text_embeddings/specter_text_cache.pt --batch-size 2 --steps 3
