# %% [markdown]
# # 07 Evaluate MeSH And Atlas Retrieval
# Use the evaluation scripts after saving score and positive-mask tensors.

# %%
# Example:
# !python -m atlas_free_multipositive.evaluation.evaluate_mesh_ranking --scores outputs/scores.pt --positive-mask outputs/positive_mask.pt
