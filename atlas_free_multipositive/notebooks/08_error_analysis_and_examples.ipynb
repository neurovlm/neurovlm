# %% [markdown]
# # 08 Error Analysis And Examples

# %%
import json, random
p='atlas_free_multipositive/cache/unified_jsonl/unified_map_text.jsonl'
rows=[json.loads(l) for l in open(p)]
for row in random.sample(rows, min(5, len(rows))):
    print(row['map_id'], row['positive_terms'][:5])
    for pos in row['positive_texts'][:3]: print(' ', pos['category'], pos['text'][:200])
