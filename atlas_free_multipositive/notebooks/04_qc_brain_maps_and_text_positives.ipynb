# %% [markdown]
# # 04 QC Brain Maps And Text Positives

# %%
from pathlib import Path
import os

ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / "atlas_free_multipositive/configs/paths.yaml").exists():
    ROOT = ROOT.parent

os.chdir(ROOT)
print("cwd:", Path.cwd())
# Out:
# cwd: /Users/borng/code/lab_work/neurovlm

# %%
# !python -m atlas_free_multipositive.data_building.qc_dataset atlas_free_multipositive/cache/unified_jsonl/unified_map_text.jsonl --samples 5
# Out:
# {
#   "n_rows": 31073,
#   "source_counts": {
#     "pubmed": 30658,
#     "nilearn": 415
#   },
#   "map_type_counts": {
#     "coordinate_ale": 30658,
#     "network_map": 184,
#     "atlas_region": 169,
#     "probabilistic_atlas_region": 62
#   },
#   "positive_category_counts": {
#     "cognitive_construct": 27282,
#     "paper_summary": 30658,
#     "paper_title": 30658,
#     "anatomical_region": 2938,
#     "disorder": 1607,
#     "network": 284
#   },
#   "positive_source_counts": {
#     "mesh": 31696,
#     "wiki_style_summary": 30658,
#     "pubmed_title": 30658,
#     "nilearn_network_label": 284,
#     "nilearn_atlas_label": 131
#   },
#   "shape_counts": {
#     "[36, 45, 38]": 30658,
#     "[99, 117, 95]": 415
#   },
#   "missing_path_count": 0,
#   "missing_path_examples": []
# }
# {
#   "map_id": "pubmed_ale_22884992",
#   "source": "pubmed",
#   "map_type": "coordinate_ale",
#   "positive_terms": [
# ...
