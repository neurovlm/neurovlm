# %% [markdown]
# # 11 Evaluate Text-To-Brain Generation
#
# Evaluate generated maps with voxel, sparse top-k, peak, and semantic retrieval diagnostics.

# %%
# Example once generated/target tensors are saved:
# !python -m atlas_free_multipositive.evaluation.evaluate_generation --pred atlas_free_multipositive/outputs/eval/generated_maps.pt --target atlas_free_multipositive/outputs/eval/true_maps.pt
# !python -m atlas_free_multipositive.evaluation.evaluate_generation_semantic_retrieval --generated-brain-embeddings gen_brain.pt --candidate-text-embeddings candidates.pt --positive-mask pos_mask.pt
