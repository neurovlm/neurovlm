# %% [markdown]
# # 01 Ingest Full Nilearn Atlas Set
#
# Build atlas-derived maps for all configured Nilearn atlases: Yeo 2011, Schaefer 2018, Harvard-Oxford cortical/subcortical, Juelich probabilistic, AAL if available, and Smith 2009 if available. Optional local priority-3 atlases can be listed in `configs/dataset_config.yaml`.

# %%
from pathlib import Path
import os

ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / "atlas_free_multipositive/configs/paths.yaml").exists():
    ROOT = ROOT.parent
os.chdir(ROOT)
print("cwd:", Path.cwd())
# Out:
# cwd: /Users/borng/code/lab_work/neurovlm

# %%
# !python -m atlas_free_multipositive.data_building.ingest_nilearn_atlases \
  --paths atlas_free_multipositive/configs/paths.yaml \
  --config atlas_free_multipositive/configs/dataset_config.yaml \
  --output atlas_free_multipositive/cache/unified_jsonl/nilearn_atlases.jsonl
# Out:
# [fetch_atlas_yeo_2011] Dataset found in
# atlas_free_multipositive/cache/nilearn_data/yeo_2011
# [fetch_atlas_schaefer_2018] Dataset found in
# atlas_free_multipositive/cache/nilearn_data/schaefer_2018
# [fetch_atlas_harvard_oxford] Dataset found in
# atlas_free_multipositive/cache/nilearn_data/fsl
# [fetch_atlas_harvard_oxford] Dataset found in
# atlas_free_multipositive/cache/nilearn_data/fsl
# [fetch_atlas_juelich] Dataset found in
# atlas_free_multipositive/cache/nilearn_data/fsl
# /Users/borng/code/lab_work/neurovlm/atlas_free_multipositive/data_building/ingest_nilearn_atlases.py:208: DeprecationWarning: Starting in version 0.13, the default fetched mask will beAAL 3v2 instead.
#   return datasets.fetch_atlas_aal(version="SPM12", **fetch_kwargs)
# [fetch_atlas_aal] Dataset found in
# atlas_free_multipositive/cache/nilearn_data/aal_SPM12
# [fetch_atlas_aal] Downloading data from
# https://www.gin.cnrs.fr/AAL_files/aal_for_SPM12.tar.gz ...
# [fetch_atlas_aal] Error while fetching file aal_for_SPM12.tar.gz; dataset
# fetching aborted.
# Skipping aal: HTTPSConnectionPool(host='www.gin.cnrs.fr', port=443): Max retries exceeded with url: /AAL_files/aal_for_SPM12.tar.gz (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# [fetch_atlas_smith_2009] Dataset found in
# atlas_free_multipositive/cache/nilearn_data/smith_2009
# Wrote 568 Nilearn rows to atlas_free_multipositive/cache/unified_jsonl/nilearn_atlases.jsonl

# %%
# !python -m atlas_free_multipositive.data_building.qc_dataset atlas_free_multipositive/cache/unified_jsonl/nilearn_atlases.jsonl --samples 8
# Out:
# {
#   "n_rows": 568,
#   "source_counts": {
#     "nilearn": 568
#   },
#   "atlas_map_counts": {
#     "yeo_2011": 17,
#     "schaefer_2018": 400,
#     "harvard_oxford_cortical": 48,
#     "harvard_oxford_subcortical": 21,
#     "juelich": 62,
#     "smith_2009": 20
#   },
#   "atlas_label_counts": {
#     "yeo_2011": 17,
#     "schaefer_2018": 400,
#     "harvard_oxford_cortical": 48,
#     "harvard_oxford_subcortical": 21,
#     "juelich": 62,
#     "smith_2009": 20
#   },
#   "atlas_fallback_definition_counts": {
#     "yeo_2011": 17,
#     "harvard_oxford_cortical": 48,
#     "harvard_oxford_subcortical": 21,
#     "juelich": 57,
#     "smith_2009": 20
#   },
#   "total_new_atlas_derived_maps": 568,
#   "total_pubmed_ale_maps": 0,
#   "total_combined_training_examples": 568,
#   "map_type_counts": {
#     "network_map": 37,
#     "atlas_region": 531
#   },
#   "positive_category_counts": {
#     "network": 437,
#     "anatomical_region": 131
#   },
#   "positive_source_counts": {
#     "nilearn_network_label": 437,
#     "nilearn_atlas_label": 131
#   },
#   "shape_counts": {
#     "[99, 117, 95]": 568
#   },
#   "missing_path_count": 0,
#   "missing_path_examples": []
# }
# {
#   "map_id": "nilearn_yeo_2011_1_17networks_1",
#   "source": "nilearn:yeo_2011",
#   "map_type": "network_map",
#   "positive_terms": [
#     "17Networks_1"
#   ],
#   "positive_categories": [
#     "network"
#   ]
# }
# {
#   "map_id": "nilearn_yeo_2011_2_17networks_2",
#   "source": "nilearn:yeo_2011",
#   "map_type": "network_map",
#   "positive_terms": [
#     "17Networks_2"
#   ],
#   "positive_categories": [
#     "network"
#   ]
# }
# {
#   "map_id": "nilearn_yeo_2011_3_17networks_3",
#   "source": "nilearn:yeo_2011",
#   "map_type": "network_map",
#   "positive_terms": [
#     "17Networks_3"
#   ],
#   "positive_categories": [
#     "network"
#   ]
# }
# {
#   "map_id": "nilearn_yeo_2011_4_17networks_4",
#   "source": "nilearn:yeo_2011",
#   "map_type": "network_map",
#   "positive_terms": [
#     "17Networks_4"
#   ],
#   "positive_categories": [
#     "network"
#   ]
# }
# {
#   "map_id": "nilearn_yeo_2011_5_17networks_5",
#   "source": "nilearn:yeo_2011",
#   "map_type": "network_map",
#   "positive_terms": [
#     "17Networks_5"
#   ],
#   "positive_categories": [
#     "network"
#   ]
# }
# {
#   "map_id": "nilearn_yeo_2011_6_17networks_6",
#   "source": "nilearn:yeo_2011",
#   "map_type": "network_map",
#   "positive_terms": [
#     "17Networks_6"
#   ],
#   "positive_categories": [
#     "network"
#   ]
# }
# {
#   "map_id": "nilearn_yeo_2011_7_17networks_7",
#   "source": "nilearn:yeo_2011",
#   "map_type": "network_map",
#   "positive_terms": [
#     "17Networks_7"
#   ],
#   "positive_categories": [
#     "network"
#   ]
# }
# {
#   "map_id": "nilearn_yeo_2011_8_17networks_8",
#   "source": "nilearn:yeo_2011",
#   "map_type": "network_map",
#   "positive_terms": [
#     "17Networks_8"
#   ],
#   "positive_categories": [
#     "network"
#   ]
# }
