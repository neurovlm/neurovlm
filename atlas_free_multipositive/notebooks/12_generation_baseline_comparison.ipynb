# %% [markdown]
# # 12 Generation Baseline Comparison
#
# Compare trained text-to-brain generations against mean ALE, random train ALE, nearest-neighbor text embedding, and category-average baselines.

# %%
from atlas_free_multipositive.training.generation_baselines import global_mean_map, random_training_maps, nearest_neighbor_text_maps, category_average_maps
from atlas_free_multipositive.evaluation.generation_metrics import generation_metrics
# Load train/eval tensors, build baselines, then aggregate metrics into a CSV table.
