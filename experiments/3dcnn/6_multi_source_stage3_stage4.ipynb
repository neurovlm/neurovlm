# %% [markdown]
# # SPECTER Convention-Aware Stage 3-4 Rerun
#
# Rerun of the downstream Stage 3/4 experiment using the selected SPECTER2 text embedding cache convention. The legacy unnormalized-cache outputs from notebook 6 remain preserved as the baseline for paired comparisons.
#
# This notebook writes convention-aware Stage 3 outputs and can launch the corrected convention-matched Stage 4 generation branches.

# %%
from pathlib import Path
import json
import os
import platform
import shutil
import subprocess
import sys

print("Python:", sys.version)
print("Platform:", platform.platform())

# Match the working Colab setup used by Notebook 2:
# code repo in /content/neurovlm_gnn, Drive used for data and run outputs.
REPO_URL = os.environ.get("NEUROVLM_REPO_URL", "https://github.com/neurovlm/neurovlm.git")
REPO_BRANCH = os.environ.get("NEUROVLM_REPO_BRANCH", "neurovlm_gnn")
REPO_DIR = Path(os.environ.get("NEUROVLM_REPO_DIR", "/content/neurovlm_gnn"))
DRIVE_ROOT = Path(os.environ.get("NEUROVLM_DRIVE_ROOT", "/content/drive/MyDrive/neurovlm"))
INSTALL_DEPENDENCIES = os.environ.get("NEUROVLM_INSTALL_DEPS", "1") == "1"

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    from google.colab import drive
    drive.mount("/content/drive")


def run_cmd(cmd, cwd=None, *, check=True):
    print("$", " ".join(map(str, cmd)))
    result = subprocess.run(cmd, cwd=cwd, text=True, capture_output=True)
    if result.stdout.strip():
        print(result.stdout.strip())
    if result.returncode != 0:
        if result.stderr.strip():
            print(result.stderr.strip())
        if check:
            raise RuntimeError(f"Command failed ({result.returncode}): {' '.join(map(str, cmd))}")
    return result

if not REPO_DIR.exists():
    REPO_DIR.parent.mkdir(parents=True, exist_ok=True)
    run_cmd(["git", "clone", "--branch", REPO_BRANCH, "--single-branch", REPO_URL, str(REPO_DIR)])
else:
    if not (REPO_DIR / ".git").exists():
        raise RuntimeError(
            f"{REPO_DIR} exists but is not a git checkout. Set NEUROVLM_REPO_DIR to a clean path "
            "or remove that folder, then rerun this cell."
        )
    run_cmd(["git", "-C", str(REPO_DIR), "fetch", "origin", REPO_BRANCH])
    checkout = run_cmd(["git", "-C", str(REPO_DIR), "checkout", REPO_BRANCH], check=False)
    if checkout.returncode != 0:
        run_cmd(["git", "-C", str(REPO_DIR), "checkout", "-B", REPO_BRANCH, f"origin/{REPO_BRANCH}"])
    run_cmd(["git", "-C", str(REPO_DIR), "pull", "--ff-only", "origin", REPO_BRANCH])

os.chdir(REPO_DIR)

if INSTALL_DEPENDENCIES:
    run_cmd([sys.executable, "-m", "pip", "install", "-q", "nilearn", "nibabel", "huggingface-hub", "safetensors", "adapters", "transformers", "pyarrow", "matplotlib", "pandas", "scikit-learn", "tqdm", "umap-learn"])
    run_cmd([sys.executable, "-m", "pip", "install", "-q", "-e", ".[viz,notebook,metrics]"])

sys.path.insert(0, str(REPO_DIR / "experiments" / "3dcnn"))
sys.path.insert(0, str(REPO_DIR / "src"))
sys.path.insert(0, str(REPO_DIR))

print("Working directory:", os.getcwd())
print("Repo branch:", run_cmd(["git", "branch", "--show-current"], cwd=REPO_DIR, check=False).stdout.strip())
print("Drive root:", DRIVE_ROOT)
DRIVE_ROOT.mkdir(parents=True, exist_ok=True)

from atlas_free_cnn.pipeline_outputs import (
    create_stage2_stage3_stage4_run_dir,
    git_info,
    write_json,
    write_status_report,
    write_readme_what_to_look_at,
    write_table,
    flatten_stage3_metrics,
    ae_source_metric_columns,
)
from atlas_free_cnn.stage1_selection_integration import IntegrationConfig, integrate_completed_stage1_selection
from atlas_free_cnn.notebook_utils import (
    AE_BRANCH_MODES,
    DOMAIN_DIRS,
    SPECIALIZED_BRANCHES,
    ae_branch_specs,
    CORRECTED_STAGE4_CHECKPOINT,
    CORRECTED_STAGE4_DIRNAME,
    GENERATION_AUC_VAL_INTERVAL as DEFAULT_GENERATION_AUC_VAL_INTERVAL,
    NORMALIZED_STAGE3_CHECKPOINT,
    NORMALIZED_STAGE3_DIRNAME,
    STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING as DEFAULT_STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING,
    STAGE4_PRIMARY_SPATIAL_CHECKPOINT,
    STAGE4_SPATIAL_CORR_CHECKPOINT,
    STAGE4_SEMANTIC_CHECKPOINT,
    corrected_stage4_dirname_for_text_embedding_convention,
    discover_unified_split_dir as shared_discover_unified_split_dir,
    build_normalized_specter2_cache,
    download_text_embedding_cache,
    hf_download_first_available as shared_hf_download_first_available,
    print_relevant_text_embedding_hf_files,
    print_split_files,
    required_text_records_from_jsonls,
    resolve_text_embedding_cache,
    run_subprocess_streaming,
    selected_downstream_runs_for_ae_branch_mode,
    sha256_file,
    split_file_fingerprints,
    stage_output_dir,
    stage3_dirname_for_text_embedding_convention,
    text_embedding_convention_dir_suffix,
    text_embedding_metadata_fields,
    validate_text_embedding_cache,
)
# Out:
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Platform: Linux-6.6.122+-x86_64-with-glibc2.35
# Mounted at /content/drive
# $ git clone --branch neurovlm_gnn --single-branch https://github.com/neurovlm/neurovlm.git /content/neurovlm_gnn
# $ /usr/bin/python3 -m pip install -q nilearn nibabel huggingface-hub safetensors adapters transformers pyarrow matplotlib pandas scikit-learn tqdm umap-learn
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 184.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.5/295.5 kB 45.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 196.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 73.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 198.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 11.9 MB/s eta 0:00:00
# $ /usr/bin/python3 -m pip install -q -e .[viz,notebook,metrics]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 64.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 175.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.8/910.8 kB 101.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 kB 51.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 8.5 MB/s eta 0:00:00
# Working directory: /content/neurovlm_gnn
# $ git branch --show-current
# neurovlm_gnn
# Repo branch: neurovlm_gnn
# Drive root: /content/drive/MyDrive/neurovlm

# %% [markdown]
# ## Subprocess Streaming Smoke Check
#
# The next cell should display one subprocess line per second, including stderr. Stage 3 and corrected Stage 4 use the same streaming helper. Colab/Jupyter may still delay browser rendering during front-end stalls, but the notebook no longer captures the full training output or waits for process completion before printing each received line.

# %%
RUN_SUBPROCESS_STREAMING_SMOKE_TEST = os.environ.get("NEUROVLM_STREAMING_SMOKE_TEST", "1") == "1"
if RUN_SUBPROCESS_STREAMING_SMOKE_TEST:
    run_subprocess_streaming([
        sys.executable,
        "-u",
        "-c",
        "import sys, time\nfor i in range(3):\n    print(f'streaming smoke stdout {i + 1}/3', flush=True)\n    time.sleep(1)\nprint('streaming smoke stderr visible', file=sys.stderr, flush=True)",
    ], cwd=REPO_DIR, label="streaming-smoke")
else:
    print("Streaming smoke test skipped via NEUROVLM_STREAMING_SMOKE_TEST=0", flush=True)
# Out:
# [streaming-smoke] $ /usr/bin/python3 -u -c 'import sys, time
# for i in range(3):
#     print(f'"'"'streaming smoke stdout {i + 1}/3'"'"', flush=True)
#     time.sleep(1)
# print('"'"'streaming smoke stderr visible'"'"', file=sys.stderr, flush=True)'
# streaming smoke stdout 1/3
# streaming smoke stdout 2/3
# streaming smoke stdout 3/3
# streaming smoke stderr visible

# %% [markdown]
# ## Config Switches
#
# Top-level controls for building/downloading the selected text cache, choosing which AE branches feed downstream Stage 3/4, rerunning the selected convention-matched Stage 3 branches, and running the selected corrected convention-matched Stage 4 branches.

# %%
# 6a top-level controls
CREATE_OR_DOWNLOAD_NORMALIZED_CACHE = True
RERUN_STAGE3_NORMALIZED = True
RUN_CORRECTED_STAGE4_NORMALIZED = True
RUN_FRESH_STAGE3_PROJECTOR_CONTROL = False
UPLOAD_RESULTS_TO_DRIVE = True

VAL_INTERVAL = int(os.environ.get("NEUROVLM_STAGE3_VAL_INTERVAL", "1"))
RUN_TRAIN_SANITY_EVAL = os.environ.get("NEUROVLM_RUN_TRAIN_SANITY_EVAL", "0") == "1"
SAVE_PLOTS_DURING_TRAINING = os.environ.get("NEUROVLM_SAVE_PLOTS_DURING_TRAINING", "0") == "1"
RUN_UMAP_DURING_TRAINING = os.environ.get("NEUROVLM_RUN_UMAP_DURING_TRAINING", "0") == "1"
RUN_COVARIATE_CORRELATIONS = os.environ.get("NEUROVLM_RUN_COVARIATE_CORRELATIONS", "0") == "1"
FINAL_TEST_EVAL = os.environ.get("NEUROVLM_FINAL_TEST_EVAL", "1") != "0"

STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING = os.environ.get(
    "NEUROVLM_STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING",
    "1" if DEFAULT_STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING else "0",
).strip().lower() in {"1", "true", "yes", "on"}
GENERATION_AUC_VAL_INTERVAL = int(os.environ.get("NEUROVLM_GENERATION_AUC_VAL_INTERVAL", str(DEFAULT_GENERATION_AUC_VAL_INTERVAL)))
RUN_DUPLICATE_AWARE_VAL_EVERY_EPOCH = os.environ.get("NEUROVLM_RUN_DUPLICATE_AWARE_VAL_EVERY_EPOCH", "0") == "1"
RUN_RAW_AND_GROUP_AUC_DURING_TRAINING = os.environ.get("NEUROVLM_RUN_RAW_AND_GROUP_AUC_DURING_TRAINING", "0") == "1"
RUN_FULL_DEBUG_METRICS_DURING_TRAINING = os.environ.get("NEUROVLM_RUN_FULL_DEBUG_METRICS_DURING_TRAINING", "0") == "1"

# Stage 4 checkpoint policy (spatial-first)
STAGE4_PRIMARY_CHECKPOINT = STAGE4_PRIMARY_SPATIAL_CHECKPOINT   # "best_val_top5_dice.pt"
STAGE4_SPATIAL_CORR_CHECKPOINT_NAME = STAGE4_SPATIAL_CORR_CHECKPOINT  # "best_val_spatial_corr.pt"
STAGE4_SEMANTIC_CHECKPOINT_NAME = STAGE4_SEMANTIC_CHECKPOINT    # "best_val_generation_normalized_auc.pt"
SAVE_LEGACY_CHECKPOINT_ALIASES = False
SAVE_LEGACY_STAGE3_CHECKPOINT_ALIASES = False

AE_BRANCH_MODE = "mixed_and_specialized" # mixed_and_specialized, mixed_only or specialized_only
TEXT_EMBEDDING_CONVENTION = os.environ.get("NEUROVLM_TEXT_EMBEDDING_CONVENTION", "normalized_specter2")

# %%
HF_DATASET_REPO = os.environ.get("NEUROVLM_ATLAS_FREE_HF_REPO", "neurovlm/atlas_free_cnn_dataset")
LOCAL_UNIFIED_CACHE_DIR = REPO_DIR / "experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild"
LOCAL_SPLIT_DIR = LOCAL_UNIFIED_CACHE_DIR / "splits"
LOCAL_PACK_DIR = REPO_DIR / "experiments/3dcnn/atlas_free_cnn/cache/hf_atlas_free_cnn_rebuild"
LOCAL_TEXT_CACHE_DIR = REPO_DIR / "experiments/3dcnn/atlas_free_cnn/cache/text_embeddings"
TEXT_EMBEDDING_SPEC = resolve_text_embedding_cache(
    TEXT_EMBEDDING_CONVENTION,
    repo_dir=REPO_DIR,
    local_cache_dir=LOCAL_TEXT_CACHE_DIR,
    hf_repo=HF_DATASET_REPO,
)
if TEXT_EMBEDDING_SPEC["convention"] not in {"normalized_specter2", "legacy_specter2"}:
    raise ValueError("Notebook 6a expects TEXT_EMBEDDING_CONVENTION to be 'normalized_specter2' or 'legacy_specter2'.")
TEXT_EMBEDDING_PREPROCESSING = TEXT_EMBEDDING_SPEC["preprocessing"]
TEXT_EMBEDDING_DIR_SUFFIX = text_embedding_convention_dir_suffix(TEXT_EMBEDDING_SPEC["convention"])
TEXT_EMBEDDING_SUMMARY_LABEL = TEXT_EMBEDDING_SPEC["convention"]
STAGE3_SPECTER_DIRNAME = stage3_dirname_for_text_embedding_convention(TEXT_EMBEDDING_SPEC["convention"])
CORRECTED_STAGE4_SPECTER_DIRNAME = corrected_stage4_dirname_for_text_embedding_convention(TEXT_EMBEDDING_SPEC["convention"])
STAGE3_PROVENANCE_FILENAME = f"{TEXT_EMBEDDING_DIR_SUFFIX}_provenance.json"
STAGE3_COMPLETE_MARKER_NAME = "NORMALIZED_STAGE3_COMPLETE.json" if TEXT_EMBEDDING_DIR_SUFFIX == "normalized_specter" else "LEGACY_STAGE3_COMPLETE.json"
AE_BRANCH_SPECS = ae_branch_specs(AE_BRANCH_MODE)
AE_BRANCH_RUN_NAMES = [spec["run"] for spec in AE_BRANCH_SPECS]
AE_BRANCH_REQUIRED_SELECTION_KEYS = list(dict.fromkeys(spec["ae_registry_key"] for spec in AE_BRANCH_SPECS))
print("AE_BRANCH_MODE:", AE_BRANCH_MODE)
print("Selected AE branch count:", len(AE_BRANCH_SPECS))
print("Selected AE branch runs:", AE_BRANCH_RUN_NAMES)
print("Required AE registry keys:", AE_BRANCH_REQUIRED_SELECTION_KEYS)



def hf_download_first_available(filenames, local_dir: Path) -> Path:
    return shared_hf_download_first_available(
        list(filenames),
        local_dir,
        dataset_repo=HF_DATASET_REPO,
    )


def discover_unified_split_dir() -> Path:
    return shared_discover_unified_split_dir(
        repo_dir=REPO_DIR,
        drive_root=DRIVE_ROOT,
        dataset_repo=HF_DATASET_REPO,
        local_unified_cache_dir=LOCAL_UNIFIED_CACHE_DIR,
        local_split_dir=LOCAL_SPLIT_DIR,
        local_pack_dir=LOCAL_PACK_DIR,
    )

UNIFIED_SPLIT_DIR = discover_unified_split_dir()
TRAIN_JSONL = str(UNIFIED_SPLIT_DIR / "train.jsonl")
VAL_JSONL = str(UNIFIED_SPLIT_DIR / "val.jsonl")
TEST_JSONL = str(UNIFIED_SPLIT_DIR / "test.jsonl")
SPLIT_FINGERPRINTS = split_file_fingerprints(UNIFIED_SPLIT_DIR)
print("Unified split dir:", UNIFIED_SPLIT_DIR)
print("Train JSONL:", TRAIN_JSONL)

RUN_MODE = "downstream_only"
DATA_MODE = "mixed"
RERUN_STAGE1_CHECKPOINT_EVALUATION = False

import torch
from neurovlm.retrieval_resources import (
    _load_mixed_ae,
    _load_pubmed_finetuned_ae,
    _load_nilearn_finetuned_ae,
    _load_neurovault_finetuned_ae,
)

AE_RESOURCE_LOADERS = {
    "mixed_stage1a": _load_mixed_ae,
    "mixed_to_pubmed_stage1b": _load_pubmed_finetuned_ae,
    "mixed_to_nilearn_stage1b": _load_nilearn_finetuned_ae,
    "mixed_to_neurovault_stage1b": _load_neurovault_finetuned_ae,
}

AE_RESOURCE_CHECKPOINT_DIR = REPO_DIR / "experiments/3dcnn/atlas_free_cnn/cache/retrieval_resource_ae_checkpoints"
AE_RESOURCE_CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)


def ae_resource_checkpoint(key: str, filename: str, ae_variant: str) -> str:
    model = AE_RESOURCE_LOADERS[key]()
    checkpoint_path = AE_RESOURCE_CHECKPOINT_DIR / filename
    target_shape = list(getattr(model.decoder, "output_shape", [36, 45, 38]))
    model_cfg = {"latent_dim": 384, "base_channels": 64, "num_blocks": 4, "dropout": 0.1, "norm": "group", "pooling": "max", "encoder_arch": "plain", "blocks_per_stage": 2, "use_dilation": False, "multi_scale": False, "global_context": "none"}
    torch.save({"model": model.state_dict(), "config": {"model": model_cfg, "target_shape": target_shape, "ae_variant": ae_variant}, "target_shape": target_shape, "ae_variant": ae_variant, "checkpoint_source_function": AE_RESOURCE_LOADERS[key].__name__}, checkpoint_path)
    return str(checkpoint_path)

CONFIGURED_SELECTED_AE_CHECKPOINTS = {
    "mixed_stage1a": {
        "path": ae_resource_checkpoint("mixed_stage1a", "mixed_ae.pt", "mixed_baseline_raw_mse"),
        "stage": "stage1a",
        "training_domain": "mixed",
        "checkpoint_name": "mixed_ae.pt",
        "selection_reason": "locked_downstream_stage1_selection",
        "evaluation_status": "completed",
    },
    "mixed_to_pubmed_stage1b": {
        "path": ae_resource_checkpoint("mixed_to_pubmed_stage1b", "pubmed_finetuned_ae.pt", "mixed_baseline_to_pubmed"),
        "stage": "stage1b",
        "training_domain": "pubmed",
        "checkpoint_name": "pubmed_finetuned_ae.pt",
        "selection_reason": "locked_downstream_stage1_selection",
        "evaluation_status": "completed",
    },
    "mixed_to_nilearn_stage1b": {
        "path": ae_resource_checkpoint("mixed_to_nilearn_stage1b", "nilearn_finetuned_ae.pt", "mixed_baseline_to_nilearn"),
        "stage": "stage1b",
        "training_domain": "nilearn",
        "checkpoint_name": "nilearn_finetuned_ae.pt",
        "selection_reason": "locked_downstream_stage1_selection",
        "evaluation_status": "completed",
    },
    "mixed_to_neurovault_stage1b": {
        "path": ae_resource_checkpoint("mixed_to_neurovault_stage1b", "neurovault_finetuned_ae.pt", "mixed_baseline_to_neurovault"),
        "stage": "stage1b",
        "training_domain": "neurovault",
        "checkpoint_name": "neurovault_finetuned_ae.pt",
        "selection_reason": "locked_downstream_stage1_selection",
        "evaluation_status": "completed",
    },
}

# Optional provenance-only notebook-7 evaluation output folders. Leave blank if unavailable.
STAGE1A_EVALUATION_DIR_VALUE = os.environ.get("NEUROVLM_STAGE1A_EVALUATION_DIR", "").strip()
STAGE1B_EVALUATION_DIR_VALUE = os.environ.get("NEUROVLM_STAGE1B_EVALUATION_DIR", "").strip()
STAGE1A_EVALUATION_DIR = Path(STAGE1A_EVALUATION_DIR_VALUE).expanduser() if STAGE1A_EVALUATION_DIR_VALUE else None
STAGE1B_EVALUATION_DIR = Path(STAGE1B_EVALUATION_DIR_VALUE).expanduser() if STAGE1B_EVALUATION_DIR_VALUE else None

RUN_STAGE1_SELECTION_INTEGRATION = True
RERUN_STAGE3 = os.environ.get(
    "NEUROVLM_RERUN_STAGE3",
    os.environ.get("NEUROVLM_RERUN_STAGE3_NORMALIZED", "1" if RERUN_STAGE3_NORMALIZED else "0"),
) == "1"
RUN_STAGE3_CONTRASTIVE = RERUN_STAGE3
RUN_STAGE4_TEXT_TO_BRAIN = os.environ.get(
    "NEUROVLM_RUN_CORRECTED_STAGE4",
    os.environ.get("NEUROVLM_RUN_CORRECTED_STAGE4_NORMALIZED", "1" if RUN_CORRECTED_STAGE4_NORMALIZED else "0"),
) == "1"
RUN_STAGE5_GENERATION_EVAL = True
COMPLETED_STAGE3_RUN_ROOT_VALUE = os.environ.get("NEUROVLM_COMPLETED_STAGE3_RUN_ROOT", "").strip()
DEFAULT_COMPLETED_STAGE3_RUN_ROOT = DRIVE_ROOT / "runs_stage2_stage3_stage4/stage2_stage3_stage4_20260625_210801"
COMPLETED_STAGE3_RUN_ROOT = Path(COMPLETED_STAGE3_RUN_ROOT_VALUE).expanduser() if COMPLETED_STAGE3_RUN_ROOT_VALUE else DEFAULT_COMPLETED_STAGE3_RUN_ROOT
STAGE4_TEXT_EMBEDDING_CACHE_VALUE = os.environ.get("NEUROVLM_STAGE4_TEXT_EMBEDDING_CACHE", "").strip()
STAGE4_TEXT_EMBEDDING_CACHE = Path(STAGE4_TEXT_EMBEDDING_CACHE_VALUE).expanduser() if STAGE4_TEXT_EMBEDDING_CACHE_VALUE else None
STAGE4_TEXT_EMBEDDING_CACHE_FILENAME = os.environ.get("NEUROVLM_STAGE4_TEXT_EMBEDDING_CACHE_FILENAME", "").strip()

domain_dirs = DOMAIN_DIRS
specialized_dirs = SPECIALIZED_BRANCHES
NUM_WORKERS = int(os.environ.get("NEUROVLM_NUM_WORKERS", "4" if IN_COLAB else "0"))
EVAL_NUM_WORKERS = int(os.environ.get("NEUROVLM_EVAL_NUM_WORKERS", str(NUM_WORKERS)))
PREFETCH_FACTOR = int(os.environ.get("NEUROVLM_PREFETCH_FACTOR", "4"))
METRICS_DEVICE = os.environ.get("NEUROVLM_METRICS_DEVICE", "cuda")

BASE_OUTPUT_DIR = DRIVE_ROOT if "DRIVE_ROOT" in globals() and UPLOAD_RESULTS_TO_DRIVE else Path(".")
STAGE1_SELECTION_INTEGRATION_OUTPUT_ROOT = DRIVE_ROOT / f"runs_stage1_selection_integration_6a_{TEXT_EMBEDDING_DIR_SUFFIX}" if "DRIVE_ROOT" in globals() else Path(f"runs_stage1_selection_integration_6a_{TEXT_EMBEDDING_DIR_SUFFIX}")
# Out:
# AE_BRANCH_MODE: mixed_and_specialized
# Selected AE branch count: 6
# Selected AE branch runs: ['mixed_stage1a_on_pubmed', 'mixed_to_pubmed_stage1b_on_pubmed', 'mixed_stage1a_on_nilearn', 'mixed_to_nilearn_stage1b_on_nilearn', 'mixed_stage1a_on_neurovault', 'mixed_to_neurovault_stage1b_on_neurovault']
# Required AE registry keys: ['mixed_stage1a', 'mixed_to_pubmed_stage1b', 'mixed_to_nilearn_stage1b', 'mixed_to_neurovault_stage1b']
# Downloading atlas-free CNN split JSONLs from Hugging Face: neurovlm/atlas_free_cnn_dataset
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:986: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# train.jsonl:   0%|          | 0.00/81.8M [00:00<?, ?B/s]
# val.jsonl:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# test.jsonl:   0%|          | 0.00/10.2M [00:00<?, ?B/s]
# train_map_ids.json: 0.00B [00:00, ?B/s]
# val_map_ids.json: 0.00B [00:00, ?B/s]
# test_map_ids.json: 0.00B [00:00, ?B/s]
# atlas_free_cnn_volumes.pt:   0%|          | 0.00/4.16G [00:00<?, ?B/s]
# Volume tensor available at: /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/hf_atlas_free_cnn_rebuild/atlas_free_cnn_volumes.pt
# Unified split files used:
# - train: /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/train.jsonl sha256=5216f4d249332f497fe2bc1d6388f9ec23d0d4f16c3f7df2ac7dfe198de9ea0e fingerprint=feee9b706ba6b6a3d8e1fae7495d4d8dc8a3df9a3c86639b2ac299d66f1e9f52 rows=26944
# - val: /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/val.jsonl sha256=325580264110b38da5ee6f29228ce843c917ee3adef69ac261b6606b2425fa49 fingerprint=958ffe87a9563b8212e9cf2a88bc66f10d6e678b5dafeb807f5022175752469b rows=3366
# - test: /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/test.jsonl sha256=b05ed4cb6808b48fd3f1a12df0cec89d748ad76fe5289cd5d534a3c713c116c1 fingerprint=fb0dfc838a924482b02b4251b603f6ecaf22007f036e58e910f663f7f6401d04 rows=3347
# Unified split dir: /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits
# Train JSONL: /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/train.jsonl
# mixed_ae.pt:   0%|          | 0.00/46.5M [00:00<?, ?B/s]
# pubmed_finetuned_ae_top5_dice.pt:   0%|          | 0.00/46.4M [00:00<?, ?B/s]
# nilearn_finetuned_ae_spatial_corr.pt:   0%|          | 0.00/46.4M [00:00<?, ?B/s]
# neurovault_finetuned_ae_spatial_corr.pt:   0%|          | 0.00/46.4M [00:00<?, ?B/s]

# %%
paths = create_stage2_stage3_stage4_run_dir(BASE_OUTPUT_DIR, prefix="6a_results", branch_stage_dirs=())
RUN_DIR = Path(paths["run_dir"])
print(f"Run directory: {RUN_DIR}")

metadata_dir = Path(paths["metadata"])
metadata_dir.mkdir(parents=True, exist_ok=True)
write_json(metadata_dir / "run_config.json", {
    "RUN_MODE": RUN_MODE,
    "DATA_MODE": DATA_MODE,
    "AE_CHECKPOINT_SOURCE": "neurovlm.retrieval_resources",
    "AE_RESOURCE_CHECKPOINT_DIR": str(AE_RESOURCE_CHECKPOINT_DIR),
    "CONFIGURED_SELECTED_AE_CHECKPOINTS": CONFIGURED_SELECTED_AE_CHECKPOINTS,
    "AE_BRANCH_MODE": AE_BRANCH_MODE,
    "AE_BRANCH_COUNT": len(AE_BRANCH_SPECS),
    "AE_BRANCH_RUN_NAMES": AE_BRANCH_RUN_NAMES,
    "AE_BRANCH_REQUIRED_SELECTION_KEYS": AE_BRANCH_REQUIRED_SELECTION_KEYS,
    "STAGE1A_EVALUATION_DIR": str(STAGE1A_EVALUATION_DIR or ""),
    "STAGE1B_EVALUATION_DIR": str(STAGE1B_EVALUATION_DIR or ""),
    "RERUN_STAGE1_CHECKPOINT_EVALUATION": RERUN_STAGE1_CHECKPOINT_EVALUATION,
    "RUN_STAGE1_SELECTION_INTEGRATION": RUN_STAGE1_SELECTION_INTEGRATION,
    "RERUN_STAGE3": RERUN_STAGE3,
    "RUN_STAGE3_CONTRASTIVE": RUN_STAGE3_CONTRASTIVE,
    "COMPLETED_STAGE3_RUN_ROOT": str(COMPLETED_STAGE3_RUN_ROOT or ""),
    "RUN_STAGE4_TEXT_TO_BRAIN": RUN_STAGE4_TEXT_TO_BRAIN,
    "STAGE4_TEXT_EMBEDDING_CACHE": str(STAGE4_TEXT_EMBEDDING_CACHE or ""),
    "STAGE4_TEXT_EMBEDDING_CACHE_FILENAME": STAGE4_TEXT_EMBEDDING_CACHE_FILENAME,
    "TEXT_EMBEDDING_CONVENTION": TEXT_EMBEDDING_CONVENTION,
    "TEXT_EMBEDDING_SPEC": TEXT_EMBEDDING_SPEC,
    **text_embedding_metadata_fields(TEXT_EMBEDDING_SPEC),
    "RUN_STAGE5_GENERATION_EVAL": RUN_STAGE5_GENERATION_EVAL,
})
write_json(metadata_dir / "git_info.json", git_info(REPO_DIR))
write_json(metadata_dir / "unified_split_fingerprints.json", SPLIT_FINGERPRINTS)
(metadata_dir / "environment.txt").write_text(sys.version)
# Out:
# Run directory: /content/drive/MyDrive/neurovlm/6a_results_20260706_180022
# 50

# %% [markdown]
# ## Stage 1 Selection Integration: Validate Explicit Checkpoint Paths

# %%
SELECTED_AE_CHECKPOINTS = {}
STAGE2_STAGE3_STAGE4_INPUT_MANIFEST = None
STAGE1_SELECTION_INTEGRATION_DIR = None
SELECTED_DOWNSTREAM_RUNS = []
stage1_selection_status = "not_requested"


def select_downstream_runs_from_manifest(manifest: dict) -> list[dict]:
    return selected_downstream_runs_for_ae_branch_mode(
        manifest["six_stage2_stage3_stage4_runs"],
        AE_BRANCH_MODE,
    )


if RUN_STAGE1_SELECTION_INTEGRATION:
    integration_result = integrate_completed_stage1_selection(
        IntegrationConfig(
            output_root=STAGE1_SELECTION_INTEGRATION_OUTPUT_ROOT,
            selected_checkpoints=CONFIGURED_SELECTED_AE_CHECKPOINTS,
            stage1a_evaluation_dir=STAGE1A_EVALUATION_DIR,
            stage1b_evaluation_dir=STAGE1B_EVALUATION_DIR,
            rerun_stage1_checkpoint_evaluation=RERUN_STAGE1_CHECKPOINT_EVALUATION,
            required_selection_keys=tuple(AE_BRANCH_REQUIRED_SELECTION_KEYS),
            downstream_runs=AE_BRANCH_SPECS,
        )
    )
    stage1_selection_status = integration_result["status"]
    STAGE1_SELECTION_INTEGRATION_DIR = Path(integration_result["output_dir"])
    STAGE2_STAGE3_STAGE4_INPUT_MANIFEST = STAGE1_SELECTION_INTEGRATION_DIR / "03_downstream_usage/stage2_stage3_stage4_input_manifest.json"
    downstream_manifest = json.loads(STAGE2_STAGE3_STAGE4_INPUT_MANIFEST.read_text())
    SELECTED_AE_CHECKPOINTS = downstream_manifest["selected_ae_checkpoints"]
    SELECTED_DOWNSTREAM_RUNS = select_downstream_runs_from_manifest(downstream_manifest)
    write_json(metadata_dir / "stage1_selection_integration_result.json", integration_result)
    write_json(metadata_dir / "stage2_stage3_stage4_input_manifest_pointer.json", {"path": str(STAGE2_STAGE3_STAGE4_INPUT_MANIFEST)})
    write_json(metadata_dir / "selected_ae_branch_runs.json", {
        "AE_BRANCH_MODE": AE_BRANCH_MODE,
        "required_selection_keys": AE_BRANCH_REQUIRED_SELECTION_KEYS,
        "selected_run_count": len(SELECTED_DOWNSTREAM_RUNS),
        "selected_runs": SELECTED_DOWNSTREAM_RUNS,
    })
    validation_report = STAGE1_SELECTION_INTEGRATION_DIR / "02_selected_checkpoint_registry/selected_checkpoint_validation.json"
    if stage1_selection_status not in {"completed", "completed_with_warnings"}:
        print("Stage 1 checkpoint validation failed:", stage1_selection_status)
        print("Validation report:", validation_report)
        for row in integration_result.get("blocking_checkpoints", []):
            print(f"- {row.get('key')}: {row.get('status')} -> {row.get('checkpoint_path')}")
            if row.get("warnings"):
                print("  warnings:", row.get("warnings"))
        raise RuntimeError(
            f"Stage 1 selection integration failed: {stage1_selection_status}. "
            f"Set NEUROVLM_AE_CHECKPOINT_ROOT or the individual NEUROVLM_*_AE_CKPT paths. "
            f"See {validation_report}"
        )
    print("Stage 1 checkpoint validation:", stage1_selection_status)
    print("Integration output:", STAGE1_SELECTION_INTEGRATION_DIR)
    print("Downstream manifest:", STAGE2_STAGE3_STAGE4_INPUT_MANIFEST)
    print("AE_BRANCH_MODE:", AE_BRANCH_MODE)
    print("Selected downstream branches:", ", ".join(run["run"] for run in SELECTED_DOWNSTREAM_RUNS))
else:
    print("Stage 1 selection integration not requested")
# Out:
# Stage 1 checkpoint validation: completed_with_warnings
# Integration output: /content/drive/MyDrive/neurovlm/runs_stage1_selection_integration_6a_normalized_specter/stage1_selection_integration_20260706_180022
# Downstream manifest: /content/drive/MyDrive/neurovlm/runs_stage1_selection_integration_6a_normalized_specter/stage1_selection_integration_20260706_180022/03_downstream_usage/stage2_stage3_stage4_input_manifest.json
# AE_BRANCH_MODE: mixed_and_specialized
# Selected downstream branches: mixed_stage1a_on_pubmed, mixed_to_pubmed_stage1b_on_pubmed, mixed_stage1a_on_nilearn, mixed_to_nilearn_stage1b_on_nilearn, mixed_stage1a_on_neurovault, mixed_to_neurovault_stage1b_on_neurovault

# %% [markdown]
# ## Preserved Stage 1 Evaluation Tables

# %%
if STAGE1_SELECTION_INTEGRATION_DIR:
    for path in [
        STAGE1_SELECTION_INTEGRATION_DIR / "01_existing_evaluation_tables/mixed_stage1a_checkpoint_selection.csv",
        STAGE1_SELECTION_INTEGRATION_DIR / "01_existing_evaluation_tables/pubmed_stage1b_checkpoint_selection.csv",
        STAGE1_SELECTION_INTEGRATION_DIR / "01_existing_evaluation_tables/nilearn_stage1b_checkpoint_selection.csv",
        STAGE1_SELECTION_INTEGRATION_DIR / "01_existing_evaluation_tables/neurovault_stage1b_checkpoint_selection.csv",
        STAGE1_SELECTION_INTEGRATION_DIR / "02_selected_checkpoint_registry/selected_ae_checkpoints_for_stage2_stage3_stage4.json",
        STAGE1_SELECTION_INTEGRATION_DIR / "02_selected_checkpoint_registry/selected_checkpoint_validation.json",
        STAGE1_SELECTION_INTEGRATION_DIR / "03_downstream_usage/selected_ae_branch_assignment.csv",
    ]:
        print(path, "exists=", path.exists())
else:
    print("No Stage 1 selection integration output available")
# Out:
# /content/drive/MyDrive/neurovlm/runs_stage1_selection_integration_6a_normalized_specter/stage1_selection_integration_20260706_180022/01_existing_evaluation_tables/mixed_stage1a_checkpoint_selection.csv exists= False
# /content/drive/MyDrive/neurovlm/runs_stage1_selection_integration_6a_normalized_specter/stage1_selection_integration_20260706_180022/01_existing_evaluation_tables/pubmed_stage1b_checkpoint_selection.csv exists= False
# /content/drive/MyDrive/neurovlm/runs_stage1_selection_integration_6a_normalized_specter/stage1_selection_integration_20260706_180022/01_existing_evaluation_tables/nilearn_stage1b_checkpoint_selection.csv exists= False
# /content/drive/MyDrive/neurovlm/runs_stage1_selection_integration_6a_normalized_specter/stage1_selection_integration_20260706_180022/01_existing_evaluation_tables/neurovault_stage1b_checkpoint_selection.csv exists= False
# /content/drive/MyDrive/neurovlm/runs_stage1_selection_integration_6a_normalized_specter/stage1_selection_integration_20260706_180022/02_selected_checkpoint_registry/selected_ae_checkpoints_for_stage2_stage3_stage4.json exists= True
# /content/drive/MyDrive/neurovlm/runs_stage1_selection_integration_6a_normalized_specter/stage1_selection_integration_20260706_180022/02_selected_checkpoint_registry/selected_checkpoint_validation.json exists= True
# /content/drive/MyDrive/neurovlm/runs_stage1_selection_integration_6a_normalized_specter/stage1_selection_integration_20260706_180022/03_downstream_usage/selected_ae_branch_assignment.csv exists= True

# %% [markdown]
# ## Part 1: Build or Download Normalized SPECTER2 Cache
#
# This cell lists the Hugging Face repository, builds or downloads `text_embeddings/specter2_stage3_stage4_emptycentered_unitnorm.pt`, validates 768-dimensional unit norms, and fails before training if the wrong cache is loaded.

# %%
def required_primary_text_records() -> dict:
    return required_text_records_from_jsonls([TRAIN_JSONL, VAL_JSONL, TEST_JSONL])


def validate_resolved_text_cache(spec: dict) -> dict:
    requirements = required_primary_text_records()
    audit = validate_text_embedding_cache(
        spec,
        required_text_ids=requirements["text_ids"],
        required_texts=requirements["texts"],
        expected_dim=spec["expected_dim"],
        expect_unit_norm=spec["expect_unit_norm"],
        mean_norm_tol=1e-3,
    )
    print(f"{spec['convention']} text embedding cache stats")
    print(json.dumps(audit["stats"], indent=2))
    return audit


if CREATE_OR_DOWNLOAD_NORMALIZED_CACHE:
    print_relevant_text_embedding_hf_files(HF_DATASET_REPO)

TEXT_EMBEDDING_SPEC = resolve_text_embedding_cache(
    TEXT_EMBEDDING_CONVENTION,
    repo_dir=REPO_DIR,
    local_cache_dir=LOCAL_TEXT_CACHE_DIR,
    hf_repo=HF_DATASET_REPO,
)
TEXT_EMBEDDING_CACHE = Path(TEXT_EMBEDDING_SPEC["local_cache_path"]).expanduser()
if not TEXT_EMBEDDING_CACHE.exists():
    downloaded = False
    try:
        TEXT_EMBEDDING_CACHE = download_text_embedding_cache(TEXT_EMBEDDING_SPEC)
        downloaded = True
    except Exception as exc:
        print(f"{TEXT_EMBEDDING_SPEC['convention']} cache was not available on HF yet:", exc)
    if not downloaded and CREATE_OR_DOWNLOAD_NORMALIZED_CACHE:
        TEXT_EMBEDDING_CACHE = build_normalized_specter2_cache(
            TEXT_EMBEDDING_SPEC,
            repo_dir=REPO_DIR,
            python_executable=sys.executable,
        )

if not TEXT_EMBEDDING_CACHE.exists():
    raise FileNotFoundError(f"Text embedding cache is missing: {TEXT_EMBEDDING_CACHE}")

TEXT_EMBEDDING_SPEC["local_cache_path"] = str(TEXT_EMBEDDING_CACHE)
TEXT_EMBEDDING_AUDIT = validate_resolved_text_cache(TEXT_EMBEDDING_SPEC)
TEXT_EMBEDDING_METADATA = text_embedding_metadata_fields(TEXT_EMBEDDING_SPEC, TEXT_EMBEDDING_AUDIT)
write_json(metadata_dir / f"text_cache_audit_{TEXT_EMBEDDING_CONVENTION}.json", {"spec": TEXT_EMBEDDING_SPEC, "audit": TEXT_EMBEDDING_AUDIT})
write_json(metadata_dir / f"text_cache_metadata_{TEXT_EMBEDDING_CONVENTION}.json", TEXT_EMBEDDING_METADATA)

NORMALIZED_PATHS = {
    "pt": Path(TEXT_EMBEDDING_SPEC["local_cache_path"]),
    "metadata": Path(TEXT_EMBEDDING_SPEC["metadata_local_path"]),
    "validation": Path(TEXT_EMBEDDING_SPEC["validation_local_path"]),
    "index": Path(TEXT_EMBEDDING_SPEC["index_local_path"]),
}
NORMALIZED_SPECTER_CACHE = TEXT_EMBEDDING_CACHE
NORMALIZED_CACHE_AUDIT = TEXT_EMBEDDING_AUDIT
TEXT_EMBEDDING_CACHE = NORMALIZED_SPECTER_CACHE
STAGE4_TEXT_EMBEDDING_CACHE = NORMALIZED_SPECTER_CACHE
print("TEXT_EMBEDDING_CONVENTION =", TEXT_EMBEDDING_CONVENTION)
print("TEXT_EMBEDDING_CACHE =", TEXT_EMBEDDING_CACHE)
print("TEXT_EMBEDDING_PREPROCESSING =", TEXT_EMBEDDING_PREPROCESSING)
# Out:
# Potentially relevant Hugging Face files
# - atlas_free_cnn_manifest.json
# - atlas_free_cnn_rows.parquet
# - atlas_free_cnn_text_pairs.parquet
# - specter2_stage3_stage4_emptycentered_unitnorm.pt
# - specter2_stage3_stage4_emptycentered_unitnorm_index.csv
# - specter2_stage3_stage4_emptycentered_unitnorm_metadata.json
# - specter2_stage3_stage4_emptycentered_unitnorm_validation.json
# - specter_text_cache.pt
# - test.jsonl
# - train.jsonl
# - val.jsonl
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:986: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# specter2_stage3_stage4_emptycentered_uni(…):   0%|          | 0.00/142M [00:00<?, ?B/s]
# (…)ge4_emptycentered_unitnorm_metadata.json: 0.00B [00:00, ?B/s]
# (…)4_emptycentered_unitnorm_validation.json: 0.00B [00:00, ?B/s]
# specter2_stage3_stage4_emptycentered_uni(…):   0%|          | 0.00/12.1M [00:00<?, ?B/s]
# normalized_specter2 text embedding cache stats
# {
#   "path": "/content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/text_embeddings/specter2_stage3_stage4_emptycentered_unitnorm.pt",
#   "sha256": "dd52b88bbb077f5b4f4c6d8b270a2cb0f43ff593e3f187116767e3c8739e10d4",
#   "convention": "normalized_specter2",
#   "n": 33657,
#   "dim": 768,
#   "norm_mean": 1.0,
#   "norm_std": 6.75429063790034e-08,
#   "norm_min": 0.9999997019767761,
#   "norm_max": 1.000000238418579,
#   "fraction_within_1e_3": 1.0,
#   "text_id_count": 33657,
#   "text_key_count": 33398,
#   "required_text_ids_present": true,
#   "required_texts_present": true,
#   "metadata_sha256": "d0339eba25bbf9ec43f18b51882994ad2a9cbbb214468ba2cdae205ce2fe2d32",
#   "validation_sha256": "656c5bd4bf9385a4cc9b01a5e28003958e509cc88598ef99c11c8edec0a1439e",
#   "index_sha256": "209a1ec4a98bbf4c3186755e3ac8290d2130a8a68ec457e512b0c67705275158"
# }
# TEXT_EMBEDDING_CONVENTION = normalized_specter2
# TEXT_EMBEDDING_CACHE = /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/text_embeddings/specter2_stage3_stage4_emptycentered_unitnorm.pt
# TEXT_EMBEDDING_PREPROCESSING = empty_string_centered_l2_unit_normalized

# %% [markdown]
# ## Stage 2/3: Selected Controlled Encoder Initialization Runs

# %%
TEXT_EMBEDDING_CACHE = NORMALIZED_SPECTER_CACHE
print("Stage 3 text embedding cache:", TEXT_EMBEDDING_CACHE)
print("Text preprocessing:", TEXT_EMBEDDING_PREPROCESSING)
print("Stage 3 output directory name:", STAGE3_SPECTER_DIRNAME)

def copy_stage3_checkpoint_aliases(ckpt_dir: Path) -> None:
    def copy_if_stale(src: Path, dst: Path) -> None:
        if dst.exists() and src.stat().st_size == dst.stat().st_size and src.stat().st_mtime_ns == dst.stat().st_mtime_ns:
            return
        shutil.copy2(src, dst)

    best = ckpt_dir / "best_ale_cnn.pt"
    last = ckpt_dir / "last_ale_cnn.pt"
    if best.exists():
        copy_if_stale(best, ckpt_dir / "best_val_normalized_recall_auc.pt")
    if last.exists():
        copy_if_stale(last, ckpt_dir / "last.pt")

if RUN_STAGE3_CONTRASTIVE:
    if not STAGE2_STAGE3_STAGE4_INPUT_MANIFEST or not Path(STAGE2_STAGE3_STAGE4_INPUT_MANIFEST).exists():
        raise RuntimeError("Stage 2/3 requires the validated Stage 1 selected-checkpoint manifest")
    downstream_manifest = json.loads(Path(STAGE2_STAGE3_STAGE4_INPUT_MANIFEST).read_text())
    SELECTED_DOWNSTREAM_RUNS = select_downstream_runs_from_manifest(downstream_manifest)
    print(f"Stage 3 selected branch mode: {AE_BRANCH_MODE} ({len(SELECTED_DOWNSTREAM_RUNS)} runs)")
    for run_idx, run in enumerate(SELECTED_DOWNSTREAM_RUNS, start=1):
        domain = run["domain"]
        branch = run["branch"]
        stage3_dir = stage_output_dir(RUN_DIR, domain, branch, "stage3", text_embedding_convention=TEXT_EMBEDDING_SPEC["convention"])
        ckpt_dir = stage3_dir / "checkpoints"
        complete_marker = stage3_dir / STAGE3_COMPLETE_MARKER_NAME
        if complete_marker.exists():
            print("Skipping complete Stage 3 run:", stage3_dir)
            copy_stage3_checkpoint_aliases(ckpt_dir)
            continue
        ae_entry = downstream_manifest["selected_ae_checkpoints"][run["ae_registry_key"]]
        checkpoint_name = Path(ae_entry["checkpoint_name"]).stem
        cmd = [
            sys.executable, "-u", "experiments/3dcnn/atlas_free_cnn/training/train_ale_cnn.py",
            "--mode", "atlas_free",
            "--model", "ale_3dcnn",
            "--train-jsonl", TRAIN_JSONL,
            "--val-jsonl", VAL_JSONL,
            "--test-jsonl", TEST_JSONL,
            "--text-embedding-cache", str(TEXT_EMBEDDING_CACHE),
            "--domain", domain,
            "--target-shape", "36,45,38",
            "--epochs", "150",
            "--early-stopping-patience", "25",
            "--val-interval", str(VAL_INTERVAL),
            "--batch-size", "512",
            "--base-channels", "64",
            "--num-blocks", "4",
            "--out-dim", "384",
            "--lr-cnn", "0.0001",
            "--lr-proj", "0.00001",
            "--weight-decay", "0.0001",
            "--warmup-epochs", "5",
            "--temperature", "0.07",
            "--dropout", "0.1",
            "--norm", "group",
            "--pooling", "max",
            "--encoder-init", "autoencoder_pretrained",
            "--ae-ckpt-path", str(ae_entry["path"]),
            "--ae-init-variant", str(run["ae_registry_key"]),
            "--ae-checkpoint-selection", checkpoint_name,
            "--text-proj-init", "pretrained_infonce",
            "--monitor-metric", "paper_recall_curve_auc",
            "--strict-controlled-recipe",
            "--run-dir", str(stage3_dir),
            "--checkpoint-dir", str(ckpt_dir),
        ]
        if RUN_TRAIN_SANITY_EVAL:
            cmd.append("--run-train-sanity-eval")
        if SAVE_PLOTS_DURING_TRAINING:
            cmd.append("--save-plots")
        if RUN_UMAP_DURING_TRAINING:
            cmd.append("--umap")
        if RUN_COVARIATE_CORRELATIONS:
            cmd.append("--run-covariate-correlations")
        if not FINAL_TEST_EVAL:
            cmd.append("--no-final-test-eval")
        stage3_run_name = f"{run['run']}_{TEXT_EMBEDDING_DIR_SUFFIX}"
        print(f"Starting sequential Stage 3 run {run_idx}/{len(SELECTED_DOWNSTREAM_RUNS)}: {stage3_run_name}", flush=True)
        run_subprocess_streaming(cmd, cwd=REPO_DIR, label=f"Stage 3 {stage3_run_name}")
        copy_stage3_checkpoint_aliases(ckpt_dir)
        write_json(stage3_dir / STAGE3_PROVENANCE_FILENAME, {
            "run": stage3_run_name,
            "text_embedding_cache": str(TEXT_EMBEDDING_CACHE),
            "text_embedding_cache_sha256": sha256_file(TEXT_EMBEDDING_CACHE),
            **TEXT_EMBEDDING_METADATA,
            "primary_metric": "mean bidirectional normalized recall@k curve AUC over k/N",
            "checkpoint_alias": str(ckpt_dir / "best_val_normalized_recall_auc.pt"),
            "text_proj_init": "pretrained_infonce",
            "text_projection_trainable": True,
            "single_positive_policy": "one selected primary text per map",
        })
        write_json(complete_marker, {"status": "complete", "stage3_dir": str(stage3_dir)})
else:
    print("Stage 3 not requested")

if RUN_FRESH_STAGE3_PROJECTOR_CONTROL:
    print("Fresh-projector control is enabled, but not part of the selected primary branch experiment. Add a separate control loop here if needed.")
# Out:
# Stage 3 text embedding cache: /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/text_embeddings/specter2_stage3_stage4_emptycentered_unitnorm.pt
# Text preprocessing: empty_string_centered_l2_unit_normalized
# Stage 3 output directory name: stage3_normalized_specter
# Stage 3 selected branch mode: mixed_and_specialized (6 runs)
# Starting sequential Stage 3 run 1/6: mixed_stage1a_on_pubmed_normalized_specter
# [Stage 3 mixed_stage1a_on_pubmed_normalized_specter] $ /usr/bin/python3 -u experiments/3dcnn/atlas_free_cnn/training/train_ale_cnn.py --mode atlas_free --model ale_3dcnn --train-jsonl /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/train.jsonl --val-jsonl /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/val.jsonl --test-jsonl /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/test.jsonl --text-embedding-cache /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/text_embeddings/specter2_stage3_stage4_emptycentered_unitnorm.pt --domain pubmed --target-shape 36,45,38 --epochs 150 --early-stopping-patience 25 --val-interval 1 --batch-size 512 --base-channels 64 --num-blocks 4 --out-dim 384 --lr-cnn 0.0001 --lr-proj 0.00001 --weight-decay 0.0001 --warmup-epochs 5 --temperature 0.07 --dropout 0.1 --norm group --pooling max --encoder-init autoencoder_pretrained --ae-ckpt-path /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/retrieval_resource_ae_checkpoints/mixed_ae.pt --ae-init-variant mixed_stage1a --ae-checkpoint-selection best_top1_dice --text-proj-init pretrained_infonce --monitor-metric paper_recall_curve_auc --strict-controlled-recipe --run-dir /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/01_pubmed/baseline_mixed_stage1a/stage3_normalized_specter --checkpoint-dir /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/01_pubmed/baseline_mixed_stage1a/stage3_normalized_specter/checkpoints
# AE encoder initialization:
# {
#   "encoder_init": "autoencoder_pretrained",
#   "ae_init_variant": "mixed_stage1a",
#   "ae_checkpoint_selection": "custom_path",
#   "ae_checkpoint_path": "/content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/retrieval_resource_ae_checkpoints/mixed_ae.pt",
#   "ae_checkpoint_epoch": null,
#   "ae_source_wise_reconstruction_metrics": {},
#   "ae_validation_metrics": {}
# }
# Building ALE model ...
# [timing] data_cache_load seconds=3.84
# Selected device: cuda
#
# == ALE Dataset ==
#   mode=atlas_free cache=None
#   volume shape=(36, 45, 38) aligned papers=24,526
#   split train=24,526 val=3,066 test=3,066
#
# == Model ==
#   ale_3dcnn brain params=4,846,464
#   text params=590,720 train_text=True
#   device=cuda amp=True batch=512
# Contrastive objective: symmetric InfoNCE over projected ALE-brain and projected SPECTER-text embeddings (not reconstruction/MSE).
# text_proj trainable=True trainable_text_params=590,720
# [timing] preflight_batch_size seconds=0.00
#   selected batch_size=512
# First-batch contrastive sanity check:
#   projected_text shape=(512, 384) projected_brain shape=(512, 384)
#   similarity matrix = normalize(text_proj(SPECTER)) @ normalize(brain_encoder(ALE)).T
#   sim shape=(512, 512)
#   diagonal entries are true paired text-brain examples from the same dataset row
#   first paper_idx values=[20237, 5616, 15317, 9100, 6748] diag cosine mean=0.0091
# [timing] train_epoch epoch=0 seconds=14.79
# [timing] validation_eval epoch=0 seconds=2.03
# Epoch 000/150 loss=6.2539 val_paper_recall_curve_auc=0.7259 val_r@10=0.0269 time=14.8s vram=33796MB
# [timing] artifact_save epoch=0 artifact=last_checkpoint seconds=0.34
# [timing] train_epoch epoch=1 seconds=13.24
# [timing] validation_eval epoch=1 seconds=1.07
# Epoch 001/150 loss=5.6022 val_paper_recall_curve_auc=0.8097 val_r@10=0.0571 time=13.2s vram=33817MB
# [timing] artifact_save epoch=1 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=2 seconds=12.98
# [timing] validation_eval epoch=2 seconds=1.10
# Epoch 002/150 loss=5.3275 val_paper_recall_curve_auc=0.8291 val_r@10=0.0737 time=13.0s vram=33817MB
# [timing] artifact_save epoch=2 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=3 seconds=12.98
# [timing] validation_eval epoch=3 seconds=1.05
# Epoch 003/150 loss=5.1868 val_paper_recall_curve_auc=0.8387 val_r@10=0.0814 time=13.0s vram=33817MB
# [timing] artifact_save epoch=3 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=4 seconds=12.51
# [timing] validation_eval epoch=4 seconds=1.01
# Epoch 004/150 loss=5.0892 val_paper_recall_curve_auc=0.8443 val_r@10=0.0897 time=12.5s vram=33817MB
# [timing] artifact_save epoch=4 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=5 seconds=12.51
# [timing] validation_eval epoch=5 seconds=1.04
# Epoch 005/150 loss=4.9896 val_paper_recall_curve_auc=0.8451 val_r@10=0.0933 time=12.5s vram=33817MB
# [timing] artifact_save epoch=5 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=6 seconds=12.34
# [timing] validation_eval epoch=6 seconds=1.02
# Epoch 006/150 loss=4.8880 val_paper_recall_curve_auc=0.8484 val_r@10=0.0943 time=12.3s vram=33817MB
# [timing] artifact_save epoch=6 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=7 seconds=12.30
# [timing] validation_eval epoch=7 seconds=1.00
# Epoch 007/150 loss=4.8008 val_paper_recall_curve_auc=0.8497 val_r@10=0.0970 time=12.3s vram=33817MB
# [timing] artifact_save epoch=7 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=8 seconds=12.52
# [timing] validation_eval epoch=8 seconds=1.04
# Epoch 008/150 loss=4.7005 val_paper_recall_curve_auc=0.8492 val_r@10=0.0962 time=12.5s vram=33817MB
# [timing] artifact_save epoch=8 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=9 seconds=12.50
# [timing] validation_eval epoch=9 seconds=1.04
# Epoch 009/150 loss=4.5898 val_paper_recall_curve_auc=0.8465 val_r@10=0.0946 time=12.5s vram=33817MB
# [timing] artifact_save epoch=9 artifact=last_checkpoint seconds=0.10
# [timing] train_epoch epoch=10 seconds=12.51
# [timing] validation_eval epoch=10 seconds=1.08
# Epoch 010/150 loss=4.4798 val_paper_recall_curve_auc=0.8467 val_r@10=0.0959 time=12.5s vram=33817MB
# [timing] artifact_save epoch=10 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=11 seconds=12.63
# [timing] validation_eval epoch=11 seconds=1.07
# Epoch 011/150 loss=4.3607 val_paper_recall_curve_auc=0.8466 val_r@10=0.0959 time=12.6s vram=33817MB
# [timing] artifact_save epoch=11 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=12 seconds=12.44
# [timing] validation_eval epoch=12 seconds=1.04
# Epoch 012/150 loss=4.2344 val_paper_recall_curve_auc=0.8440 val_r@10=0.0975 time=12.4s vram=33817MB
# [timing] artifact_save epoch=12 artifact=last_checkpoint seconds=0.09
# [timing] train_epoch epoch=13 seconds=12.31
# [timing] validation_eval epoch=13 seconds=0.99
# Epoch 013/150 loss=4.0980 val_paper_recall_curve_auc=0.8422 val_r@10=0.0923 time=12.3s vram=33817MB
# [timing] artifact_save epoch=13 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=14 seconds=12.39
# [timing] validation_eval epoch=14 seconds=1.02
# Epoch 014/150 loss=3.9619 val_paper_recall_curve_auc=0.8392 val_r@10=0.0926 time=12.4s vram=33817MB
# [timing] artifact_save epoch=14 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=15 seconds=12.60
# [timing] validation_eval epoch=15 seconds=1.02
# Epoch 015/150 loss=3.8226 val_paper_recall_curve_auc=0.8354 val_r@10=0.0913 time=12.6s vram=33817MB
# [timing] artifact_save epoch=15 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=16 seconds=12.74
# [timing] validation_eval epoch=16 seconds=1.04
# Epoch 016/150 loss=3.6839 val_paper_recall_curve_auc=0.8313 val_r@10=0.0952 time=12.7s vram=33817MB
# [timing] artifact_save epoch=16 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=17 seconds=12.48
# [timing] validation_eval epoch=17 seconds=1.01
# Epoch 017/150 loss=3.5505 val_paper_recall_curve_auc=0.8292 val_r@10=0.0900 time=12.5s vram=33817MB
# [timing] artifact_save epoch=17 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=18 seconds=12.47
# [timing] validation_eval epoch=18 seconds=1.01
# Epoch 018/150 loss=3.4128 val_paper_recall_curve_auc=0.8273 val_r@10=0.0876 time=12.5s vram=33817MB
# [timing] artifact_save epoch=18 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=19 seconds=12.47
# [timing] validation_eval epoch=19 seconds=1.01
# Epoch 019/150 loss=3.2633 val_paper_recall_curve_auc=0.8238 val_r@10=0.0877 time=12.5s vram=33817MB
# [timing] artifact_save epoch=19 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=20 seconds=12.76
# [timing] validation_eval epoch=20 seconds=1.06
# Epoch 020/150 loss=3.1302 val_paper_recall_curve_auc=0.8201 val_r@10=0.0863 time=12.8s vram=33817MB
# [timing] artifact_save epoch=20 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=21 seconds=12.30
# [timing] validation_eval epoch=21 seconds=0.99
# Epoch 021/150 loss=2.9951 val_paper_recall_curve_auc=0.8169 val_r@10=0.0833 time=12.3s vram=33817MB
# [timing] artifact_save epoch=21 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=22 seconds=12.62
# [timing] validation_eval epoch=22 seconds=1.07
# Epoch 022/150 loss=2.8477 val_paper_recall_curve_auc=0.8137 val_r@10=0.0817 time=12.6s vram=33817MB
# [timing] artifact_save epoch=22 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=23 seconds=12.81
# [timing] validation_eval epoch=23 seconds=1.04
# Epoch 023/150 loss=2.7090 val_paper_recall_curve_auc=0.8134 val_r@10=0.0799 time=12.8s vram=33817MB
# [timing] artifact_save epoch=23 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=24 seconds=12.52
# [timing] validation_eval epoch=24 seconds=1.04
# Epoch 024/150 loss=2.5785 val_paper_recall_curve_auc=0.8077 val_r@10=0.0770 time=12.5s vram=33817MB
# [timing] artifact_save epoch=24 artifact=last_checkpoint seconds=0.09
# [timing] train_epoch epoch=25 seconds=12.50
# [timing] validation_eval epoch=25 seconds=1.01
# Epoch 025/150 loss=2.4577 val_paper_recall_curve_auc=0.8074 val_r@10=0.0784 time=12.5s vram=33817MB
# [timing] artifact_save epoch=25 artifact=last_checkpoint seconds=0.09
# [timing] train_epoch epoch=26 seconds=12.51
# [timing] validation_eval epoch=26 seconds=1.04
# Epoch 026/150 loss=2.3369 val_paper_recall_curve_auc=0.8050 val_r@10=0.0786 time=12.5s vram=33817MB
# [timing] artifact_save epoch=26 artifact=last_checkpoint seconds=0.09
# [timing] train_epoch epoch=27 seconds=12.51
# [timing] validation_eval epoch=27 seconds=1.05
# Epoch 027/150 loss=2.2217 val_paper_recall_curve_auc=0.8032 val_r@10=0.0749 time=12.5s vram=33817MB
# [timing] artifact_save epoch=27 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=28 seconds=12.55
# [timing] validation_eval epoch=28 seconds=1.05
# Epoch 028/150 loss=2.1071 val_paper_recall_curve_auc=0.8020 val_r@10=0.0776 time=12.6s vram=33817MB
# [timing] artifact_save epoch=28 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=29 seconds=12.50
# [timing] validation_eval epoch=29 seconds=1.01
# Epoch 029/150 loss=2.0039 val_paper_recall_curve_auc=0.7989 val_r@10=0.0732 time=12.5s vram=33817MB
# [timing] artifact_save epoch=29 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=30 seconds=12.55
# [timing] validation_eval epoch=30 seconds=1.08
# Epoch 030/150 loss=1.9082 val_paper_recall_curve_auc=0.7987 val_r@10=0.0701 time=12.5s vram=33817MB
# [timing] artifact_save epoch=30 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=31 seconds=12.44
# [timing] validation_eval epoch=31 seconds=1.34
# Epoch 031/150 loss=1.8164 val_paper_recall_curve_auc=0.7955 val_r@10=0.0726 time=12.4s vram=33817MB
# [timing] artifact_save epoch=31 artifact=last_checkpoint seconds=0.09
# [timing] train_epoch epoch=32 seconds=12.48
# [timing] validation_eval epoch=32 seconds=1.03
# Epoch 032/150 loss=1.7166 val_paper_recall_curve_auc=0.7936 val_r@10=0.0709 time=12.5s vram=33817MB
# Early stopping after 25 validation checks.
# [timing] artifact_save epoch=32 artifact=last_checkpoint seconds=0.08
# [timing] final_eval split=val seconds=1.01
#
# VAL n=3,066 paper_recall_curve_auc=0.8497 r@1=0.0168 r@5=0.0556 r@10=0.0970 r@50=0.2570 MRR=0.0460 median_rank=206.5 random_r@10=0.0033
# [timing] final_eval split=test seconds=1.82
#
# TEST n=3,066 paper_recall_curve_auc=0.8499 r@1=0.0186 r@5=0.0607 r@10=0.0962 r@50=0.2585 MRR=0.0473 median_rank=206.5 random_r@10=0.0033
# [timing] artifact_save artifact=final_core_artifacts seconds=0.02
# [timing] artifact_save artifact=final_diagnostics_artifacts seconds=0.34
# [timing] total_branch seconds=465.66
#
# Artifacts saved to /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/01_pubmed/baseline_mixed_stage1a/stage3_normalized_specter
# Comparison row appended to runs/ale_model_comparison.csv
# Starting sequential Stage 3 run 2/6: mixed_to_pubmed_stage1b_on_pubmed_normalized_specter
# [Stage 3 mixed_to_pubmed_stage1b_on_pubmed_normalized_specter] $ /usr/bin/python3 -u experiments/3dcnn/atlas_free_cnn/training/train_ale_cnn.py --mode atlas_free --model ale_3dcnn --train-jsonl /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/train.jsonl --val-jsonl /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/val.jsonl --test-jsonl /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/test.jsonl --text-embedding-cache /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/text_embeddings/specter2_stage3_stage4_emptycentered_unitnorm.pt --domain pubmed --target-shape 36,45,38 --epochs 150 --early-stopping-patience 25 --val-interval 1 --batch-size 512 --base-channels 64 --num-blocks 4 --out-dim 384 --lr-cnn 0.0001 --lr-proj 0.00001 --weight-decay 0.0001 --warmup-epochs 5 --temperature 0.07 --dropout 0.1 --norm group --pooling max --encoder-init autoencoder_pretrained --ae-ckpt-path /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/retrieval_resource_ae_checkpoints/pubmed_finetuned_ae.pt --ae-init-variant mixed_to_pubmed_stage1b --ae-checkpoint-selection best_top1_dice --text-proj-init pretrained_infonce --monitor-metric paper_recall_curve_auc --strict-controlled-recipe --run-dir /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/01_pubmed/specialized_mixed_to_pubmed/stage3_normalized_specter --checkpoint-dir /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/01_pubmed/specialized_mixed_to_pubmed/stage3_normalized_specter/checkpoints
# AE encoder initialization:
# {
#   "encoder_init": "autoencoder_pretrained",
#   "ae_init_variant": "mixed_to_pubmed_stage1b",
#   "ae_checkpoint_selection": "custom_path",
#   "ae_checkpoint_path": "/content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/retrieval_resource_ae_checkpoints/pubmed_finetuned_ae.pt",
#   "ae_checkpoint_epoch": null,
#   "ae_source_wise_reconstruction_metrics": {},
#   "ae_validation_metrics": {}
# }
# Building ALE model ...
# [timing] data_cache_load seconds=3.30
# Selected device: cuda
#
# == ALE Dataset ==
#   mode=atlas_free cache=None
#   volume shape=(36, 45, 38) aligned papers=24,526
#   split train=24,526 val=3,066 test=3,066
#
# == Model ==
#   ale_3dcnn brain params=4,846,464
#   text params=590,720 train_text=True
#   device=cuda amp=True batch=512
# Contrastive objective: symmetric InfoNCE over projected ALE-brain and projected SPECTER-text embeddings (not reconstruction/MSE).
# text_proj trainable=True trainable_text_params=590,720
# [timing] preflight_batch_size seconds=0.00
#   selected batch_size=512
# First-batch contrastive sanity check:
#   projected_text shape=(512, 384) projected_brain shape=(512, 384)
#   similarity matrix = normalize(text_proj(SPECTER)) @ normalize(brain_encoder(ALE)).T
#   sim shape=(512, 512)
#   diagonal entries are true paired text-brain examples from the same dataset row
#   first paper_idx values=[20237, 5616, 15317, 9100, 6748] diag cosine mean=0.0066
# [timing] train_epoch epoch=0 seconds=14.33
# [timing] validation_eval epoch=0 seconds=1.92
# Epoch 000/150 loss=6.2337 val_paper_recall_curve_auc=0.7346 val_r@10=0.0298 time=14.3s vram=33796MB
# [timing] artifact_save epoch=0 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=1 seconds=13.08
# [timing] validation_eval epoch=1 seconds=1.10
# Epoch 001/150 loss=5.5794 val_paper_recall_curve_auc=0.8116 val_r@10=0.0566 time=13.1s vram=33817MB
# [timing] artifact_save epoch=1 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=2 seconds=13.38
# [timing] validation_eval epoch=2 seconds=1.10
# Epoch 002/150 loss=5.3125 val_paper_recall_curve_auc=0.8301 val_r@10=0.0744 time=13.4s vram=33817MB
# [timing] artifact_save epoch=2 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=3 seconds=12.91
# [timing] validation_eval epoch=3 seconds=1.06
# Epoch 003/150 loss=5.1758 val_paper_recall_curve_auc=0.8394 val_r@10=0.0825 time=12.9s vram=33817MB
# [timing] artifact_save epoch=3 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=4 seconds=12.56
# [timing] validation_eval epoch=4 seconds=1.02
# Epoch 004/150 loss=5.0801 val_paper_recall_curve_auc=0.8449 val_r@10=0.0872 time=12.6s vram=33817MB
# [timing] artifact_save epoch=4 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=5 seconds=12.31
# [timing] validation_eval epoch=5 seconds=1.04
# Epoch 005/150 loss=4.9792 val_paper_recall_curve_auc=0.8456 val_r@10=0.0923 time=12.3s vram=33817MB
# [timing] artifact_save epoch=5 artifact=last_checkpoint seconds=0.09
# [timing] train_epoch epoch=6 seconds=12.29
# [timing] validation_eval epoch=6 seconds=0.99
# Epoch 006/150 loss=4.8776 val_paper_recall_curve_auc=0.8487 val_r@10=0.0936 time=12.3s vram=33817MB
# [timing] artifact_save epoch=6 artifact=last_checkpoint seconds=0.09
# [timing] train_epoch epoch=7 seconds=12.27
# [timing] validation_eval epoch=7 seconds=1.00
# Epoch 007/150 loss=4.7865 val_paper_recall_curve_auc=0.8503 val_r@10=0.0938 time=12.3s vram=33817MB
# [timing] artifact_save epoch=7 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=8 seconds=12.27
# [timing] validation_eval epoch=8 seconds=0.98
# Epoch 008/150 loss=4.6842 val_paper_recall_curve_auc=0.8487 val_r@10=0.0969 time=12.3s vram=33817MB
# [timing] artifact_save epoch=8 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=9 seconds=12.29
# [timing] validation_eval epoch=9 seconds=1.00
# Epoch 009/150 loss=4.5710 val_paper_recall_curve_auc=0.8460 val_r@10=0.0975 time=12.3s vram=33817MB
# [timing] artifact_save epoch=9 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=10 seconds=12.28
# [timing] validation_eval epoch=10 seconds=1.00
# Epoch 010/150 loss=4.4557 val_paper_recall_curve_auc=0.8468 val_r@10=0.0965 time=12.3s vram=33817MB
# [timing] artifact_save epoch=10 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=11 seconds=12.64
# [timing] validation_eval epoch=11 seconds=1.05
# Epoch 011/150 loss=4.3379 val_paper_recall_curve_auc=0.8459 val_r@10=0.0967 time=12.6s vram=33817MB
# [timing] artifact_save epoch=11 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=12 seconds=12.70
# [timing] validation_eval epoch=12 seconds=1.05
# Epoch 012/150 loss=4.2103 val_paper_recall_curve_auc=0.8441 val_r@10=0.0964 time=12.7s vram=33817MB
# [timing] artifact_save epoch=12 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=13 seconds=12.69
# [timing] validation_eval epoch=13 seconds=1.06
# Epoch 013/150 loss=4.0710 val_paper_recall_curve_auc=0.8418 val_r@10=0.0928 time=12.7s vram=33817MB
# [timing] artifact_save epoch=13 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=14 seconds=12.62
# [timing] validation_eval epoch=14 seconds=0.98
# Epoch 014/150 loss=3.9264 val_paper_recall_curve_auc=0.8380 val_r@10=0.0943 time=12.6s vram=33817MB
# [timing] artifact_save epoch=14 artifact=last_checkpoint seconds=0.09
# [timing] train_epoch epoch=15 seconds=12.60
# [timing] validation_eval epoch=15 seconds=1.06
# Epoch 015/150 loss=3.7894 val_paper_recall_curve_auc=0.8338 val_r@10=0.0925 time=12.6s vram=33817MB
# [timing] artifact_save epoch=15 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=16 seconds=12.51
# [timing] validation_eval epoch=16 seconds=1.01
# Epoch 016/150 loss=3.6462 val_paper_recall_curve_auc=0.8287 val_r@10=0.0881 time=12.5s vram=33817MB
# [timing] artifact_save epoch=16 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=17 seconds=12.69
# [timing] validation_eval epoch=17 seconds=1.04
# Epoch 017/150 loss=3.5049 val_paper_recall_curve_auc=0.8281 val_r@10=0.0908 time=12.7s vram=33817MB
# [timing] artifact_save epoch=17 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=18 seconds=12.49
# [timing] validation_eval epoch=18 seconds=1.04
# Epoch 018/150 loss=3.3721 val_paper_recall_curve_auc=0.8250 val_r@10=0.0872 time=12.5s vram=33817MB
# [timing] artifact_save epoch=18 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=19 seconds=12.50
# [timing] validation_eval epoch=19 seconds=1.04
# Epoch 019/150 loss=3.2230 val_paper_recall_curve_auc=0.8226 val_r@10=0.0861 time=12.5s vram=33817MB
# [timing] artifact_save epoch=19 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=20 seconds=12.49
# [timing] validation_eval epoch=20 seconds=1.01
# Epoch 020/150 loss=3.0918 val_paper_recall_curve_auc=0.8178 val_r@10=0.0848 time=12.5s vram=33817MB
# [timing] artifact_save epoch=20 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=21 seconds=12.51
# [timing] validation_eval epoch=21 seconds=1.14
# Epoch 021/150 loss=2.9505 val_paper_recall_curve_auc=0.8145 val_r@10=0.0843 time=12.5s vram=33817MB
# [timing] artifact_save epoch=21 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=22 seconds=13.18
# [timing] validation_eval epoch=22 seconds=1.11
# Epoch 022/150 loss=2.8086 val_paper_recall_curve_auc=0.8132 val_r@10=0.0820 time=13.2s vram=33817MB
# [timing] artifact_save epoch=22 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=23 seconds=13.16
# [timing] validation_eval epoch=23 seconds=1.11
# Epoch 023/150 loss=2.6670 val_paper_recall_curve_auc=0.8102 val_r@10=0.0811 time=13.2s vram=33817MB
# [timing] artifact_save epoch=23 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=24 seconds=13.07
# [timing] validation_eval epoch=24 seconds=1.06
# Epoch 024/150 loss=2.5417 val_paper_recall_curve_auc=0.8058 val_r@10=0.0765 time=13.1s vram=33817MB
# [timing] artifact_save epoch=24 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=25 seconds=13.10
# [timing] validation_eval epoch=25 seconds=1.07
# Epoch 025/150 loss=2.4183 val_paper_recall_curve_auc=0.8057 val_r@10=0.0781 time=13.1s vram=33817MB
# [timing] artifact_save epoch=25 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=26 seconds=12.92
# [timing] validation_eval epoch=26 seconds=1.07
# Epoch 026/150 loss=2.2975 val_paper_recall_curve_auc=0.8021 val_r@10=0.0771 time=12.9s vram=33817MB
# [timing] artifact_save epoch=26 artifact=last_checkpoint seconds=0.09
# [timing] train_epoch epoch=27 seconds=12.99
# [timing] validation_eval epoch=27 seconds=1.07
# Epoch 027/150 loss=2.1790 val_paper_recall_curve_auc=0.8007 val_r@10=0.0752 time=13.0s vram=33817MB
# [timing] artifact_save epoch=27 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=28 seconds=13.00
# [timing] validation_eval epoch=28 seconds=1.08
# Epoch 028/150 loss=2.0667 val_paper_recall_curve_auc=0.8006 val_r@10=0.0781 time=13.0s vram=33817MB
# [timing] artifact_save epoch=28 artifact=last_checkpoint seconds=0.09
# [timing] train_epoch epoch=29 seconds=12.51
# [timing] validation_eval epoch=29 seconds=1.01
# Epoch 029/150 loss=1.9762 val_paper_recall_curve_auc=0.7966 val_r@10=0.0740 time=12.5s vram=33817MB
# [timing] artifact_save epoch=29 artifact=last_checkpoint seconds=0.09
# [timing] train_epoch epoch=30 seconds=12.50
# [timing] validation_eval epoch=30 seconds=1.03
# Epoch 030/150 loss=1.8703 val_paper_recall_curve_auc=0.7972 val_r@10=0.0739 time=12.5s vram=33817MB
# [timing] artifact_save epoch=30 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=31 seconds=12.68
# [timing] validation_eval epoch=31 seconds=1.08
# Epoch 031/150 loss=1.7852 val_paper_recall_curve_auc=0.7934 val_r@10=0.0716 time=12.7s vram=33817MB
# [timing] artifact_save epoch=31 artifact=last_checkpoint seconds=0.09
# [timing] train_epoch epoch=32 seconds=12.76
# [timing] validation_eval epoch=32 seconds=1.01
# Epoch 032/150 loss=1.6883 val_paper_recall_curve_auc=0.7911 val_r@10=0.0709 time=12.8s vram=33817MB
# Early stopping after 25 validation checks.
# [timing] artifact_save epoch=32 artifact=last_checkpoint seconds=0.09
# [timing] final_eval split=val seconds=1.03
#
# VAL n=3,066 paper_recall_curve_auc=0.8503 r@1=0.0171 r@5=0.0548 r@10=0.0938 r@50=0.2601 MRR=0.0458 median_rank=206.0 random_r@10=0.0033
# [timing] final_eval split=test seconds=1.83
#
# TEST n=3,066 paper_recall_curve_auc=0.8498 r@1=0.0191 r@5=0.0592 r@10=0.0969 r@50=0.2578 MRR=0.0480 median_rank=204.5 random_r@10=0.0033
# [timing] artifact_save artifact=final_core_artifacts seconds=0.21
# [timing] artifact_save artifact=final_diagnostics_artifacts seconds=0.36
# [timing] total_branch seconds=466.14
#
# Artifacts saved to /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/01_pubmed/specialized_mixed_to_pubmed/stage3_normalized_specter
# Comparison row appended to runs/ale_model_comparison.csv
# Starting sequential Stage 3 run 3/6: mixed_stage1a_on_nilearn_normalized_specter
# [Stage 3 mixed_stage1a_on_nilearn_normalized_specter] $ /usr/bin/python3 -u experiments/3dcnn/atlas_free_cnn/training/train_ale_cnn.py --mode atlas_free --model ale_3dcnn --train-jsonl /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/train.jsonl --val-jsonl /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/val.jsonl --test-jsonl /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/test.jsonl --text-embedding-cache /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/text_embeddings/specter2_stage3_stage4_emptycentered_unitnorm.pt --domain nilearn --target-shape 36,45,38 --epochs 150 --early-stopping-patience 25 --val-interval 1 --batch-size 512 --base-channels 64 --num-blocks 4 --out-dim 384 --lr-cnn 0.0001 --lr-proj 0.00001 --weight-decay 0.0001 --warmup-epochs 5 --temperature 0.07 --dropout 0.1 --norm group --pooling max --encoder-init autoencoder_pretrained --ae-ckpt-path /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/retrieval_resource_ae_checkpoints/mixed_ae.pt --ae-init-variant mixed_stage1a --ae-checkpoint-selection best_top1_dice --text-proj-init pretrained_infonce --monitor-metric paper_recall_curve_auc --strict-controlled-recipe --run-dir /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/02_nilearn/baseline_mixed_stage1a/stage3_normalized_specter --checkpoint-dir /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/02_nilearn/baseline_mixed_stage1a/stage3_normalized_specter/checkpoints
# AE encoder initialization:
# {
#   "encoder_init": "autoencoder_pretrained",
#   "ae_init_variant": "mixed_stage1a",
#   "ae_checkpoint_selection": "custom_path",
#   "ae_checkpoint_path": "/content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/retrieval_resource_ae_checkpoints/mixed_ae.pt",
#   "ae_checkpoint_epoch": null,
#   "ae_source_wise_reconstruction_metrics": {},
#   "ae_validation_metrics": {}
# }
# Building ALE model ...
# [timing] data_cache_load seconds=3.13
# Selected device: cuda
#
# == ALE Dataset ==
#   mode=atlas_free cache=None
#   volume shape=(36, 45, 38) aligned papers=639
#   split train=639 val=79 test=79
#
# == Model ==
#   ale_3dcnn brain params=4,846,464
#   text params=590,720 train_text=True
#   device=cuda amp=True batch=512
# Contrastive objective: symmetric InfoNCE over projected ALE-brain and projected SPECTER-text embeddings (not reconstruction/MSE).
# text_proj trainable=True trainable_text_params=590,720
# [timing] preflight_batch_size seconds=0.00
#   selected batch_size=512
# First-batch contrastive sanity check:
#   projected_text shape=(512, 384) projected_brain shape=(512, 384)
#   similarity matrix = normalize(text_proj(SPECTER)) @ normalize(brain_encoder(ALE)).T
#   sim shape=(512, 512)
#   diagonal entries are true paired text-brain examples from the same dataset row
#   first paper_idx values=[638, 28, 478, 180, 468] diag cosine mean=-0.0115
# [timing] train_epoch epoch=0 seconds=1.47
# [timing] validation_eval epoch=0 seconds=0.83
# Epoch 000/150 loss=5.7031 val_paper_recall_curve_auc=0.5146 val_r@10=0.1519 time=1.5s vram=33754MB
# [timing] artifact_save epoch=0 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=1 seconds=0.34
# [timing] validation_eval epoch=1 seconds=0.02
# Epoch 001/150 loss=5.6250 val_paper_recall_curve_auc=0.5679 val_r@10=0.1646 time=0.3s vram=33817MB
# [timing] artifact_save epoch=1 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=2 seconds=0.34
# [timing] validation_eval epoch=2 seconds=0.02
# Epoch 002/150 loss=5.5000 val_paper_recall_curve_auc=0.6563 val_r@10=0.2405 time=0.3s vram=33817MB
# [timing] artifact_save epoch=2 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=3 seconds=0.35
# [timing] validation_eval epoch=3 seconds=0.02
# Epoch 003/150 loss=5.2969 val_paper_recall_curve_auc=0.7353 val_r@10=0.3418 time=0.3s vram=33817MB
# [timing] artifact_save epoch=3 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=4 seconds=0.35
# [timing] validation_eval epoch=4 seconds=0.02
# Epoch 004/150 loss=5.0938 val_paper_recall_curve_auc=0.7871 val_r@10=0.4810 time=0.3s vram=33817MB
# [timing] artifact_save epoch=4 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=5 seconds=0.34
# [timing] validation_eval epoch=5 seconds=0.02
# Epoch 005/150 loss=4.8438 val_paper_recall_curve_auc=0.8233 val_r@10=0.5633 time=0.3s vram=33817MB
# [timing] artifact_save epoch=5 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=6 seconds=0.34
# [timing] validation_eval epoch=6 seconds=0.02
# Epoch 006/150 loss=4.7031 val_paper_recall_curve_auc=0.8425 val_r@10=0.5696 time=0.3s vram=33817MB
# [timing] artifact_save epoch=6 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=7 seconds=0.34
# [timing] validation_eval epoch=7 seconds=0.02
# Epoch 007/150 loss=4.5156 val_paper_recall_curve_auc=0.8563 val_r@10=0.5949 time=0.3s vram=33817MB
# [timing] artifact_save epoch=7 artifact=last_checkpoint seconds=0.48
# [timing] train_epoch epoch=8 seconds=0.34
# [timing] validation_eval epoch=8 seconds=0.02
# Epoch 008/150 loss=4.4375 val_paper_recall_curve_auc=0.8680 val_r@10=0.6266 time=0.3s vram=33817MB
# [timing] artifact_save epoch=8 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=9 seconds=0.34
# [timing] validation_eval epoch=9 seconds=0.02
# Epoch 009/150 loss=4.2812 val_paper_recall_curve_auc=0.8818 val_r@10=0.6582 time=0.3s vram=33817MB
# [timing] artifact_save epoch=9 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=10 seconds=0.34
# [timing] validation_eval epoch=10 seconds=0.02
# Epoch 010/150 loss=4.1406 val_paper_recall_curve_auc=0.8910 val_r@10=0.6962 time=0.3s vram=33817MB
# [timing] artifact_save epoch=10 artifact=last_checkpoint seconds=0.51
# [timing] train_epoch epoch=11 seconds=0.34
# [timing] validation_eval epoch=11 seconds=0.02
# Epoch 011/150 loss=4.0938 val_paper_recall_curve_auc=0.8959 val_r@10=0.7278 time=0.3s vram=33817MB
# [timing] artifact_save epoch=11 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=12 seconds=0.34
# [timing] validation_eval epoch=12 seconds=0.02
# Epoch 012/150 loss=3.9766 val_paper_recall_curve_auc=0.9020 val_r@10=0.7468 time=0.3s vram=33817MB
# [timing] artifact_save epoch=12 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=13 seconds=0.34
# [timing] validation_eval epoch=13 seconds=0.02
# Epoch 013/150 loss=3.9297 val_paper_recall_curve_auc=0.9051 val_r@10=0.7405 time=0.3s vram=33817MB
# [timing] artifact_save epoch=13 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=14 seconds=0.34
# [timing] validation_eval epoch=14 seconds=0.02
# Epoch 014/150 loss=3.8203 val_paper_recall_curve_auc=0.9083 val_r@10=0.7532 time=0.3s vram=33817MB
# [timing] artifact_save epoch=14 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=15 seconds=0.34
# [timing] validation_eval epoch=15 seconds=0.02
# Epoch 015/150 loss=3.7734 val_paper_recall_curve_auc=0.9116 val_r@10=0.7532 time=0.3s vram=33817MB
# [timing] artifact_save epoch=15 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=16 seconds=0.34
# [timing] validation_eval epoch=16 seconds=0.02
# Epoch 016/150 loss=3.6719 val_paper_recall_curve_auc=0.9135 val_r@10=0.7595 time=0.3s vram=33817MB
# [timing] artifact_save epoch=16 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=17 seconds=0.34
# [timing] validation_eval epoch=17 seconds=0.02
# Epoch 017/150 loss=3.6094 val_paper_recall_curve_auc=0.9154 val_r@10=0.7848 time=0.3s vram=33817MB
# [timing] artifact_save epoch=17 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=18 seconds=0.33
# [timing] validation_eval epoch=18 seconds=0.02
# Epoch 018/150 loss=3.5938 val_paper_recall_curve_auc=0.9158 val_r@10=0.7911 time=0.3s vram=33817MB
# [timing] artifact_save epoch=18 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=19 seconds=0.33
# [timing] validation_eval epoch=19 seconds=0.02
# Epoch 019/150 loss=3.5156 val_paper_recall_curve_auc=0.9174 val_r@10=0.7975 time=0.3s vram=33817MB
# [timing] artifact_save epoch=19 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=20 seconds=0.33
# [timing] validation_eval epoch=20 seconds=0.02
# Epoch 020/150 loss=3.4844 val_paper_recall_curve_auc=0.9193 val_r@10=0.7911 time=0.3s vram=33817MB
# [timing] artifact_save epoch=20 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=21 seconds=0.34
# [timing] validation_eval epoch=21 seconds=0.02
# Epoch 021/150 loss=3.4062 val_paper_recall_curve_auc=0.9194 val_r@10=0.7911 time=0.3s vram=33817MB
# [timing] artifact_save epoch=21 artifact=last_checkpoint seconds=0.29
# [timing] train_epoch epoch=22 seconds=0.33
# [timing] validation_eval epoch=22 seconds=0.02
# Epoch 022/150 loss=3.3438 val_paper_recall_curve_auc=0.9204 val_r@10=0.7848 time=0.3s vram=33817MB
# [timing] artifact_save epoch=22 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=23 seconds=0.34
# [timing] validation_eval epoch=23 seconds=0.02
# Epoch 023/150 loss=3.2656 val_paper_recall_curve_auc=0.9215 val_r@10=0.7848 time=0.3s vram=33817MB
# [timing] artifact_save epoch=23 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=24 seconds=0.34
# [timing] validation_eval epoch=24 seconds=0.02
# Epoch 024/150 loss=3.2344 val_paper_recall_curve_auc=0.9224 val_r@10=0.7975 time=0.3s vram=33817MB
# [timing] artifact_save epoch=24 artifact=last_checkpoint seconds=0.78
# [timing] train_epoch epoch=25 seconds=0.34
# [timing] validation_eval epoch=25 seconds=0.02
# Epoch 025/150 loss=3.1250 val_paper_recall_curve_auc=0.9228 val_r@10=0.7911 time=0.3s vram=33817MB
# [timing] artifact_save epoch=25 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=26 seconds=0.34
# [timing] validation_eval epoch=26 seconds=0.02
# Epoch 026/150 loss=3.0625 val_paper_recall_curve_auc=0.9230 val_r@10=0.7911 time=0.3s vram=33817MB
# [timing] artifact_save epoch=26 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=27 seconds=0.34
# [timing] validation_eval epoch=27 seconds=0.02
# Epoch 027/150 loss=3.0547 val_paper_recall_curve_auc=0.9243 val_r@10=0.7911 time=0.3s vram=33817MB
# [timing] artifact_save epoch=27 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=28 seconds=0.34
# [timing] validation_eval epoch=28 seconds=0.02
# Epoch 028/150 loss=2.9844 val_paper_recall_curve_auc=0.9236 val_r@10=0.7785 time=0.3s vram=33817MB
# [timing] artifact_save epoch=28 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=29 seconds=0.33
# [timing] validation_eval epoch=29 seconds=0.02
# Epoch 029/150 loss=2.9688 val_paper_recall_curve_auc=0.9252 val_r@10=0.7848 time=0.3s vram=33817MB
# [timing] artifact_save epoch=29 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=30 seconds=0.34
# [timing] validation_eval epoch=30 seconds=0.02
# Epoch 030/150 loss=2.8750 val_paper_recall_curve_auc=0.9265 val_r@10=0.8038 time=0.3s vram=33817MB
# [timing] artifact_save epoch=30 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=31 seconds=0.34
# [timing] validation_eval epoch=31 seconds=0.02
# Epoch 031/150 loss=2.8047 val_paper_recall_curve_auc=0.9273 val_r@10=0.8291 time=0.3s vram=33817MB
# [timing] artifact_save epoch=31 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=32 seconds=0.34
# [timing] validation_eval epoch=32 seconds=0.02
# Epoch 032/150 loss=2.7812 val_paper_recall_curve_auc=0.9265 val_r@10=0.8038 time=0.3s vram=33817MB
# [timing] artifact_save epoch=32 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=33 seconds=0.33
# [timing] validation_eval epoch=33 seconds=0.02
# Epoch 033/150 loss=2.7656 val_paper_recall_curve_auc=0.9261 val_r@10=0.8101 time=0.3s vram=33817MB
# [timing] artifact_save epoch=33 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=34 seconds=0.33
# [timing] validation_eval epoch=34 seconds=0.02
# Epoch 034/150 loss=2.6875 val_paper_recall_curve_auc=0.9240 val_r@10=0.8101 time=0.3s vram=33817MB
# [timing] artifact_save epoch=34 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=35 seconds=0.33
# [timing] validation_eval epoch=35 seconds=0.02
# Epoch 035/150 loss=2.6875 val_paper_recall_curve_auc=0.9218 val_r@10=0.7848 time=0.3s vram=33817MB
# [timing] artifact_save epoch=35 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=36 seconds=0.33
# [timing] validation_eval epoch=36 seconds=0.02
# Epoch 036/150 loss=2.6016 val_paper_recall_curve_auc=0.9234 val_r@10=0.8101 time=0.3s vram=33817MB
# [timing] artifact_save epoch=36 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=37 seconds=0.33
# [timing] validation_eval epoch=37 seconds=0.02
# Epoch 037/150 loss=2.5859 val_paper_recall_curve_auc=0.9226 val_r@10=0.7975 time=0.3s vram=33817MB
# [timing] artifact_save epoch=37 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=38 seconds=0.33
# [timing] validation_eval epoch=38 seconds=0.02
# Epoch 038/150 loss=2.5469 val_paper_recall_curve_auc=0.9234 val_r@10=0.7975 time=0.3s vram=33817MB
# [timing] artifact_save epoch=38 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=39 seconds=0.33
# [timing] validation_eval epoch=39 seconds=0.02
# Epoch 039/150 loss=2.5039 val_paper_recall_curve_auc=0.9230 val_r@10=0.7975 time=0.3s vram=33817MB
# [timing] artifact_save epoch=39 artifact=last_checkpoint seconds=1.04
# [timing] train_epoch epoch=40 seconds=0.33
# [timing] validation_eval epoch=40 seconds=0.02
# Epoch 040/150 loss=2.4180 val_paper_recall_curve_auc=0.9219 val_r@10=0.7911 time=0.3s vram=33817MB
# [timing] artifact_save epoch=40 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=41 seconds=0.34
# [timing] validation_eval epoch=41 seconds=0.02
# Epoch 041/150 loss=2.4453 val_paper_recall_curve_auc=0.9202 val_r@10=0.7848 time=0.3s vram=33817MB
# [timing] artifact_save epoch=41 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=42 seconds=0.34
# [timing] validation_eval epoch=42 seconds=0.02
# Epoch 042/150 loss=2.3633 val_paper_recall_curve_auc=0.9187 val_r@10=0.7785 time=0.3s vram=33817MB
# [timing] artifact_save epoch=42 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=43 seconds=0.34
# [timing] validation_eval epoch=43 seconds=0.02
# Epoch 043/150 loss=2.3516 val_paper_recall_curve_auc=0.9178 val_r@10=0.7722 time=0.3s vram=33817MB
# [timing] artifact_save epoch=43 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=44 seconds=0.34
# [timing] validation_eval epoch=44 seconds=0.02
# Epoch 044/150 loss=2.3047 val_paper_recall_curve_auc=0.9176 val_r@10=0.7722 time=0.3s vram=33817MB
# [timing] artifact_save epoch=44 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=45 seconds=0.34
# [timing] validation_eval epoch=45 seconds=0.02
# Epoch 045/150 loss=2.3125 val_paper_recall_curve_auc=0.9146 val_r@10=0.7722 time=0.3s vram=33817MB
# [timing] artifact_save epoch=45 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=46 seconds=0.34
# [timing] validation_eval epoch=46 seconds=0.02
# Epoch 046/150 loss=2.1953 val_paper_recall_curve_auc=0.9135 val_r@10=0.7658 time=0.3s vram=33817MB
# [timing] artifact_save epoch=46 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=47 seconds=0.34
# [timing] validation_eval epoch=47 seconds=0.02
# Epoch 047/150 loss=2.1680 val_paper_recall_curve_auc=0.9130 val_r@10=0.7658 time=0.3s vram=33817MB
# [timing] artifact_save epoch=47 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=48 seconds=0.34
# [timing] validation_eval epoch=48 seconds=0.02
# Epoch 048/150 loss=2.1602 val_paper_recall_curve_auc=0.9123 val_r@10=0.7468 time=0.3s vram=33817MB
# [timing] artifact_save epoch=48 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=49 seconds=0.34
# [timing] validation_eval epoch=49 seconds=0.02
# Epoch 049/150 loss=2.1484 val_paper_recall_curve_auc=0.9102 val_r@10=0.7658 time=0.3s vram=33817MB
# [timing] artifact_save epoch=49 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=50 seconds=0.34
# [timing] validation_eval epoch=50 seconds=0.02
# Epoch 050/150 loss=2.1562 val_paper_recall_curve_auc=0.9091 val_r@10=0.7722 time=0.3s vram=33817MB
# [timing] artifact_save epoch=50 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=51 seconds=0.34
# [timing] validation_eval epoch=51 seconds=0.02
# Epoch 051/150 loss=2.0859 val_paper_recall_curve_auc=0.9097 val_r@10=0.7595 time=0.3s vram=33817MB
# [timing] artifact_save epoch=51 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=52 seconds=0.34
# [timing] validation_eval epoch=52 seconds=0.02
# Epoch 052/150 loss=2.0469 val_paper_recall_curve_auc=0.9091 val_r@10=0.7658 time=0.3s vram=33817MB
# [timing] artifact_save epoch=52 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=53 seconds=0.33
# [timing] validation_eval epoch=53 seconds=0.02
# Epoch 053/150 loss=2.0078 val_paper_recall_curve_auc=0.9091 val_r@10=0.7595 time=0.3s vram=33817MB
# [timing] artifact_save epoch=53 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=54 seconds=0.34
# [timing] validation_eval epoch=54 seconds=0.02
# Epoch 054/150 loss=1.9805 val_paper_recall_curve_auc=0.9086 val_r@10=0.7595 time=0.3s vram=33817MB
# [timing] artifact_save epoch=54 artifact=last_checkpoint seconds=2.71
# [timing] train_epoch epoch=55 seconds=0.34
# [timing] validation_eval epoch=55 seconds=0.02
# Epoch 055/150 loss=1.9531 val_paper_recall_curve_auc=0.9059 val_r@10=0.7532 time=0.3s vram=33817MB
# [timing] artifact_save epoch=55 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=56 seconds=0.34
# [timing] validation_eval epoch=56 seconds=0.02
# Epoch 056/150 loss=1.9453 val_paper_recall_curve_auc=0.9048 val_r@10=0.7595 time=0.3s vram=33817MB
# Early stopping after 25 validation checks.
# [timing] artifact_save epoch=56 artifact=last_checkpoint seconds=0.07
# [timing] final_eval split=val seconds=0.02
#
# VAL n=79 paper_recall_curve_auc=0.9273 r@1=0.2342 r@5=0.6962 r@10=0.8291 r@50=1.0000 MRR=0.4283 median_rank=3.0 random_r@10=0.1266
# [timing] final_eval split=test seconds=0.84
#
# TEST n=79 paper_recall_curve_auc=0.9062 r@1=0.2215 r@5=0.5506 r@10=0.7532 r@50=0.9873 MRR=0.3751 median_rank=4.5 random_r@10=0.1266
# [timing] artifact_save artifact=final_core_artifacts seconds=0.21
# [timing] artifact_save artifact=final_diagnostics_artifacts seconds=0.02
# [timing] total_branch seconds=38.34
#
# Artifacts saved to /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/02_nilearn/baseline_mixed_stage1a/stage3_normalized_specter
# Comparison row appended to runs/ale_model_comparison.csv
# Starting sequential Stage 3 run 4/6: mixed_to_nilearn_stage1b_on_nilearn_normalized_specter
# [Stage 3 mixed_to_nilearn_stage1b_on_nilearn_normalized_specter] $ /usr/bin/python3 -u experiments/3dcnn/atlas_free_cnn/training/train_ale_cnn.py --mode atlas_free --model ale_3dcnn --train-jsonl /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/train.jsonl --val-jsonl /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/val.jsonl --test-jsonl /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/unified_jsonl_rebuild/splits/test.jsonl --text-embedding-cache /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/text_embeddings/specter2_stage3_stage4_emptycentered_unitnorm.pt --domain nilearn --target-shape 36,45,38 --epochs 150 --early-stopping-patience 25 --val-interval 1 --batch-size 512 --base-channels 64 --num-blocks 4 --out-dim 384 --lr-cnn 0.0001 --lr-proj 0.00001 --weight-decay 0.0001 --warmup-epochs 5 --temperature 0.07 --dropout 0.1 --norm group --pooling max --encoder-init autoencoder_pretrained --ae-ckpt-path /content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/retrieval_resource_ae_checkpoints/nilearn_finetuned_ae.pt --ae-init-variant mixed_to_nilearn_stage1b --ae-checkpoint-selection best_val_loss --text-proj-init pretrained_infonce --monitor-metric paper_recall_curve_auc --strict-controlled-recipe --run-dir /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/02_nilearn/specialized_mixed_to_nilearn/stage3_normalized_specter --checkpoint-dir /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/02_nilearn/specialized_mixed_to_nilearn/stage3_normalized_specter/checkpoints
# AE encoder initialization:
# {
#   "encoder_init": "autoencoder_pretrained",
#   "ae_init_variant": "mixed_to_nilearn_stage1b",
#   "ae_checkpoint_selection": "custom_path",
#   "ae_checkpoint_path": "/content/neurovlm_gnn/experiments/3dcnn/atlas_free_cnn/cache/retrieval_resource_ae_checkpoints/nilearn_finetuned_ae.pt",
#   "ae_checkpoint_epoch": null,
#   "ae_source_wise_reconstruction_metrics": {},
#   "ae_validation_metrics": {}
# }
# Building ALE model ...
# [timing] data_cache_load seconds=2.67
# Selected device: cuda
#
# == ALE Dataset ==
#   mode=atlas_free cache=None
#   volume shape=(36, 45, 38) aligned papers=639
#   split train=639 val=79 test=79
#
# == Model ==
#   ale_3dcnn brain params=4,846,464
#   text params=590,720 train_text=True
#   device=cuda amp=True batch=512
# Contrastive objective: symmetric InfoNCE over projected ALE-brain and projected SPECTER-text embeddings (not reconstruction/MSE).
# text_proj trainable=True trainable_text_params=590,720
# [timing] preflight_batch_size seconds=0.00
#   selected batch_size=512
# First-batch contrastive sanity check:
#   projected_text shape=(512, 384) projected_brain shape=(512, 384)
#   similarity matrix = normalize(text_proj(SPECTER)) @ normalize(brain_encoder(ALE)).T
#   sim shape=(512, 512)
#   diagonal entries are true paired text-brain examples from the same dataset row
#   first paper_idx values=[638, 28, 478, 180, 468] diag cosine mean=-0.0092
# [timing] train_epoch epoch=0 seconds=1.48
# [timing] validation_eval epoch=0 seconds=0.84
# Epoch 000/150 loss=5.7031 val_paper_recall_curve_auc=0.5139 val_r@10=0.1519 time=1.5s vram=33754MB
# [timing] artifact_save epoch=0 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=1 seconds=0.34
# [timing] validation_eval epoch=1 seconds=0.02
# Epoch 001/150 loss=5.6250 val_paper_recall_curve_auc=0.5693 val_r@10=0.1835 time=0.3s vram=33817MB
# [timing] artifact_save epoch=1 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=2 seconds=0.34
# [timing] validation_eval epoch=2 seconds=0.02
# Epoch 002/150 loss=5.4844 val_paper_recall_curve_auc=0.6567 val_r@10=0.2278 time=0.3s vram=33817MB
# [timing] artifact_save epoch=2 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=3 seconds=0.34
# [timing] validation_eval epoch=3 seconds=0.02
# Epoch 003/150 loss=5.2969 val_paper_recall_curve_auc=0.7391 val_r@10=0.3671 time=0.3s vram=33817MB
# [timing] artifact_save epoch=3 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=4 seconds=0.34
# [timing] validation_eval epoch=4 seconds=0.02
# Epoch 004/150 loss=5.0625 val_paper_recall_curve_auc=0.7923 val_r@10=0.4937 time=0.3s vram=33817MB
# ...
# Epoch 047/150 loss=1.7129 val_paper_recall_curve_auc=0.8708 val_r@10=0.5928 time=0.9s vram=33817MB
# [timing] artifact_save epoch=47 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=48 seconds=0.93
# [timing] validation_eval epoch=48 seconds=0.06
# Epoch 048/150 loss=1.6758 val_paper_recall_curve_auc=0.8712 val_r@10=0.6063 time=0.9s vram=33817MB
# [timing] artifact_save epoch=48 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=49 seconds=0.91
# [timing] validation_eval epoch=49 seconds=0.06
# Epoch 049/150 loss=1.6309 val_paper_recall_curve_auc=0.8666 val_r@10=0.6063 time=0.9s vram=33817MB
# [timing] artifact_save epoch=49 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=50 seconds=0.93
# [timing] validation_eval epoch=50 seconds=0.06
# Epoch 050/150 loss=1.5957 val_paper_recall_curve_auc=0.8696 val_r@10=0.5995 time=0.9s vram=33817MB
# [timing] artifact_save epoch=50 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=51 seconds=0.93
# [timing] validation_eval epoch=51 seconds=0.06
# Epoch 051/150 loss=1.5723 val_paper_recall_curve_auc=0.8706 val_r@10=0.6063 time=0.9s vram=33817MB
# [timing] artifact_save epoch=51 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=52 seconds=0.93
# [timing] validation_eval epoch=52 seconds=0.06
# Epoch 052/150 loss=1.5352 val_paper_recall_curve_auc=0.8715 val_r@10=0.6086 time=0.9s vram=33817MB
# [timing] artifact_save epoch=52 artifact=last_checkpoint seconds=0.27
# [timing] train_epoch epoch=53 seconds=0.93
# [timing] validation_eval epoch=53 seconds=0.06
# Epoch 053/150 loss=1.4922 val_paper_recall_curve_auc=0.8715 val_r@10=0.6131 time=0.9s vram=33817MB
# [timing] artifact_save epoch=53 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=54 seconds=0.94
# [timing] validation_eval epoch=54 seconds=0.07
# Epoch 054/150 loss=1.4863 val_paper_recall_curve_auc=0.8697 val_r@10=0.6041 time=0.9s vram=33817MB
# [timing] artifact_save epoch=54 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=55 seconds=0.93
# [timing] validation_eval epoch=55 seconds=0.07
# Epoch 055/150 loss=1.4336 val_paper_recall_curve_auc=0.8722 val_r@10=0.6131 time=0.9s vram=33817MB
# [timing] artifact_save epoch=55 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=56 seconds=0.92
# [timing] validation_eval epoch=56 seconds=0.07
# Epoch 056/150 loss=1.4219 val_paper_recall_curve_auc=0.8691 val_r@10=0.6109 time=0.9s vram=33817MB
# [timing] artifact_save epoch=56 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=57 seconds=0.91
# [timing] validation_eval epoch=57 seconds=0.07
# Epoch 057/150 loss=1.3828 val_paper_recall_curve_auc=0.8708 val_r@10=0.6018 time=0.9s vram=33817MB
# [timing] artifact_save epoch=57 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=58 seconds=0.94
# [timing] validation_eval epoch=58 seconds=0.07
# Epoch 058/150 loss=1.3672 val_paper_recall_curve_auc=0.8721 val_r@10=0.5995 time=0.9s vram=33817MB
# [timing] artifact_save epoch=58 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=59 seconds=0.93
# [timing] validation_eval epoch=59 seconds=0.07
# Epoch 059/150 loss=1.3398 val_paper_recall_curve_auc=0.8724 val_r@10=0.6041 time=0.9s vram=33817MB
# [timing] artifact_save epoch=59 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=60 seconds=0.93
# [timing] validation_eval epoch=60 seconds=0.07
# Epoch 060/150 loss=1.3398 val_paper_recall_curve_auc=0.8714 val_r@10=0.6041 time=0.9s vram=33817MB
# [timing] artifact_save epoch=60 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=61 seconds=0.91
# [timing] validation_eval epoch=61 seconds=0.06
# Epoch 061/150 loss=1.2998 val_paper_recall_curve_auc=0.8729 val_r@10=0.6063 time=0.9s vram=33817MB
# [timing] artifact_save epoch=61 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=62 seconds=0.89
# [timing] validation_eval epoch=62 seconds=0.07
# Epoch 062/150 loss=1.2676 val_paper_recall_curve_auc=0.8720 val_r@10=0.6131 time=0.9s vram=33817MB
# [timing] artifact_save epoch=62 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=63 seconds=0.90
# [timing] validation_eval epoch=63 seconds=0.07
# Epoch 063/150 loss=1.2578 val_paper_recall_curve_auc=0.8718 val_r@10=0.6176 time=0.9s vram=33817MB
# [timing] artifact_save epoch=63 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=64 seconds=0.90
# [timing] validation_eval epoch=64 seconds=0.07
# Epoch 064/150 loss=1.2441 val_paper_recall_curve_auc=0.8677 val_r@10=0.6131 time=0.9s vram=33817MB
# [timing] artifact_save epoch=64 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=65 seconds=0.89
# [timing] validation_eval epoch=65 seconds=0.06
# Epoch 065/150 loss=1.2256 val_paper_recall_curve_auc=0.8693 val_r@10=0.6109 time=0.9s vram=33817MB
# [timing] artifact_save epoch=65 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=66 seconds=0.89
# [timing] validation_eval epoch=66 seconds=0.06
# Epoch 066/150 loss=1.2021 val_paper_recall_curve_auc=0.8711 val_r@10=0.6154 time=0.9s vram=33817MB
# [timing] artifact_save epoch=66 artifact=last_checkpoint seconds=0.80
# [timing] train_epoch epoch=67 seconds=0.89
# [timing] validation_eval epoch=67 seconds=0.06
# Epoch 067/150 loss=1.1875 val_paper_recall_curve_auc=0.8700 val_r@10=0.6176 time=0.9s vram=33817MB
# [timing] artifact_save epoch=67 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=68 seconds=0.91
# [timing] validation_eval epoch=68 seconds=0.07
# Epoch 068/150 loss=1.1768 val_paper_recall_curve_auc=0.8688 val_r@10=0.6222 time=0.9s vram=33817MB
# [timing] artifact_save epoch=68 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=69 seconds=0.91
# [timing] validation_eval epoch=69 seconds=0.07
# Epoch 069/150 loss=1.1836 val_paper_recall_curve_auc=0.8727 val_r@10=0.6086 time=0.9s vram=33817MB
# [timing] artifact_save epoch=69 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=70 seconds=0.91
# [timing] validation_eval epoch=70 seconds=0.07
# Epoch 070/150 loss=1.1533 val_paper_recall_curve_auc=0.8707 val_r@10=0.6154 time=0.9s vram=33817MB
# [timing] artifact_save epoch=70 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=71 seconds=0.91
# [timing] validation_eval epoch=71 seconds=0.07
# Epoch 071/150 loss=1.1250 val_paper_recall_curve_auc=0.8728 val_r@10=0.6176 time=0.9s vram=33817MB
# [timing] artifact_save epoch=71 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=72 seconds=0.93
# [timing] validation_eval epoch=72 seconds=0.07
# Epoch 072/150 loss=1.1094 val_paper_recall_curve_auc=0.8731 val_r@10=0.6131 time=0.9s vram=33817MB
# [timing] artifact_save epoch=72 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=73 seconds=0.93
# [timing] validation_eval epoch=73 seconds=0.07
# Epoch 073/150 loss=1.0918 val_paper_recall_curve_auc=0.8699 val_r@10=0.6267 time=0.9s vram=33817MB
# [timing] artifact_save epoch=73 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=74 seconds=0.92
# [timing] validation_eval epoch=74 seconds=0.07
# Epoch 074/150 loss=1.0918 val_paper_recall_curve_auc=0.8715 val_r@10=0.6199 time=0.9s vram=33817MB
# [timing] artifact_save epoch=74 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=75 seconds=0.92
# [timing] validation_eval epoch=75 seconds=0.07
# Epoch 075/150 loss=1.0850 val_paper_recall_curve_auc=0.8720 val_r@10=0.6176 time=0.9s vram=33817MB
# [timing] artifact_save epoch=75 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=76 seconds=0.92
# [timing] validation_eval epoch=76 seconds=0.07
# Epoch 076/150 loss=1.0645 val_paper_recall_curve_auc=0.8691 val_r@10=0.6267 time=0.9s vram=33817MB
# [timing] artifact_save epoch=76 artifact=last_checkpoint seconds=0.55
# [timing] train_epoch epoch=77 seconds=0.92
# [timing] validation_eval epoch=77 seconds=0.07
# Epoch 077/150 loss=1.0586 val_paper_recall_curve_auc=0.8706 val_r@10=0.6244 time=0.9s vram=33817MB
# [timing] artifact_save epoch=77 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=78 seconds=0.92
# [timing] validation_eval epoch=78 seconds=0.07
# Epoch 078/150 loss=1.0342 val_paper_recall_curve_auc=0.8731 val_r@10=0.6199 time=0.9s vram=33817MB
# [timing] artifact_save epoch=78 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=79 seconds=0.91
# [timing] validation_eval epoch=79 seconds=0.07
# Epoch 079/150 loss=1.0234 val_paper_recall_curve_auc=0.8722 val_r@10=0.6222 time=0.9s vram=33817MB
# [timing] artifact_save epoch=79 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=80 seconds=0.91
# [timing] validation_eval epoch=80 seconds=0.07
# Epoch 080/150 loss=1.0273 val_paper_recall_curve_auc=0.8741 val_r@10=0.6267 time=0.9s vram=33817MB
# [timing] artifact_save epoch=80 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=81 seconds=0.91
# [timing] validation_eval epoch=81 seconds=0.07
# Epoch 081/150 loss=1.0078 val_paper_recall_curve_auc=0.8702 val_r@10=0.6222 time=0.9s vram=33817MB
# [timing] artifact_save epoch=81 artifact=last_checkpoint seconds=0.54
# [timing] train_epoch epoch=82 seconds=0.91
# [timing] validation_eval epoch=82 seconds=0.07
# Epoch 082/150 loss=1.0117 val_paper_recall_curve_auc=0.8698 val_r@10=0.6199 time=0.9s vram=33817MB
# [timing] artifact_save epoch=82 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=83 seconds=0.91
# [timing] validation_eval epoch=83 seconds=0.07
# Epoch 083/150 loss=1.0000 val_paper_recall_curve_auc=0.8721 val_r@10=0.6131 time=0.9s vram=33817MB
# [timing] artifact_save epoch=83 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=84 seconds=0.91
# [timing] validation_eval epoch=84 seconds=0.07
# Epoch 084/150 loss=0.9922 val_paper_recall_curve_auc=0.8732 val_r@10=0.6244 time=0.9s vram=33817MB
# [timing] artifact_save epoch=84 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=85 seconds=0.91
# [timing] validation_eval epoch=85 seconds=0.07
# Epoch 085/150 loss=0.9844 val_paper_recall_curve_auc=0.8709 val_r@10=0.6290 time=0.9s vram=33817MB
# [timing] artifact_save epoch=85 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=86 seconds=0.91
# [timing] validation_eval epoch=86 seconds=0.07
# Epoch 086/150 loss=0.9658 val_paper_recall_curve_auc=0.8704 val_r@10=0.6176 time=0.9s vram=33817MB
# [timing] artifact_save epoch=86 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=87 seconds=0.91
# [timing] validation_eval epoch=87 seconds=0.07
# Epoch 087/150 loss=0.9561 val_paper_recall_curve_auc=0.8721 val_r@10=0.6244 time=0.9s vram=33817MB
# [timing] artifact_save epoch=87 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=88 seconds=0.91
# [timing] validation_eval epoch=88 seconds=0.07
# Epoch 088/150 loss=0.9668 val_paper_recall_curve_auc=0.8723 val_r@10=0.6267 time=0.9s vram=33817MB
# [timing] artifact_save epoch=88 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=89 seconds=0.91
# [timing] validation_eval epoch=89 seconds=0.07
# Epoch 089/150 loss=0.9561 val_paper_recall_curve_auc=0.8724 val_r@10=0.6267 time=0.9s vram=33817MB
# [timing] artifact_save epoch=89 artifact=last_checkpoint seconds=0.07
# [timing] train_epoch epoch=90 seconds=0.91
# [timing] validation_eval epoch=90 seconds=0.07
# Epoch 090/150 loss=0.9463 val_paper_recall_curve_auc=0.8700 val_r@10=0.6312 time=0.9s vram=33817MB
# [timing] artifact_save epoch=90 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=91 seconds=0.93
# [timing] validation_eval epoch=91 seconds=0.07
# Epoch 091/150 loss=0.9482 val_paper_recall_curve_auc=0.8699 val_r@10=0.6199 time=0.9s vram=33817MB
# [timing] artifact_save epoch=91 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=92 seconds=0.91
# [timing] validation_eval epoch=92 seconds=0.07
# Epoch 092/150 loss=0.9453 val_paper_recall_curve_auc=0.8719 val_r@10=0.6267 time=0.9s vram=33817MB
# [timing] artifact_save epoch=92 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=93 seconds=0.93
# [timing] validation_eval epoch=93 seconds=0.07
# Epoch 093/150 loss=0.9365 val_paper_recall_curve_auc=0.8715 val_r@10=0.6222 time=0.9s vram=33817MB
# [timing] artifact_save epoch=93 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=94 seconds=0.93
# [timing] validation_eval epoch=94 seconds=0.07
# Epoch 094/150 loss=0.9111 val_paper_recall_curve_auc=0.8721 val_r@10=0.6199 time=0.9s vram=33817MB
# [timing] artifact_save epoch=94 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=95 seconds=0.93
# [timing] validation_eval epoch=95 seconds=0.07
# Epoch 095/150 loss=0.9277 val_paper_recall_curve_auc=0.8728 val_r@10=0.6244 time=0.9s vram=33817MB
# [timing] artifact_save epoch=95 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=96 seconds=0.93
# [timing] validation_eval epoch=96 seconds=0.07
# Epoch 096/150 loss=0.9141 val_paper_recall_curve_auc=0.8713 val_r@10=0.6131 time=0.9s vram=33817MB
# [timing] artifact_save epoch=96 artifact=last_checkpoint seconds=0.27
# [timing] train_epoch epoch=97 seconds=0.93
# [timing] validation_eval epoch=97 seconds=0.07
# Epoch 097/150 loss=0.9043 val_paper_recall_curve_auc=0.8695 val_r@10=0.6403 time=0.9s vram=33817MB
# [timing] artifact_save epoch=97 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=98 seconds=0.93
# [timing] validation_eval epoch=98 seconds=0.07
# Epoch 098/150 loss=0.8955 val_paper_recall_curve_auc=0.8708 val_r@10=0.6267 time=0.9s vram=33817MB
# [timing] artifact_save epoch=98 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=99 seconds=0.93
# [timing] validation_eval epoch=99 seconds=0.07
# Epoch 099/150 loss=0.8936 val_paper_recall_curve_auc=0.8709 val_r@10=0.6244 time=0.9s vram=33817MB
# [timing] artifact_save epoch=99 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=100 seconds=0.92
# [timing] validation_eval epoch=100 seconds=0.07
# Epoch 100/150 loss=0.8906 val_paper_recall_curve_auc=0.8703 val_r@10=0.6199 time=0.9s vram=33817MB
# [timing] artifact_save epoch=100 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=101 seconds=0.92
# [timing] validation_eval epoch=101 seconds=0.07
# Epoch 101/150 loss=0.8916 val_paper_recall_curve_auc=0.8722 val_r@10=0.6335 time=0.9s vram=33817MB
# [timing] artifact_save epoch=101 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=102 seconds=0.93
# [timing] validation_eval epoch=102 seconds=0.07
# Epoch 102/150 loss=0.8857 val_paper_recall_curve_auc=0.8697 val_r@10=0.6244 time=0.9s vram=33817MB
# [timing] artifact_save epoch=102 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=103 seconds=0.91
# [timing] validation_eval epoch=103 seconds=0.07
# Epoch 103/150 loss=0.8721 val_paper_recall_curve_auc=0.8713 val_r@10=0.6312 time=0.9s vram=33817MB
# [timing] artifact_save epoch=103 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=104 seconds=0.92
# [timing] validation_eval epoch=104 seconds=0.06
# Epoch 104/150 loss=0.8691 val_paper_recall_curve_auc=0.8702 val_r@10=0.6267 time=0.9s vram=33817MB
# [timing] artifact_save epoch=104 artifact=last_checkpoint seconds=0.08
# [timing] train_epoch epoch=105 seconds=0.94
# [timing] validation_eval epoch=105 seconds=0.06
# Epoch 105/150 loss=0.8584 val_paper_recall_curve_auc=0.8723 val_r@10=0.6199 time=0.9s vram=33817MB
# Early stopping after 25 validation checks.
# [timing] artifact_save epoch=105 artifact=last_checkpoint seconds=0.08
# [timing] final_eval split=val seconds=0.06
#
# VAL n=221 paper_recall_curve_auc=0.8741 r@1=0.2647 r@5=0.5226 r@10=0.6267 r@50=0.8032 MRR=0.3814 median_rank=5.5 random_r@10=0.0452
# [timing] final_eval split=test seconds=0.88
#
# TEST n=202 paper_recall_curve_auc=0.8847 r@1=0.3020 r@5=0.5668 r@10=0.6361 r@50=0.8267 MRR=0.4250 median_rank=3.5 random_r@10=0.0495
# [timing] artifact_save artifact=final_core_artifacts seconds=0.22
# [timing] artifact_save artifact=final_diagnostics_artifacts seconds=0.03
# [timing] total_branch seconds=123.54
#
# Artifacts saved to /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/03_neurovault/specialized_mixed_to_neurovault/stage3_normalized_specter
# Comparison row appended to runs/ale_model_comparison.csv

# %% [markdown]
# # Stage 4: Run Selected Controlled Variants
#
# Stage 4 runs for the branches selected by `AE_BRANCH_MODE`, not only the Stage 3 winners. Use `mixed_only` for the three mixed Stage 1A branches, `specialized_only` for the three Stage 1B branches, or `mixed_and_specialized` for the historical six-branch paired comparison.
#
# Corrected 6a outputs are written under the convention-aware `corrected_stage4_<specter_suffix>/` directory.
#
# All comparisons are within-domain only. When both baseline and specialized branches are selected for the same domain, they must use identical train, validation, and test splits, text IDs, SPECTER embeddings, batching, optimizer, schedule, random seed where practical, loss, early stopping, checkpoint-selection policy, and evaluation implementation.
#
# ## Selected AE Checkpoints
#
# Use the explicit selected-checkpoint registry produced above. Do not infer checkpoints from filename labels, directory order, mtime, the most recent run, or generic aliases.
#
# Required choices:
#
# | Registry key | Checkpoint | Selection reason |
# | --- | --- | --- |
# | `mixed_stage1a` | `mixed_baseline_raw_mse/checkpoints/best_top1_dice.pt` | `held_out_multi_source_rank_1` |
# | `mixed_to_pubmed_stage1b` | `pubmed/checkpoints/best_top1_dice.pt` | `held_out_domain_rank_1` |
# | `mixed_to_nilearn_stage1b` | `nilearn/checkpoints/best_val_loss.pt` | `held_out_top5_dice_rank_1` |
# | `mixed_to_neurovault_stage1b` | `neurovault/checkpoints/best_top5_dice.pt` | `held_out_top5_dice_rank_1` |
#
# ## Branch Selection
#
# The active branch list is generated from `AE_BRANCH_MODE` and recorded in `00_run_metadata/selected_ae_branch_runs.json` and the final README.
#
# ## Component Matching
#
# Each Stage 4 run must load only matching upstream components:
#
# 1. Stage 3 text-side representation/projection from the matching Stage 3 run.
# 2. AE decoder from the exact AE checkpoint used to initialize that Stage 3 run.
# 3. Correct domain-specific train, validation, and held-out test splits.
# 4. A new Stage 4 text-to-latent projection head unique to that run.
#
# Fail before training if a specialized Stage 3 checkpoint is paired with the mixed decoder, a mixed Stage 3 checkpoint is paired with a Stage 1B decoder, components are crossed across domains, a projection head is reused, or a run is evaluated on the wrong domain test split.
#
# ## Required Preflight And Provenance
#
# Before each Stage 4 run, write `stage4_component_provenance.json` and `stage4_trainable_parameter_report.json`.
#
# Validate and record:
#
# * AE checkpoint path, filename, stage, training domain, selection reason, epoch, encoder checksum, decoder checksum.
# * Stage 3 run/checkpoint path, epoch, selection metric, text projection checksum.
# * SPECTER model/version.
# * Train/validation/test split fingerprints.
# * Decoder, Stage 3 text projection, and Stage 4 projection trainable/frozen status.
# * Stage 3 domain equals Stage 4 domain.
# * Stage 3 AE initialization path equals the AE checkpoint supplying the decoder.
# * Decoder checksum matches the registered AE checkpoint.
# * Baseline/specialized split fingerprints match within domain when both branches are selected.
# * No test example appears in train or validation data.
#
# Dimensional preflight must verify:
#
# ```text
# text batch -> SPECTER/text embedding -> Stage 3 text projection -> Stage 4 latent [batch, 384] -> decoder output [batch, 1, 36, 45, 38]
# ```
#
# Primary trainability policy:
#
# * AE decoder frozen.
# * Stage 4 text-to-AE-latent projection trainable.
# * Stage 3 CNN encoder not updated for generation.
# * Stage 3 text projection frozen unless the previously validated Stage 4 recipe trained it; if so, use that same policy for every selected run and log it.
# * SPECTER/base embeddings unchanged.
#
# ## Checkpointing, Evaluation, And Outputs
#
# For each Stage 4 run, save:
#
# * `best_val_loss.pt`
# * `best_val_spatial_corr.pt`
# * `best_val_top5_dice.pt`
# * `best_val_foreground_mse.pt`
# * `last.pt`
# * training/validation histories and per-example held-out test generation metrics
# * generated maps or compact prediction tensor plus manifest
#
# Do not select final generation checkpoint by validation MSE alone. Prefer validation spatial correlation, top-5 Dice/overlap, foreground reconstruction quality, then validation MSE.
#
# Test split is evaluation-only: no gradients, early stopping, checkpoint selection, or hyperparameter decisions.
#
# ## Comparison Files
#
# Create within-domain Stage 4 comparisons for domains where both baseline and specialized branches are selected. Also create selected-branch all-domain summary files.
#
# Primary conclusions for `mixed_and_specialized` must come from within-domain paired comparisons, not raw cross-domain ranking.
#
# ## Completion Rule
#
# A Stage 4 run is complete only if saved outputs exist and validate: config, provenance, trainable-parameter report, checkpoint, training/validation histories, held-out generation metrics, nonzero predictions, per-example metrics, and generated-map manifest. The overall pipeline is complete when every branch selected by `AE_BRANCH_MODE` is complete.

# %%
def discover_stage3_checkpoint(domain: str, branch: str) -> Path:
    if RERUN_STAGE3:
        candidate = RUN_DIR / domain_dirs[domain] / branch / STAGE3_SPECTER_DIRNAME / "checkpoints" / NORMALIZED_STAGE3_CHECKPOINT
    else:
        if COMPLETED_STAGE3_RUN_ROOT is None:
            raise RuntimeError(
                "RERUN_STAGE3 is False, so Stage 4 needs explicit completed Stage 3 outputs. "
                "Set NEUROVLM_COMPLETED_STAGE3_RUN_ROOT to the run directory containing 01_pubmed/, 02_nilearn/, and 03_neurovault/."
            )
        candidate = COMPLETED_STAGE3_RUN_ROOT / domain_dirs[domain] / branch / STAGE3_SPECTER_DIRNAME / "checkpoints" / NORMALIZED_STAGE3_CHECKPOINT
    if not candidate.exists():
        raise FileNotFoundError(f"Missing matching Stage 3 checkpoint: {candidate}")
    return candidate


def discover_stage4_generation_cache() -> Path:
    if NORMALIZED_SPECTER_CACHE is None or not Path(NORMALIZED_SPECTER_CACHE).exists():
        raise FileNotFoundError(f"Text embedding cache does not exist: {NORMALIZED_SPECTER_CACHE}")
    return Path(NORMALIZED_SPECTER_CACHE)



STAGE4_GENERATION_TEXT_CACHE = discover_stage4_generation_cache() if RUN_STAGE4_TEXT_TO_BRAIN else None
if STAGE4_GENERATION_TEXT_CACHE:
    print("Corrected Stage 4 generation cache:", STAGE4_GENERATION_TEXT_CACHE)

if RUN_STAGE4_TEXT_TO_BRAIN:
    if not STAGE2_STAGE3_STAGE4_INPUT_MANIFEST or not Path(STAGE2_STAGE3_STAGE4_INPUT_MANIFEST).exists():
        raise RuntimeError("Stage 4 requires the validated Stage 1 selected-checkpoint manifest")
    downstream_manifest = json.loads(Path(STAGE2_STAGE3_STAGE4_INPUT_MANIFEST).read_text())
    SELECTED_DOWNSTREAM_RUNS = select_downstream_runs_from_manifest(downstream_manifest)
    print(f"Stage 4 selected branch mode: {AE_BRANCH_MODE} ({len(SELECTED_DOWNSTREAM_RUNS)} runs)")
    stage4_epochs = int(os.environ.get("NEUROVLM_STAGE4_EPOCHS", "200"))
    stage4_patience = int(os.environ.get("NEUROVLM_STAGE4_EARLY_STOPPING_PATIENCE", "25"))
    stage4_val_interval = int(os.environ.get("NEUROVLM_STAGE4_VAL_INTERVAL", "1"))
    generation_auc_val_interval = GENERATION_AUC_VAL_INTERVAL
    stage4_primary_checkpoint_metric = os.environ.get("NEUROVLM_STAGE4_PRIMARY_CHECKPOINT_METRIC", "val_top5_dice")
    stage4_early_stopping_metric = os.environ.get("NEUROVLM_STAGE4_EARLY_STOPPING_METRIC", stage4_primary_checkpoint_metric)
    stage4_early_stopping_mode = os.environ.get("NEUROVLM_STAGE4_EARLY_STOPPING_MODE", "min" if stage4_early_stopping_metric.endswith(("loss", "mse")) else "max")
    stage4_summaries = []
    for run_idx, run in enumerate(SELECTED_DOWNSTREAM_RUNS, start=1):
        domain = run["domain"]
        branch = run["branch"]
        branch_dir = RUN_DIR / domain_dirs[domain] / branch
        stage3_ckpt = discover_stage3_checkpoint(domain, branch)
        stage3_dir = stage3_ckpt.parents[1]
        stage4_dir = branch_dir / CORRECTED_STAGE4_SPECTER_DIRNAME
        ckpt_dir = stage4_dir / "checkpoints"
        config_dir = stage4_dir / "config"
        for rel in ["config", "provenance", "checkpoints", "training_metrics", "validation_metrics", "test_metrics", "per_example", "recall_curves", "generated_maps", "plots"]:
            (stage4_dir / rel).mkdir(parents=True, exist_ok=True)
        ae_entry = downstream_manifest["selected_ae_checkpoints"][run["ae_registry_key"]]
        stage4_run_name = f"{run['run']}_corrected_{TEXT_EMBEDDING_DIR_SUFFIX}_stage4"
        provenance = {
            "stage4_run": stage4_run_name,
            "domain": domain,
            "type": run["type"],
            "architecture": "generative_text_to_ae_latent",
            "ae_registry_key": run["ae_registry_key"],
            "ae_checkpoint_path": ae_entry["path"],
            "ae_checkpoint_name": ae_entry["checkpoint_name"],
            "ae_stage": ae_entry["stage"],
            "ae_training_domain": ae_entry["training_domain"],
            "ae_selection_reason": ae_entry["selection_reason"],
            "stage3_dir": str(stage3_dir),
            "stage3_checkpoint": str(stage3_ckpt),
            "stage3_usage": "semantic_validation_during_stage4_training" if STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING else "not_used_by_stage4_training; available_for_notebook7_diagnostics",
            "stage4_training_semantic_auc": "enabled" if STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING else "disabled",
            "stage4_primary_checkpoint": STAGE4_PRIMARY_CHECKPOINT,
            "stage4_spatial_corr_checkpoint": STAGE4_SPATIAL_CORR_CHECKPOINT_NAME,
            "stage4_semantic_checkpoint": STAGE4_SEMANTIC_CHECKPOINT_NAME if STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING else "not produced during training",
            "stage4_semantic_diagnostics": "available in Notebook 7 final evaluation",
            "train_jsonl": TRAIN_JSONL,
            "val_jsonl": VAL_JSONL,
            "test_jsonl": TEST_JSONL,
            "stage4_text_embedding_cache": str(STAGE4_GENERATION_TEXT_CACHE),
            "stage4_text_embedding_cache_sha256": sha256_file(STAGE4_GENERATION_TEXT_CACHE),
            **TEXT_EMBEDDING_METADATA,
            "single_positive_policy": "one selected primary text per map",
        }
        write_json(stage4_dir / "provenance/stage4_component_provenance.json", provenance)
        write_json(stage4_dir / "stage4_trainable_parameter_report.json", {
            "frozen": ["autoencoder_encoder", "autoencoder_decoder", "stage3_contrastive_projector", "stage3_brain_encoder"],
            "trainable": ["generative_text_to_ae_latent"],
            "forbidden": ["stage3_contrastive_projector_weight_loading", "stage3_contrastive_embedding_decoder_input"],
            "note": "Corrected Stage 4 learns a fresh 768->512->384 projector into the raw frozen AE latent space.",
        })
        cfg = {
            "train_jsonl": TRAIN_JSONL,
            "val_jsonl": VAL_JSONL,
            "test_jsonl": TEST_JSONL,
            "eval_jsonls": {},
            "text_embedding_cache": str(STAGE4_GENERATION_TEXT_CACHE),
            **TEXT_EMBEDDING_METADATA,
            "autoencoder_checkpoint": ae_entry["path"],
            "stage3_contrastive_checkpoint": str(stage3_ckpt),
            "domain": domain,
            "output_dir": str(stage4_dir),
            "checkpoint_dir": str(ckpt_dir),
            "device": "auto",
            "seed": 42,
            "target_shape": [36, 45, 38],
            "batch_size": int(os.environ.get("NEUROVLM_STAGE4_BATCH_SIZE", "1024")),
            "preflight_batch_size": True,
            "batch_candidates": [2048, 1536, 1024, 768, 512, 384, 256, 192, 128, 96, 64],
            "runtime_batch_fallback": True,
            "num_workers": NUM_WORKERS,
            "pin_memory": True,
            "persistent_workers": NUM_WORKERS > 0,
            "prefetch_factor": PREFETCH_FACTOR,
            "epochs": stage4_epochs,
            "early_stopping": True,
            "early_stopping_metric": stage4_early_stopping_metric,
            "early_stopping_mode": stage4_early_stopping_mode,
            "early_stopping_patience": stage4_patience,
            "early_stopping_min_delta": 0.0,
            "primary_checkpoint_metric": stage4_primary_checkpoint_metric,
            "compute_semantic_auc_during_training": STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING,
            "stage4_primary_checkpoint": STAGE4_PRIMARY_CHECKPOINT,
            "stage4_spatial_corr_checkpoint": STAGE4_SPATIAL_CORR_CHECKPOINT_NAME,
            "stage4_semantic_checkpoint": STAGE4_SEMANTIC_CHECKPOINT_NAME,
            "force_generation_auc_for_early_stopping": os.environ.get("NEUROVLM_FORCE_GENERATION_AUC_FOR_EARLY_STOPPING", "0") == "1",
            "lr": float(os.environ.get("NEUROVLM_STAGE4_LR", "0.00005")),
            "weight_decay": float(os.environ.get("NEUROVLM_STAGE4_WEIGHT_DECAY", "0.0001")),
            "positive_texts_per_map": 1,
            "text_projection_init": "random",
            "prediction_activation": "none",
            "amp": True,
            "cudnn_benchmark": True,
            "val_interval": stage4_val_interval,
            "generation_auc_val_interval": generation_auc_val_interval,
            "run_duplicate_aware_val_every_epoch": RUN_DUPLICATE_AWARE_VAL_EVERY_EPOCH,
            "run_raw_and_group_auc_during_training": RUN_RAW_AND_GROUP_AUC_DURING_TRAINING,
            "run_full_debug_metrics_during_training": RUN_FULL_DEBUG_METRICS_DURING_TRAINING,
            "final_test_eval": FINAL_TEST_EVAL,
            "generation_auc_batch_size": int(os.environ.get("NEUROVLM_GENERATION_AUC_BATCH_SIZE", "512")),
            "compute_train_metrics": RUN_FULL_DEBUG_METRICS_DURING_TRAINING,
            "train_metric_batches": 8,
            "val_metric_batches": None,
            "metrics_device": METRICS_DEVICE,
            "include_voxel_auroc": False,
            "eval_num_workers": EVAL_NUM_WORKERS,
            "model": {
                "latent_dim": 384,
                "base_channels": 64,
                "num_blocks": 4,
                "encoder_arch": "plain",
                "dropout": 0.1,
                "norm": "group",
                "pooling": "max",
                "blocks_per_stage": 2,
                "use_dilation": False,
                "multi_scale": False,
                "global_context": "none",
            },
            "generative_text_to_ae_latent": {"name": "generative_text_to_ae_latent", "in_dim": 768, "hidden_dim": 512, "latent_dim": 384},
            "weighted_recon": {"type": "mse", "alpha": 0.0, "gamma": 1.0, "normalize_target": True},
            "loss_name": "latent_mse_plus_reconstruction_mse",
            "loss": {"lambda_recon": 1.0, "lambda_latent": 1.0, "lambda_dice": 0.0, "lambda_topk": 0.0, "lambda_corr": 0.0},
            "optional_loss_ablations_supported_not_run_by_default": [
                "latent_mse_only",
                "latent_mse_plus_reconstruction_mse",
                "latent_mse_plus_cosine_plus_reconstruction_mse",
            ],
        }
        config_path = config_dir / "text_to_brain_config.json"
        write_json(config_path, cfg)
        cmd = [sys.executable, "-u", "-m", "atlas_free_cnn.training.train_text_to_brain", "--config", str(config_path)]
        env = os.environ.copy()
        env["PYTHONPATH"] = os.pathsep.join([
            str(REPO_DIR / "experiments" / "3dcnn"),
            str(REPO_DIR / "src"),
            str(REPO_DIR),
            env.get("PYTHONPATH", ""),
        ])
        print(f"Starting sequential corrected Stage 4 run {run_idx}/{len(SELECTED_DOWNSTREAM_RUNS)}: {stage4_run_name}", flush=True)
        run_subprocess_streaming(cmd, env=env, cwd=REPO_DIR, label=f"Stage 4 {stage4_run_name}")
        stage4_summaries.append({
            "run": stage4_run_name,
            "stage4_dir": str(stage4_dir),
            "config": str(config_path),
            "stage4_training_semantic_auc": "enabled" if STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING else "disabled",
            "primary_checkpoint": str(ckpt_dir / STAGE4_PRIMARY_CHECKPOINT),
            "spatial_corr_checkpoint": str(ckpt_dir / STAGE4_SPATIAL_CORR_CHECKPOINT_NAME),
            "semantic_checkpoint": str(ckpt_dir / STAGE4_SEMANTIC_CHECKPOINT_NAME) if STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING else "not produced during training",
            "semantic_diagnostics": "available in Notebook 7 final evaluation",
        })
    write_json(Path(paths["stage4"]) / f"corrected_stage4_{TEXT_EMBEDDING_DIR_SUFFIX}_run_manifest.json", stage4_summaries)
else:
    print("Corrected Stage 4 not requested")

if "stage5" not in paths:
    paths["stage5"] = str(RUN_DIR / "04_stage5_generation_eval")
    Path(paths["stage5"]).mkdir(parents=True, exist_ok=True)

if RUN_STAGE5_GENERATION_EVAL:
    print("Corrected Stage 4 spatial test evaluation is produced by the trainer; semantic AUC diagnostics are produced by Notebook 7.")
else:
    print("Stage 5 not requested")
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch 153 train: 100%|██████████| 4/4 [00:02<00:00,  2.17batch/s, loss=0.0136]
#
# [timing] train_epoch epoch=153 seconds=2.24
#
# epoch 153 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 153 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 153 val: 100%|██████████| 1/1 [00:00<00:00,  3.55batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=153 seconds=0.28
# [timing] artifact_save epoch=153 artifact=checkpoints seconds=0.01
# {'epoch': 153, 'train_loss': 0.015068258624523878, 'train_latent_mse': 0.0020775341836269945, 'train_latent_cosine': 0.3881915584206581, 'train_latent_cosine_loss': 0.6118084341287613, 'train_reconstruction_mse': 0.012990724062547088, 'train_total': 0.015068258624523878, 'val_mse': 0.015403746627271175, 'val_reconstruction_mse': 0.015412133187055588, 'val_mae': 0.051745373755693436, 'val_foreground_mse': 0.061982255429029465, 'val_spatial_corr': 0.44073963165283203, 'val_top1_dice': 0.14008785784244537, 'val_top5_dice': 0.2484130561351776, 'val_top10_dice': 0.32032763957977295, 'val_top1_overlap': 0.14008785784244537, 'val_top5_overlap': 0.2484130561351776, 'val_top10_overlap': 0.32032763957977295, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6666803359985352, 'val_pred_mean': 0.04789925366640091, 'val_pred_max': 1.0, 'val_loss': 0.01730048842728138, 'val_latent_mse': 0.0018883550073951483, 'val_latent_cosine': 0.35838088393211365, 'val_latent_cosine_loss': 0.641619086265564, 'val_total': 0.01730048842728138}
#
# epoch 154 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 154 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0149]
# epoch 154 train:  25%|██▌       | 1/4 [00:00<00:02,  1.10batch/s, loss=0.0149]
# epoch 154 train:  25%|██▌       | 1/4 [00:01<00:02,  1.10batch/s, loss=0.0145]
# epoch 154 train:  50%|█████     | 2/4 [00:01<00:01,  1.51batch/s, loss=0.0145]
# epoch 154 train:  50%|█████     | 2/4 [00:01<00:01,  1.51batch/s, loss=0.0159]
# epoch 154 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.71batch/s, loss=0.0159]
# epoch 154 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.71batch/s, loss=0.0162]
# epoch 154 train: 100%|██████████| 4/4 [00:02<00:00,  2.24batch/s, loss=0.0162]
#
# [timing] train_epoch epoch=154 seconds=2.13
#
# epoch 154 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 154 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 154 val: 100%|██████████| 1/1 [00:00<00:00,  3.58batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=154 seconds=0.28
# [timing] artifact_save epoch=154 artifact=checkpoints seconds=0.03
# {'epoch': 154, 'train_loss': 0.015395527239888906, 'train_latent_mse': 0.0021270039724186063, 'train_latent_cosine': 0.39403896778821945, 'train_latent_cosine_loss': 0.6059610098600388, 'train_reconstruction_mse': 0.013268523616716266, 'train_total': 0.015395527239888906, 'val_mse': 0.015366906300187111, 'val_reconstruction_mse': 0.01537527795881033, 'val_mae': 0.05270390585064888, 'val_foreground_mse': 0.060545362532138824, 'val_spatial_corr': 0.44226837158203125, 'val_top1_dice': 0.14002174139022827, 'val_top5_dice': 0.24857330322265625, 'val_top10_dice': 0.32024526596069336, 'val_top1_overlap': 0.14002174139022827, 'val_top5_overlap': 0.24857330322265625, 'val_top10_overlap': 0.32024526596069336, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6696318984031677, 'val_pred_mean': 0.05054277926683426, 'val_pred_max': 1.0, 'val_loss': 0.017261512577533722, 'val_latent_mse': 0.001886234967969358, 'val_latent_cosine': 0.35898539423942566, 'val_latent_cosine_loss': 0.641014575958252, 'val_total': 0.017261512577533722}
#
# epoch 155 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 155 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0151]
# epoch 155 train:  25%|██▌       | 1/4 [00:00<00:02,  1.11batch/s, loss=0.0151]
# epoch 155 train:  25%|██▌       | 1/4 [00:01<00:02,  1.11batch/s, loss=0.0142]
# epoch 155 train:  50%|█████     | 2/4 [00:01<00:01,  1.51batch/s, loss=0.0142]
# epoch 155 train:  50%|█████     | 2/4 [00:01<00:01,  1.51batch/s, loss=0.0161]
# epoch 155 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.71batch/s, loss=0.0161]
# epoch 155 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.71batch/s, loss=0.0161]
# epoch 155 train: 100%|██████████| 4/4 [00:02<00:00,  2.25batch/s, loss=0.0161]
#
# [timing] train_epoch epoch=155 seconds=2.12
#
# epoch 155 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 155 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 155 val: 100%|██████████| 1/1 [00:00<00:00,  3.78batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=155 seconds=0.27
# [timing] artifact_save epoch=155 artifact=checkpoints seconds=0.01
# {'epoch': 155, 'train_loss': 0.015361386584118009, 'train_latent_mse': 0.002117694995831698, 'train_latent_cosine': 0.38938071578741074, 'train_latent_cosine_loss': 0.6106192767620087, 'train_reconstruction_mse': 0.013243691762909293, 'train_total': 0.015361386584118009, 'val_mse': 0.015379316173493862, 'val_reconstruction_mse': 0.015387746505439281, 'val_mae': 0.052317019551992416, 'val_foreground_mse': 0.06103651970624924, 'val_spatial_corr': 0.4418461322784424, 'val_top1_dice': 0.140080526471138, 'val_top5_dice': 0.24891583621501923, 'val_top10_dice': 0.3205304741859436, 'val_top1_overlap': 0.140080526471138, 'val_top5_overlap': 0.24891583621501923, 'val_top10_overlap': 0.3205304741859436, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6681604981422424, 'val_pred_mean': 0.049570683389902115, 'val_pred_max': 1.0, 'val_loss': 0.017274662852287292, 'val_latent_mse': 0.0018869155319407582, 'val_latent_cosine': 0.358857661485672, 'val_latent_cosine_loss': 0.6411423683166504, 'val_total': 0.017274662852287292}
#
# epoch 156 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 156 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0146]
# epoch 156 train:  25%|██▌       | 1/4 [00:00<00:02,  1.11batch/s, loss=0.0146]
# epoch 156 train:  25%|██▌       | 1/4 [00:01<00:02,  1.11batch/s, loss=0.0153]
# epoch 156 train:  50%|█████     | 2/4 [00:01<00:01,  1.51batch/s, loss=0.0153]
# epoch 156 train:  50%|█████     | 2/4 [00:01<00:01,  1.51batch/s, loss=0.0158]
# epoch 156 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.71batch/s, loss=0.0158]
# epoch 156 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.71batch/s, loss=0.0152]
# epoch 156 train: 100%|██████████| 4/4 [00:02<00:00,  2.25batch/s, loss=0.0152]
#
# [timing] train_epoch epoch=156 seconds=2.12
#
# epoch 156 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 156 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 156 val: 100%|██████████| 1/1 [00:00<00:00,  3.75batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=156 seconds=0.27
# [timing] artifact_save epoch=156 artifact=checkpoints seconds=0.01
# {'epoch': 156, 'train_loss': 0.015220226952806115, 'train_latent_mse': 0.0021079222206026316, 'train_latent_cosine': 0.3927304148674011, 'train_latent_cosine_loss': 0.6072695851325989, 'train_reconstruction_mse': 0.013112304732203484, 'train_total': 0.015220226952806115, 'val_mse': 0.01537304650992155, 'val_reconstruction_mse': 0.015381534583866596, 'val_mae': 0.05219847708940506, 'val_foreground_mse': 0.061093032360076904, 'val_spatial_corr': 0.44194161891937256, 'val_top1_dice': 0.14032292366027832, 'val_top5_dice': 0.24907605350017548, 'val_top10_dice': 0.3206142485141754, 'val_top1_overlap': 0.14032292366027832, 'val_top5_overlap': 0.24907605350017548, 'val_top10_overlap': 0.3206142485141754, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.667630136013031, 'val_pred_mean': 0.04934351518750191, 'val_pred_max': 1.0, 'val_loss': 0.017267653718590736, 'val_latent_mse': 0.0018861191347241402, 'val_latent_cosine': 0.35928115248680115, 'val_latent_cosine_loss': 0.6407188177108765, 'val_total': 0.017267653718590736}
#
# epoch 157 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 157 train:   0%|          | 0/4 [00:01<?, ?batch/s, loss=0.0145]
# epoch 157 train:  25%|██▌       | 1/4 [00:01<00:03,  1.02s/batch, loss=0.0145]
# epoch 157 train:  25%|██▌       | 1/4 [00:01<00:03,  1.02s/batch, loss=0.0159]
# epoch 157 train:  50%|█████     | 2/4 [00:01<00:01,  1.41batch/s, loss=0.0159]
# epoch 157 train:  50%|█████     | 2/4 [00:02<00:01,  1.41batch/s, loss=0.0149]
# epoch 157 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.63batch/s, loss=0.0149]
# epoch 157 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.63batch/s, loss=0.0160]
# epoch 157 train: 100%|██████████| 4/4 [00:02<00:00,  2.17batch/s, loss=0.0160]
#
# [timing] train_epoch epoch=157 seconds=2.24
#
# epoch 157 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 157 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 157 val: 100%|██████████| 1/1 [00:00<00:00,  3.74batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=157 seconds=0.27
# [timing] artifact_save epoch=157 artifact=checkpoints seconds=0.02
# {'epoch': 157, 'train_loss': 0.015316379256546497, 'train_latent_mse': 0.0021538861328735948, 'train_latent_cosine': 0.3932367265224457, 'train_latent_cosine_loss': 0.6067632734775543, 'train_reconstruction_mse': 0.013162492774426937, 'train_total': 0.015316379256546497, 'val_mse': 0.015372893773019314, 'val_reconstruction_mse': 0.015381459146738052, 'val_mae': 0.052147191017866135, 'val_foreground_mse': 0.06111424043774605, 'val_spatial_corr': 0.4420934319496155, 'val_top1_dice': 0.14069753885269165, 'val_top5_dice': 0.24919219315052032, 'val_top10_dice': 0.3207032382488251, 'val_top1_overlap': 0.14069753885269165, 'val_top5_overlap': 0.24919219315052032, 'val_top10_overlap': 0.3207032382488251, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6674277782440186, 'val_pred_mean': 0.04923669248819351, 'val_pred_max': 1.0, 'val_loss': 0.017266593873500824, 'val_latent_mse': 0.0018851340282708406, 'val_latent_cosine': 0.35976022481918335, 'val_latent_cosine_loss': 0.6402397751808167, 'val_total': 0.017266593873500824}
#
# epoch 158 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 158 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0150]
# epoch 158 train:  25%|██▌       | 1/4 [00:00<00:02,  1.10batch/s, loss=0.0150]
# epoch 158 train:  25%|██▌       | 1/4 [00:01<00:02,  1.10batch/s, loss=0.0155]
# epoch 158 train:  50%|█████     | 2/4 [00:01<00:01,  1.51batch/s, loss=0.0155]
# epoch 158 train:  50%|█████     | 2/4 [00:01<00:01,  1.51batch/s, loss=0.0150]
# epoch 158 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.71batch/s, loss=0.0150]
# epoch 158 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.71batch/s, loss=0.0156]
# epoch 158 train: 100%|██████████| 4/4 [00:02<00:00,  2.24batch/s, loss=0.0156]
#
# [timing] train_epoch epoch=158 seconds=2.13
#
# epoch 158 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 158 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 158 val: 100%|██████████| 1/1 [00:00<00:00,  3.70batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=158 seconds=0.27
# [timing] artifact_save epoch=158 artifact=checkpoints seconds=0.01
# {'epoch': 158, 'train_loss': 0.015240710927173495, 'train_latent_mse': 0.002113996015395969, 'train_latent_cosine': 0.3929837495088577, 'train_latent_cosine_loss': 0.6070162504911423, 'train_reconstruction_mse': 0.013126714853569865, 'train_total': 0.015240710927173495, 'val_mse': 0.015384001657366753, 'val_reconstruction_mse': 0.015392638742923737, 'val_mae': 0.05202629044651985, 'val_foreground_mse': 0.0613296739757061, 'val_spatial_corr': 0.44192367792129517, 'val_top1_dice': 0.14064612984657288, 'val_top5_dice': 0.24924364686012268, 'val_top10_dice': 0.3208656311035156, 'val_top1_overlap': 0.14064612984657288, 'val_top5_overlap': 0.24924364686012268, 'val_top10_overlap': 0.3208656311035156, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6671412587165833, 'val_pred_mean': 0.04888556897640228, 'val_pred_max': 1.0, 'val_loss': 0.017277611419558525, 'val_latent_mse': 0.0018849731422960758, 'val_latent_cosine': 0.35989630222320557, 'val_latent_cosine_loss': 0.6401036977767944, 'val_total': 0.017277611419558525}
#
# epoch 159 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 159 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0156]
# epoch 159 train:  25%|██▌       | 1/4 [00:00<00:02,  1.10batch/s, loss=0.0156]
# epoch 159 train:  25%|██▌       | 1/4 [00:01<00:02,  1.10batch/s, loss=0.0148]
# epoch 159 train:  50%|█████     | 2/4 [00:01<00:01,  1.50batch/s, loss=0.0148]
# epoch 159 train:  50%|█████     | 2/4 [00:01<00:01,  1.50batch/s, loss=0.0155]
# epoch 159 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.70batch/s, loss=0.0155]
# epoch 159 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.70batch/s, loss=0.0142]
# epoch 159 train: 100%|██████████| 4/4 [00:02<00:00,  2.24batch/s, loss=0.0142]
#
# [timing] train_epoch epoch=159 seconds=2.13
#
# epoch 159 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 159 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 159 val: 100%|██████████| 1/1 [00:00<00:00,  3.57batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=159 seconds=0.28
# [timing] artifact_save epoch=159 artifact=checkpoints seconds=0.01
# {'epoch': 159, 'train_loss': 0.015047409106045961, 'train_latent_mse': 0.002098827506415546, 'train_latent_cosine': 0.3955257833003998, 'train_latent_cosine_loss': 0.6044742166996002, 'train_reconstruction_mse': 0.012948581716045737, 'train_total': 0.015047409106045961, 'val_mse': 0.015393989160656929, 'val_reconstruction_mse': 0.015402414835989475, 'val_mae': 0.05217747390270233, 'val_foreground_mse': 0.061264075338840485, 'val_spatial_corr': 0.44214361906051636, 'val_top1_dice': 0.14078569412231445, 'val_top5_dice': 0.24920101463794708, 'val_top10_dice': 0.320931077003479, 'val_top1_overlap': 0.14078569412231445, 'val_top5_overlap': 0.24920101463794708, 'val_top10_overlap': 0.320931077003479, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.668040931224823, 'val_pred_mean': 0.04915586858987808, 'val_pred_max': 1.0, 'val_loss': 0.01728634350001812, 'val_latent_mse': 0.0018839293625205755, 'val_latent_cosine': 0.36080870032310486, 'val_latent_cosine_loss': 0.6391912698745728, 'val_total': 0.01728634350001812}
#
# epoch 160 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 160 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0142]
# epoch 160 train:  25%|██▌       | 1/4 [00:00<00:02,  1.11batch/s, loss=0.0142]
# epoch 160 train:  25%|██▌       | 1/4 [00:01<00:02,  1.11batch/s, loss=0.0159]
# epoch 160 train:  50%|█████     | 2/4 [00:01<00:01,  1.51batch/s, loss=0.0159]
# epoch 160 train:  50%|█████     | 2/4 [00:01<00:01,  1.51batch/s, loss=0.0149]
# epoch 160 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.71batch/s, loss=0.0149]
# epoch 160 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.71batch/s, loss=0.0161]
# epoch 160 train: 100%|██████████| 4/4 [00:02<00:00,  2.24batch/s, loss=0.0161]
#
# [timing] train_epoch epoch=160 seconds=2.12
#
# epoch 160 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 160 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 160 val: 100%|██████████| 1/1 [00:00<00:00,  3.79batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=160 seconds=0.26
# [timing] artifact_save epoch=160 artifact=checkpoints seconds=0.01
# {'epoch': 160, 'train_loss': 0.015284041408449411, 'train_latent_mse': 0.0021070470102131367, 'train_latent_cosine': 0.3961133509874344, 'train_latent_cosine_loss': 0.6038866639137268, 'train_reconstruction_mse': 0.013176994398236275, 'train_total': 0.015284041408449411, 'val_mse': 0.015392633154988289, 'val_reconstruction_mse': 0.015401174314320087, 'val_mae': 0.052132368087768555, 'val_foreground_mse': 0.06119753047823906, 'val_spatial_corr': 0.44220030307769775, 'val_top1_dice': 0.1413366198539734, 'val_top5_dice': 0.24950093030929565, 'val_top10_dice': 0.32108911871910095, 'val_top1_overlap': 0.1413366198539734, 'val_top5_overlap': 0.24950093030929565, 'val_top10_overlap': 0.32108911871910095, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6670947670936584, 'val_pred_mean': 0.049161698669195175, 'val_pred_max': 1.0, 'val_loss': 0.01728428155183792, 'val_latent_mse': 0.0018831081688404083, 'val_latent_cosine': 0.36120155453681946, 'val_latent_cosine_loss': 0.6387984752655029, 'val_total': 0.01728428155183792}
#
# epoch 161 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 161 train:   0%|          | 0/4 [00:01<?, ?batch/s, loss=0.0152]
# epoch 161 train:  25%|██▌       | 1/4 [00:01<00:03,  1.02s/batch, loss=0.0152]
# epoch 161 train:  25%|██▌       | 1/4 [00:01<00:03,  1.02s/batch, loss=0.0163]
# epoch 161 train:  50%|█████     | 2/4 [00:01<00:01,  1.41batch/s, loss=0.0163]
# epoch 161 train:  50%|█████     | 2/4 [00:02<00:01,  1.41batch/s, loss=0.0140]
# epoch 161 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.64batch/s, loss=0.0140]
# epoch 161 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.64batch/s, loss=0.0150]
# epoch 161 train: 100%|██████████| 4/4 [00:02<00:00,  2.17batch/s, loss=0.0150]
#
# [timing] train_epoch epoch=161 seconds=2.24
#
# epoch 161 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 161 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 161 val: 100%|██████████| 1/1 [00:00<00:00,  3.76batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=161 seconds=0.27
# [timing] artifact_save epoch=161 artifact=checkpoints seconds=0.03
# {'epoch': 161, 'train_loss': 0.01511727157048881, 'train_latent_mse': 0.0020978457760065794, 'train_latent_cosine': 0.3988550826907158, 'train_latent_cosine_loss': 0.6011449098587036, 'train_reconstruction_mse': 0.013019425794482231, 'train_total': 0.01511727157048881, 'val_mse': 0.015389960259199142, 'val_reconstruction_mse': 0.015398564748466015, 'val_mae': 0.05224023759365082, 'val_foreground_mse': 0.06090555340051651, 'val_spatial_corr': 0.4425662159919739, 'val_top1_dice': 0.1417626440525055, 'val_top5_dice': 0.24980230629444122, 'val_top10_dice': 0.32127800583839417, 'val_top1_overlap': 0.1417626440525055, 'val_top5_overlap': 0.24980230629444122, 'val_top10_overlap': 0.32127800583839417, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6666194200515747, 'val_pred_mean': 0.04964739456772804, 'val_pred_max': 1.0, 'val_loss': 0.017281003296375275, 'val_latent_mse': 0.0018824387807399035, 'val_latent_cosine': 0.36153119802474976, 'val_latent_cosine_loss': 0.6384688019752502, 'val_total': 0.017281003296375275}
#
# epoch 162 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 162 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0148]
# epoch 162 train:  25%|██▌       | 1/4 [00:00<00:02,  1.10batch/s, loss=0.0148]
# epoch 162 train:  25%|██▌       | 1/4 [00:01<00:02,  1.10batch/s, loss=0.0157]
# epoch 162 train:  50%|█████     | 2/4 [00:01<00:01,  1.51batch/s, loss=0.0157]
# epoch 162 train:  50%|█████     | 2/4 [00:01<00:01,  1.51batch/s, loss=0.0152]
# epoch 162 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.70batch/s, loss=0.0152]
# epoch 162 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.70batch/s, loss=0.0143]
# epoch 162 train: 100%|██████████| 4/4 [00:02<00:00,  2.24batch/s, loss=0.0143]
#
# [timing] train_epoch epoch=162 seconds=2.13
#
# epoch 162 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 162 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 162 val: 100%|██████████| 1/1 [00:00<00:00,  3.75batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=162 seconds=0.27
# [timing] artifact_save epoch=162 artifact=checkpoints seconds=0.02
# {'epoch': 162, 'train_loss': 0.015014880103990436, 'train_latent_mse': 0.002077332028420642, 'train_latent_cosine': 0.39550595730543137, 'train_latent_cosine_loss': 0.604494035243988, 'train_reconstruction_mse': 0.012937548104673624, 'train_total': 0.015014880103990436, 'val_mse': 0.01542068924754858, 'val_reconstruction_mse': 0.015429478138685226, 'val_mae': 0.05184108391404152, 'val_foreground_mse': 0.06154331564903259, 'val_spatial_corr': 0.4418797492980957, 'val_top1_dice': 0.14186549186706543, 'val_top5_dice': 0.24999339878559113, 'val_top10_dice': 0.32144853472709656, 'val_top1_overlap': 0.14186549186706543, 'val_top5_overlap': 0.24999339878559113, 'val_top10_overlap': 0.32144853472709656, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6648196578025818, 'val_pred_mean': 0.04852837324142456, 'val_pred_max': 1.0, 'val_loss': 0.017313789576292038, 'val_latent_mse': 0.0018843123689293861, 'val_latent_cosine': 0.3607354760169983, 'val_latent_cosine_loss': 0.6392645239830017, 'val_total': 0.017313789576292038}
#
# epoch 163 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 163 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0160]
# epoch 163 train:  25%|██▌       | 1/4 [00:00<00:02,  1.18batch/s, loss=0.0160]
# epoch 163 train:  25%|██▌       | 1/4 [00:01<00:02,  1.18batch/s, loss=0.0136]
# epoch 163 train:  50%|█████     | 2/4 [00:01<00:01,  1.57batch/s, loss=0.0136]
# epoch 163 train:  50%|█████     | 2/4 [00:01<00:01,  1.57batch/s, loss=0.0154]
# epoch 163 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.75batch/s, loss=0.0154]
# epoch 163 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.75batch/s, loss=0.0158]
# epoch 163 train: 100%|██████████| 4/4 [00:02<00:00,  2.29batch/s, loss=0.0158]
#
# [timing] train_epoch epoch=163 seconds=2.06
#
# epoch 163 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 163 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 163 val: 100%|██████████| 1/1 [00:00<00:00,  3.75batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=163 seconds=0.27
# [timing] artifact_save epoch=163 artifact=checkpoints seconds=0.01
# {'epoch': 163, 'train_loss': 0.01519863004796207, 'train_latent_mse': 0.002114768896717578, 'train_latent_cosine': 0.39541520923376083, 'train_latent_cosine_loss': 0.6045847833156586, 'train_reconstruction_mse': 0.013083860976621509, 'train_total': 0.01519863004796207, 'val_mse': 0.01541112270206213, 'val_reconstruction_mse': 0.015419993549585342, 'val_mae': 0.05214618146419525, 'val_foreground_mse': 0.06111227348446846, 'val_spatial_corr': 0.442321240901947, 'val_top1_dice': 0.14156432449817657, 'val_top5_dice': 0.24997574090957642, 'val_top10_dice': 0.3212243616580963, 'val_top1_overlap': 0.14156432449817657, 'val_top5_overlap': 0.24997574090957642, 'val_top10_overlap': 0.3212243616580963, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6660106182098389, 'val_pred_mean': 0.04934077337384224, 'val_pred_max': 1.0, 'val_loss': 0.017304085195064545, 'val_latent_mse': 0.001884091179817915, 'val_latent_cosine': 0.3605872392654419, 'val_latent_cosine_loss': 0.6394127607345581, 'val_total': 0.017304085195064545}
#
# epoch 164 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 164 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0147]
# epoch 164 train:  25%|██▌       | 1/4 [00:00<00:02,  1.13batch/s, loss=0.0147]
# epoch 164 train:  25%|██▌       | 1/4 [00:01<00:02,  1.13batch/s, loss=0.0154]
# epoch 164 train:  50%|█████     | 2/4 [00:01<00:01,  1.53batch/s, loss=0.0154]
# epoch 164 train:  50%|█████     | 2/4 [00:01<00:01,  1.53batch/s, loss=0.0142]
# epoch 164 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.72batch/s, loss=0.0142]
# epoch 164 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.72batch/s, loss=0.0171]
# epoch 164 train: 100%|██████████| 4/4 [00:02<00:00,  2.26batch/s, loss=0.0171]
#
# [timing] train_epoch epoch=164 seconds=2.10
#
# epoch 164 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 164 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 164 val: 100%|██████████| 1/1 [00:00<00:00,  3.75batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=164 seconds=0.27
# [timing] artifact_save epoch=164 artifact=checkpoints seconds=0.02
# {'epoch': 164, 'train_loss': 0.015343887498602271, 'train_latent_mse': 0.002151763765141368, 'train_latent_cosine': 0.3962072730064392, 'train_latent_cosine_loss': 0.6037927269935608, 'train_reconstruction_mse': 0.013192123966291547, 'train_total': 0.015343887498602271, 'val_mse': 0.01542229950428009, 'val_reconstruction_mse': 0.01543122623115778, 'val_mae': 0.051906436681747437, 'val_foreground_mse': 0.061441902071237564, 'val_spatial_corr': 0.44210946559906006, 'val_top1_dice': 0.1418948620557785, 'val_top5_dice': 0.2501477599143982, 'val_top10_dice': 0.3213111162185669, 'val_top1_overlap': 0.1418948620557785, 'val_top5_overlap': 0.2501477599143982, 'val_top10_overlap': 0.3213111162185669, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6648416519165039, 'val_pred_mean': 0.04873796924948692, 'val_pred_max': 1.0, 'val_loss': 0.017314838245511055, 'val_latent_mse': 0.0018836123635992408, 'val_latent_cosine': 0.36097705364227295, 'val_latent_cosine_loss': 0.639022946357727, 'val_total': 0.017314838245511055}
#
# epoch 165 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 165 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0159]
# epoch 165 train:  25%|██▌       | 1/4 [00:00<00:02,  1.04batch/s, loss=0.0159]
# epoch 165 train:  25%|██▌       | 1/4 [00:01<00:02,  1.04batch/s, loss=0.0153]
# epoch 165 train:  50%|█████     | 2/4 [00:01<00:01,  1.45batch/s, loss=0.0153]
# epoch 165 train:  50%|█████     | 2/4 [00:01<00:01,  1.45batch/s, loss=0.0147]
# epoch 165 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.67batch/s, loss=0.0147]
# epoch 165 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.67batch/s, loss=0.0137]
# epoch 165 train: 100%|██████████| 4/4 [00:02<00:00,  2.20batch/s, loss=0.0137]
#
# [timing] train_epoch epoch=165 seconds=2.18
#
# epoch 165 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 165 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 165 val: 100%|██████████| 1/1 [00:00<00:00,  3.77batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=165 seconds=0.27
# [timing] artifact_save epoch=165 artifact=checkpoints seconds=0.01
# {'epoch': 165, 'train_loss': 0.014885124517604709, 'train_latent_mse': 0.0020761434570886195, 'train_latent_cosine': 0.3968473896384239, 'train_latent_cosine_loss': 0.6031526029109955, 'train_reconstruction_mse': 0.012808980885893106, 'train_total': 0.014885124517604709, 'val_mse': 0.015439463779330254, 'val_reconstruction_mse': 0.015448302030563354, 'val_mae': 0.05196797847747803, 'val_foreground_mse': 0.0614546574652195, 'val_spatial_corr': 0.44207698106765747, 'val_top1_dice': 0.14182142913341522, 'val_top5_dice': 0.24992430210113525, 'val_top10_dice': 0.3213081359863281, 'val_top1_overlap': 0.14182142913341522, 'val_top5_overlap': 0.24992430210113525, 'val_top10_overlap': 0.3213081359863281, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6650060415267944, 'val_pred_mean': 0.04882299527525902, 'val_pred_max': 1.0, 'val_loss': 0.01733141764998436, 'val_latent_mse': 0.0018831160850822926, 'val_latent_cosine': 0.3615402579307556, 'val_latent_cosine_loss': 0.6384597420692444, 'val_total': 0.01733141764998436}
#
# epoch 166 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 166 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0150]
# epoch 166 train:  25%|██▌       | 1/4 [00:00<00:02,  1.13batch/s, loss=0.0150]
# epoch 166 train:  25%|██▌       | 1/4 [00:01<00:02,  1.13batch/s, loss=0.0151]
# epoch 166 train:  50%|█████     | 2/4 [00:01<00:01,  1.53batch/s, loss=0.0151]
# epoch 166 train:  50%|█████     | 2/4 [00:01<00:01,  1.53batch/s, loss=0.0153]
# epoch 166 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.72batch/s, loss=0.0153]
# epoch 166 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.72batch/s, loss=0.0145]
# epoch 166 train: 100%|██████████| 4/4 [00:02<00:00,  2.26batch/s, loss=0.0145]
#
# [timing] train_epoch epoch=166 seconds=2.11
#
# epoch 166 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 166 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 166 val: 100%|██████████| 1/1 [00:00<00:00,  3.73batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=166 seconds=0.27
# [timing] artifact_save epoch=166 artifact=checkpoints seconds=0.03
# {'epoch': 166, 'train_loss': 0.014979776926338673, 'train_latent_mse': 0.0020874543697573245, 'train_latent_cosine': 0.3984388932585716, 'train_latent_cosine_loss': 0.601561114192009, 'train_reconstruction_mse': 0.012892322614789009, 'train_total': 0.014979776926338673, 'val_mse': 0.015433961525559425, 'val_reconstruction_mse': 0.015442723408341408, 'val_mae': 0.05208119377493858, 'val_foreground_mse': 0.061263080686330795, 'val_spatial_corr': 0.44269639253616333, 'val_top1_dice': 0.14229154586791992, 'val_top5_dice': 0.250399112701416, 'val_top10_dice': 0.32168227434158325, 'val_top1_overlap': 0.14229154586791992, 'val_top5_overlap': 0.250399112701416, 'val_top10_overlap': 0.32168227434158325, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6655903458595276, 'val_pred_mean': 0.049117688089609146, 'val_pred_max': 1.0, 'val_loss': 0.017323438078165054, 'val_latent_mse': 0.001880713738501072, 'val_latent_cosine': 0.36282557249069214, 'val_latent_cosine_loss': 0.6371744275093079, 'val_total': 0.017323438078165054}
#
# epoch 167 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 167 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0154]
# epoch 167 train:  25%|██▌       | 1/4 [00:00<00:02,  1.18batch/s, loss=0.0154]
# epoch 167 train:  25%|██▌       | 1/4 [00:01<00:02,  1.18batch/s, loss=0.0143]
# epoch 167 train:  50%|█████     | 2/4 [00:01<00:01,  1.56batch/s, loss=0.0143]
# epoch 167 train:  50%|█████     | 2/4 [00:01<00:01,  1.56batch/s, loss=0.0155]
# epoch 167 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.74batch/s, loss=0.0155]
# epoch 167 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.74batch/s, loss=0.0147]
# epoch 167 train: 100%|██████████| 4/4 [00:02<00:00,  2.28batch/s, loss=0.0147]
#
# [timing] train_epoch epoch=167 seconds=2.07
#
# epoch 167 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 167 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 167 val: 100%|██████████| 1/1 [00:00<00:00,  3.76batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=167 seconds=0.27
# [timing] artifact_save epoch=167 artifact=checkpoints seconds=0.02
# {'epoch': 167, 'train_loss': 0.014981027459725738, 'train_latent_mse': 0.002092806447762996, 'train_latent_cosine': 0.3998819440603256, 'train_latent_cosine_loss': 0.6001180559396744, 'train_reconstruction_mse': 0.012888220604509115, 'train_total': 0.014981027459725738, 'val_mse': 0.015421108342707157, 'val_reconstruction_mse': 0.01542988047003746, 'val_mae': 0.05210001766681671, 'val_foreground_mse': 0.06111736595630646, 'val_spatial_corr': 0.44309067726135254, 'val_top1_dice': 0.14254865050315857, 'val_top5_dice': 0.2507210969924927, 'val_top10_dice': 0.32195571064949036, 'val_top1_overlap': 0.14254865050315857, 'val_top5_overlap': 0.2507210969924927, 'val_top10_overlap': 0.32195571064949036, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6654706597328186, 'val_pred_mean': 0.04928705841302872, 'val_pred_max': 1.0, 'val_loss': 0.017308592796325684, 'val_latent_mse': 0.0018787123262882233, 'val_latent_cosine': 0.3637579083442688, 'val_latent_cosine_loss': 0.6362420916557312, 'val_total': 0.017308592796325684}
#
# epoch 168 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 168 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0150]
# epoch 168 train:  25%|██▌       | 1/4 [00:00<00:02,  1.13batch/s, loss=0.0150]
# epoch 168 train:  25%|██▌       | 1/4 [00:01<00:02,  1.13batch/s, loss=0.0143]
# epoch 168 train:  50%|█████     | 2/4 [00:01<00:01,  1.53batch/s, loss=0.0143]
# epoch 168 train:  50%|█████     | 2/4 [00:01<00:01,  1.53batch/s, loss=0.0156]
# epoch 168 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.72batch/s, loss=0.0156]
# epoch 168 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.72batch/s, loss=0.0153]
# epoch 168 train: 100%|██████████| 4/4 [00:02<00:00,  2.26batch/s, loss=0.0153]
#
# [timing] train_epoch epoch=168 seconds=2.10
#
# epoch 168 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 168 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 168 val: 100%|██████████| 1/1 [00:00<00:00,  3.76batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=168 seconds=0.27
# [timing] artifact_save epoch=168 artifact=checkpoints seconds=0.03
# {'epoch': 168, 'train_loss': 0.015048113651573658, 'train_latent_mse': 0.0020921717514283955, 'train_latent_cosine': 0.39911308884620667, 'train_latent_cosine_loss': 0.6008869260549545, 'train_reconstruction_mse': 0.01295594172552228, 'train_total': 0.015048113651573658, 'val_mse': 0.015418142080307007, 'val_reconstruction_mse': 0.015426766127347946, 'val_mae': 0.05202396586537361, 'val_foreground_mse': 0.06118973344564438, 'val_spatial_corr': 0.443203330039978, 'val_top1_dice': 0.14240171015262604, 'val_top5_dice': 0.250823974609375, 'val_top10_dice': 0.3221975266933441, 'val_top1_overlap': 0.14240171015262604, 'val_top5_overlap': 0.250823974609375, 'val_top10_overlap': 0.3221975266933441, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6652539968490601, 'val_pred_mean': 0.04913787543773651, 'val_pred_max': 1.0, 'val_loss': 0.01730477437376976, 'val_latent_mse': 0.0018780084792524576, 'val_latent_cosine': 0.3642496168613434, 'val_latent_cosine_loss': 0.635750412940979, 'val_total': 0.01730477437376976}
#
# epoch 169 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 169 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0150]
# epoch 169 train:  25%|██▌       | 1/4 [00:00<00:02,  1.00batch/s, loss=0.0150]
# epoch 169 train:  25%|██▌       | 1/4 [00:01<00:02,  1.00batch/s, loss=0.0147]
# epoch 169 train:  50%|█████     | 2/4 [00:01<00:01,  1.43batch/s, loss=0.0147]
# epoch 169 train:  50%|█████     | 2/4 [00:01<00:01,  1.43batch/s, loss=0.0147]
# epoch 169 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.65batch/s, loss=0.0147]
# epoch 169 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.65batch/s, loss=0.0162]
# epoch 169 train: 100%|██████████| 4/4 [00:02<00:00,  2.18batch/s, loss=0.0162]
#
# [timing] train_epoch epoch=169 seconds=2.21
#
# epoch 169 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 169 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 169 val: 100%|██████████| 1/1 [00:00<00:00,  3.74batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=169 seconds=0.27
# [timing] artifact_save epoch=169 artifact=checkpoints seconds=0.01
# {'epoch': 169, 'train_loss': 0.01515261922031641, 'train_latent_mse': 0.002120019751600921, 'train_latent_cosine': 0.40147220343351364, 'train_latent_cosine_loss': 0.598527804017067, 'train_reconstruction_mse': 0.013032599817961454, 'train_total': 0.01515261922031641, 'val_mse': 0.015428563579916954, 'val_reconstruction_mse': 0.015437369234859943, 'val_mae': 0.05196451395750046, 'val_foreground_mse': 0.061253804713487625, 'val_spatial_corr': 0.4430832862854004, 'val_top1_dice': 0.14262942969799042, 'val_top5_dice': 0.2509077787399292, 'val_top10_dice': 0.3221968114376068, 'val_top1_overlap': 0.14262942969799042, 'val_top5_overlap': 0.2509077787399292, 'val_top10_overlap': 0.3221968114376068, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6643266677856445, 'val_pred_mean': 0.049059197306632996, 'val_pred_max': 1.0, 'val_loss': 0.01731535792350769, 'val_latent_mse': 0.0018779888050630689, 'val_latent_cosine': 0.36437180638313293, 'val_latent_cosine_loss': 0.6356282234191895, 'val_total': 0.01731535792350769}
#
# epoch 170 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 170 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0147]
# epoch 170 train:  25%|██▌       | 1/4 [00:00<00:02,  1.18batch/s, loss=0.0147]
# epoch 170 train:  25%|██▌       | 1/4 [00:01<00:02,  1.18batch/s, loss=0.0154]
# epoch 170 train:  50%|█████     | 2/4 [00:01<00:01,  1.56batch/s, loss=0.0154]
# epoch 170 train:  50%|█████     | 2/4 [00:01<00:01,  1.56batch/s, loss=0.0146]
# epoch 170 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.74batch/s, loss=0.0146]
# epoch 170 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.74batch/s, loss=0.0157]
# epoch 170 train: 100%|██████████| 4/4 [00:02<00:00,  2.28batch/s, loss=0.0157]
#
# [timing] train_epoch epoch=170 seconds=2.07
#
# epoch 170 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 170 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 170 val: 100%|██████████| 1/1 [00:00<00:00,  3.75batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=170 seconds=0.27
# [timing] artifact_save epoch=170 artifact=checkpoints seconds=0.02
# {'epoch': 170, 'train_loss': 0.015074403490871191, 'train_latent_mse': 0.0020983731374144554, 'train_latent_cosine': 0.39978473633527756, 'train_latent_cosine_loss': 0.6002152860164642, 'train_reconstruction_mse': 0.012976030353456736, 'train_total': 0.015074403490871191, 'val_mse': 0.015437331981956959, 'val_reconstruction_mse': 0.015446287579834461, 'val_mae': 0.05190511420369148, 'val_foreground_mse': 0.06132277846336365, 'val_spatial_corr': 0.4431964159011841, 'val_top1_dice': 0.14315097033977509, 'val_top5_dice': 0.25117093324661255, 'val_top10_dice': 0.32217034697532654, 'val_top1_overlap': 0.14315097033977509, 'val_top5_overlap': 0.25117093324661255, 'val_top10_overlap': 0.32217034697532654, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.663882851600647, 'val_pred_mean': 0.04891267046332359, 'val_pred_max': 1.0, 'val_loss': 0.0173238106071949, 'val_latent_mse': 0.0018775233766064048, 'val_latent_cosine': 0.36468541622161865, 'val_latent_cosine_loss': 0.6353145837783813, 'val_total': 0.0173238106071949}
#
# epoch 171 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 171 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0150]
# epoch 171 train:  25%|██▌       | 1/4 [00:00<00:02,  1.17batch/s, loss=0.0150]
# epoch 171 train:  25%|██▌       | 1/4 [00:01<00:02,  1.17batch/s, loss=0.0150]
# epoch 171 train:  50%|█████     | 2/4 [00:01<00:01,  1.56batch/s, loss=0.0150]
# epoch 171 train:  50%|█████     | 2/4 [00:01<00:01,  1.56batch/s, loss=0.0145]
# epoch 171 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.74batch/s, loss=0.0145]
# epoch 171 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.74batch/s, loss=0.0157]
# epoch 171 train: 100%|██████████| 4/4 [00:02<00:00,  2.28batch/s, loss=0.0157]
#
# [timing] train_epoch epoch=171 seconds=2.07
#
# epoch 171 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 171 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 171 val: 100%|██████████| 1/1 [00:00<00:00,  3.74batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=171 seconds=0.27
# [timing] artifact_save epoch=171 artifact=checkpoints seconds=0.03
# {'epoch': 171, 'train_loss': 0.015064289327710867, 'train_latent_mse': 0.00212746683973819, 'train_latent_cosine': 0.4036232605576515, 'train_latent_cosine_loss': 0.5963767319917679, 'train_reconstruction_mse': 0.012936822604387999, 'train_total': 0.015064289327710867, 'val_mse': 0.015444492921233177, 'val_reconstruction_mse': 0.015453401952981949, 'val_mae': 0.05201362818479538, 'val_foreground_mse': 0.06122744083404541, 'val_spatial_corr': 0.44352447986602783, 'val_top1_dice': 0.14320237934589386, 'val_top5_dice': 0.2512209117412567, 'val_top10_dice': 0.3222622275352478, 'val_top1_overlap': 0.14320237934589386, 'val_top5_overlap': 0.2512209117412567, 'val_top10_overlap': 0.3222622275352478, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6648054122924805, 'val_pred_mean': 0.04911040887236595, 'val_pred_max': 1.0, 'val_loss': 0.017330311238765717, 'val_latent_mse': 0.0018769088201224804, 'val_latent_cosine': 0.36509424448013306, 'val_latent_cosine_loss': 0.6349057555198669, 'val_total': 0.017330311238765717}
#
# epoch 172 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 172 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0146]
# epoch 172 train:  25%|██▌       | 1/4 [00:00<00:02,  1.09batch/s, loss=0.0146]
# epoch 172 train:  25%|██▌       | 1/4 [00:01<00:02,  1.09batch/s, loss=0.0142]
# epoch 172 train:  50%|█████     | 2/4 [00:01<00:01,  1.50batch/s, loss=0.0142]
# epoch 172 train:  50%|█████     | 2/4 [00:01<00:01,  1.50batch/s, loss=0.0156]
# epoch 172 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.70batch/s, loss=0.0156]
# epoch 172 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.70batch/s, loss=0.0159]
# epoch 172 train: 100%|██████████| 4/4 [00:02<00:00,  2.24batch/s, loss=0.0159]
#
# [timing] train_epoch epoch=172 seconds=2.13
#
# epoch 172 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 172 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 172 val: 100%|██████████| 1/1 [00:00<00:00,  3.76batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=172 seconds=0.27
# [timing] artifact_save epoch=172 artifact=checkpoints seconds=0.02
# {'epoch': 172, 'train_loss': 0.015071810455992818, 'train_latent_mse': 0.0021169349492993206, 'train_latent_cosine': 0.40341950207948685, 'train_latent_cosine_loss': 0.5965805053710938, 'train_reconstruction_mse': 0.012954875594004989, 'train_total': 0.015071810455992818, 'val_mse': 0.01544234063476324, 'val_reconstruction_mse': 0.015451228246092796, 'val_mae': 0.052073750644922256, 'val_foreground_mse': 0.06108850985765457, 'val_spatial_corr': 0.4439338445663452, 'val_top1_dice': 0.1434154212474823, 'val_top5_dice': 0.2516207695007324, 'val_top10_dice': 0.32259297370910645, 'val_top1_overlap': 0.1434154212474823, 'val_top5_overlap': 0.2516207695007324, 'val_top10_overlap': 0.32259297370910645, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6651118993759155, 'val_pred_mean': 0.04931999742984772, 'val_pred_max': 1.0, 'val_loss': 0.017327452078461647, 'val_latent_mse': 0.0018762237159535289, 'val_latent_cosine': 0.36543625593185425, 'val_latent_cosine_loss': 0.6345637440681458, 'val_total': 0.017327452078461647}
#
# epoch 173 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 173 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0147]
# epoch 173 train:  25%|██▌       | 1/4 [00:00<00:02,  1.04batch/s, loss=0.0147]
# epoch 173 train:  25%|██▌       | 1/4 [00:01<00:02,  1.04batch/s, loss=0.0149]
# epoch 173 train:  50%|█████     | 2/4 [00:01<00:01,  1.46batch/s, loss=0.0149]
# epoch 173 train:  50%|█████     | 2/4 [00:01<00:01,  1.46batch/s, loss=0.0147]
# epoch 173 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.67batch/s, loss=0.0147]
# epoch 173 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.67batch/s, loss=0.0158]
# epoch 173 train: 100%|██████████| 4/4 [00:02<00:00,  2.21batch/s, loss=0.0158]
#
# [timing] train_epoch epoch=173 seconds=2.18
#
# epoch 173 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 173 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0173]
# epoch 173 val: 100%|██████████| 1/1 [00:00<00:00,  3.74batch/s, loss=0.0173]
#
# [timing] validation_eval epoch=173 seconds=0.27
# [timing] artifact_save epoch=173 artifact=checkpoints seconds=0.03
# {'epoch': 173, 'train_loss': 0.015048564411699772, 'train_latent_mse': 0.0021120996098034084, 'train_latent_cosine': 0.40117350965738297, 'train_latent_cosine_loss': 0.5988264828920364, 'train_reconstruction_mse': 0.012936464976519346, 'train_total': 0.015048564411699772, 'val_mse': 0.015432783402502537, 'val_reconstruction_mse': 0.01544187031686306, 'val_mae': 0.052133750170469284, 'val_foreground_mse': 0.06077782064676285, 'val_spatial_corr': 0.44424623250961304, 'val_top1_dice': 0.14381207525730133, 'val_top5_dice': 0.25185009837150574, 'val_top10_dice': 0.322745144367218, 'val_top1_overlap': 0.14381207525730133, 'val_top5_overlap': 0.25185009837150574, 'val_top10_overlap': 0.322745144367218, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.6640915870666504, 'val_pred_mean': 0.04974605515599251, 'val_pred_max': 1.0, 'val_loss': 0.017318302765488625, 'val_latent_mse': 0.0018764323322102427, 'val_latent_cosine': 0.36524632573127747, 'val_latent_cosine_loss': 0.6347537040710449, 'val_total': 0.017318302765488625}
#
# epoch 174 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 174 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0150]
# epoch 174 train:  25%|██▌       | 1/4 [00:00<00:02,  1.13batch/s, loss=0.0150]
# epoch 174 train:  25%|██▌       | 1/4 [00:01<00:02,  1.13batch/s, loss=0.0155]
# epoch 174 train:  50%|█████     | 2/4 [00:01<00:01,  1.53batch/s, loss=0.0155]
# epoch 174 train:  50%|█████     | 2/4 [00:01<00:01,  1.53batch/s, loss=0.0136]
# epoch 174 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.72batch/s, loss=0.0136]
# epoch 174 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.72batch/s, loss=0.0163]
# epoch 174 train: 100%|██████████| 4/4 [00:02<00:00,  2.26batch/s, loss=0.0163]
#
# [timing] train_epoch epoch=174 seconds=2.10
#
# epoch 174 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 174 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0174]
# epoch 174 val: 100%|██████████| 1/1 [00:00<00:00,  3.73batch/s, loss=0.0174]
# ...
# epoch 194 val: 100%|██████████| 1/1 [00:00<00:00,  3.79batch/s, loss=0.0172]
#
# [timing] validation_eval epoch=194 seconds=0.26
# [timing] artifact_save epoch=194 artifact=checkpoints seconds=0.03
# {'epoch': 194, 'train_loss': 0.014688034076243639, 'train_latent_mse': 0.0020989655167795718, 'train_latent_cosine': 0.40697208791971207, 'train_latent_cosine_loss': 0.5930279046297073, 'train_reconstruction_mse': 0.012589068617671728, 'train_total': 0.014688034076243639, 'val_mse': 0.015280550345778465, 'val_reconstruction_mse': 0.015291738323867321, 'val_mae': 0.05210250988602638, 'val_foreground_mse': 0.059021927416324615, 'val_spatial_corr': 0.4459415674209595, 'val_top1_dice': 0.1481165885925293, 'val_top5_dice': 0.25467559695243835, 'val_top10_dice': 0.32470178604125977, 'val_top1_overlap': 0.1481165885925293, 'val_top5_overlap': 0.25467559695243835, 'val_top10_overlap': 0.32470178604125977, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.7343243956565857, 'val_pred_mean': 0.05055060610175133, 'val_pred_max': 1.0, 'val_loss': 0.0171811543405056, 'val_latent_mse': 0.0018894169479608536, 'val_latent_cosine': 0.36544564366340637, 'val_latent_cosine_loss': 0.634554386138916, 'val_total': 0.0171811543405056}
#
# epoch 195 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 195 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0147]
# epoch 195 train:  25%|██▌       | 1/4 [00:00<00:02,  1.18batch/s, loss=0.0147]
# epoch 195 train:  25%|██▌       | 1/4 [00:01<00:02,  1.18batch/s, loss=0.0149]
# epoch 195 train:  50%|█████     | 2/4 [00:01<00:01,  1.56batch/s, loss=0.0149]
# epoch 195 train:  50%|█████     | 2/4 [00:01<00:01,  1.56batch/s, loss=0.0142]
# epoch 195 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.74batch/s, loss=0.0142]
# epoch 195 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.74batch/s, loss=0.0145]
# epoch 195 train: 100%|██████████| 4/4 [00:02<00:00,  2.28batch/s, loss=0.0145]
#
# [timing] train_epoch epoch=195 seconds=2.07
#
# epoch 195 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 195 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0172]
# epoch 195 val: 100%|██████████| 1/1 [00:00<00:00,  3.80batch/s, loss=0.0172]
#
# [timing] validation_eval epoch=195 seconds=0.26
# [timing] artifact_save epoch=195 artifact=checkpoints seconds=0.02
# {'epoch': 195, 'train_loss': 0.014591533690690994, 'train_latent_mse': 0.002103626844473183, 'train_latent_cosine': 0.40712130069732666, 'train_latent_cosine_loss': 0.5928786993026733, 'train_reconstruction_mse': 0.01248790672980249, 'train_total': 0.014591533690690994, 'val_mse': 0.015288612805306911, 'val_reconstruction_mse': 0.015299293212592602, 'val_mae': 0.051776640117168427, 'val_foreground_mse': 0.059627715498209, 'val_spatial_corr': 0.4458470940589905, 'val_top1_dice': 0.14879240095615387, 'val_top5_dice': 0.2550651431083679, 'val_top10_dice': 0.32508695125579834, 'val_top1_overlap': 0.14879240095615387, 'val_top5_overlap': 0.2550651431083679, 'val_top10_overlap': 0.32508695125579834, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.735639214515686, 'val_pred_mean': 0.04949057847261429, 'val_pred_max': 1.0, 'val_loss': 0.01718645915389061, 'val_latent_mse': 0.001887166639789939, 'val_latent_cosine': 0.3671611547470093, 'val_latent_cosine_loss': 0.6328388452529907, 'val_total': 0.01718645915389061}
#
# epoch 196 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 196 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0143]
# epoch 196 train:  25%|██▌       | 1/4 [00:00<00:02,  1.04batch/s, loss=0.0143]
# epoch 196 train:  25%|██▌       | 1/4 [00:01<00:02,  1.04batch/s, loss=0.0148]
# epoch 196 train:  50%|█████     | 2/4 [00:01<00:01,  1.46batch/s, loss=0.0148]
# epoch 196 train:  50%|█████     | 2/4 [00:01<00:01,  1.46batch/s, loss=0.0146]
# epoch 196 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.67batch/s, loss=0.0146]
# epoch 196 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.67batch/s, loss=0.0147]
# epoch 196 train: 100%|██████████| 4/4 [00:02<00:00,  2.21batch/s, loss=0.0147]
#
# [timing] train_epoch epoch=196 seconds=2.18
#
# epoch 196 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 196 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0172]
# epoch 196 val: 100%|██████████| 1/1 [00:00<00:00,  3.78batch/s, loss=0.0172]
#
# [timing] validation_eval epoch=196 seconds=0.27
# [timing] artifact_save epoch=196 artifact=checkpoints seconds=0.02
# {'epoch': 196, 'train_loss': 0.014614391839131713, 'train_latent_mse': 0.0020827806438319385, 'train_latent_cosine': 0.4112987741827965, 'train_latent_cosine_loss': 0.5887012332677841, 'train_reconstruction_mse': 0.012531611137092113, 'train_total': 0.014614391839131713, 'val_mse': 0.015285433270037174, 'val_reconstruction_mse': 0.015296049416065216, 'val_mae': 0.052061282098293304, 'val_foreground_mse': 0.059162687510252, 'val_spatial_corr': 0.44659101963043213, 'val_top1_dice': 0.1487630009651184, 'val_top5_dice': 0.25537824630737305, 'val_top10_dice': 0.32506343722343445, 'val_top1_overlap': 0.1487630009651184, 'val_top5_overlap': 0.25537824630737305, 'val_top10_overlap': 0.32506343722343445, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.7355125546455383, 'val_pred_mean': 0.05029783770442009, 'val_pred_max': 1.0, 'val_loss': 0.017181916162371635, 'val_latent_mse': 0.0018858668627217412, 'val_latent_cosine': 0.3679249882698059, 'val_latent_cosine_loss': 0.6320750117301941, 'val_total': 0.017181916162371635}
#
# epoch 197 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 197 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0145]
# epoch 197 train:  25%|██▌       | 1/4 [00:00<00:02,  1.13batch/s, loss=0.0145]
# epoch 197 train:  25%|██▌       | 1/4 [00:01<00:02,  1.13batch/s, loss=0.0149]
# epoch 197 train:  50%|█████     | 2/4 [00:01<00:01,  1.53batch/s, loss=0.0149]
# epoch 197 train:  50%|█████     | 2/4 [00:01<00:01,  1.53batch/s, loss=0.0147]
# epoch 197 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.72batch/s, loss=0.0147]
# epoch 197 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.72batch/s, loss=0.0138]
# epoch 197 train: 100%|██████████| 4/4 [00:02<00:00,  2.26batch/s, loss=0.0138]
#
# [timing] train_epoch epoch=197 seconds=2.10
#
# epoch 197 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 197 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0172]
# epoch 197 val: 100%|██████████| 1/1 [00:00<00:00,  3.72batch/s, loss=0.0172]
#
# [timing] validation_eval epoch=197 seconds=0.27
# [timing] artifact_save epoch=197 artifact=checkpoints seconds=0.01
# {'epoch': 197, 'train_loss': 0.014475471572950482, 'train_latent_mse': 0.0020861515076830983, 'train_latent_cosine': 0.41032136231660843, 'train_latent_cosine_loss': 0.589678630232811, 'train_reconstruction_mse': 0.012389319948852062, 'train_total': 0.014475471572950482, 'val_mse': 0.015303292311728, 'val_reconstruction_mse': 0.015314082615077496, 'val_mae': 0.05181049928069115, 'val_foreground_mse': 0.05955696105957031, 'val_spatial_corr': 0.44610732793807983, 'val_top1_dice': 0.14888052642345428, 'val_top5_dice': 0.25533416867256165, 'val_top10_dice': 0.3251568078994751, 'val_top1_overlap': 0.14888052642345428, 'val_top5_overlap': 0.25533416867256165, 'val_top10_overlap': 0.3251568078994751, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.7353887557983398, 'val_pred_mean': 0.049603912979364395, 'val_pred_max': 1.0, 'val_loss': 0.017199920490384102, 'val_latent_mse': 0.0018858384573832154, 'val_latent_cosine': 0.36800092458724976, 'val_latent_cosine_loss': 0.6319990754127502, 'val_total': 0.017199920490384102}
#
# epoch 198 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 198 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0143]
# epoch 198 train:  25%|██▌       | 1/4 [00:00<00:02,  1.13batch/s, loss=0.0143]
# epoch 198 train:  25%|██▌       | 1/4 [00:01<00:02,  1.13batch/s, loss=0.0153]
# epoch 198 train:  50%|█████     | 2/4 [00:01<00:01,  1.53batch/s, loss=0.0153]
# epoch 198 train:  50%|█████     | 2/4 [00:01<00:01,  1.53batch/s, loss=0.0141]
# epoch 198 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.72batch/s, loss=0.0141]
# epoch 198 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.72batch/s, loss=0.0147]
# epoch 198 train: 100%|██████████| 4/4 [00:02<00:00,  2.26batch/s, loss=0.0147]
#
# [timing] train_epoch epoch=198 seconds=2.11
#
# epoch 198 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 198 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0172]
# epoch 198 val: 100%|██████████| 1/1 [00:00<00:00,  3.73batch/s, loss=0.0172]
#
# [timing] validation_eval epoch=198 seconds=0.27
# [timing] artifact_save epoch=198 artifact=checkpoints seconds=0.02
# {'epoch': 198, 'train_loss': 0.014586302684620023, 'train_latent_mse': 0.0020800543134100735, 'train_latent_cosine': 0.40972530096769333, 'train_latent_cosine_loss': 0.5902747064828873, 'train_reconstruction_mse': 0.01250624842941761, 'train_total': 0.014586302684620023, 'val_mse': 0.01530845370143652, 'val_reconstruction_mse': 0.015319502912461758, 'val_mae': 0.051785536110401154, 'val_foreground_mse': 0.05953216552734375, 'val_spatial_corr': 0.44599324464797974, 'val_top1_dice': 0.148586705327034, 'val_top5_dice': 0.25549882650375366, 'val_top10_dice': 0.3251825273036957, 'val_top1_overlap': 0.148586705327034, 'val_top5_overlap': 0.25549882650375366, 'val_top10_overlap': 0.3251825273036957, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.7348353862762451, 'val_pred_mean': 0.04960896074771881, 'val_pred_max': 1.0, 'val_loss': 0.01720527745783329, 'val_latent_mse': 0.0018857737304642797, 'val_latent_cosine': 0.3678228557109833, 'val_latent_cosine_loss': 0.6321771144866943, 'val_total': 0.01720527745783329}
#
# epoch 199 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 199 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0135]
# epoch 199 train:  25%|██▌       | 1/4 [00:00<00:02,  1.20batch/s, loss=0.0135]
# epoch 199 train:  25%|██▌       | 1/4 [00:01<00:02,  1.20batch/s, loss=0.0148]
# epoch 199 train:  50%|█████     | 2/4 [00:01<00:01,  1.58batch/s, loss=0.0148]
# epoch 199 train:  50%|█████     | 2/4 [00:01<00:01,  1.58batch/s, loss=0.0153]
# epoch 199 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.75batch/s, loss=0.0153]
# epoch 199 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.75batch/s, loss=0.0147]
# epoch 199 train: 100%|██████████| 4/4 [00:02<00:00,  2.29batch/s, loss=0.0147]
#
# [timing] train_epoch epoch=199 seconds=2.05
#
# epoch 199 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 199 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0172]
# epoch 199 val: 100%|██████████| 1/1 [00:00<00:00,  3.77batch/s, loss=0.0172]
#
# [timing] validation_eval epoch=199 seconds=0.27
# [timing] artifact_save epoch=199 artifact=checkpoints seconds=0.01
# {'epoch': 199, 'train_loss': 0.014574451372027397, 'train_latent_mse': 0.002104955434333533, 'train_latent_cosine': 0.4132842347025871, 'train_latent_cosine_loss': 0.5867157727479935, 'train_reconstruction_mse': 0.012469495879486203, 'train_total': 0.014574451372027397, 'val_mse': 0.015311810187995434, 'val_reconstruction_mse': 0.015322946943342686, 'val_mae': 0.052045781165361404, 'val_foreground_mse': 0.059168118983507156, 'val_spatial_corr': 0.4462258815765381, 'val_top1_dice': 0.14846919476985931, 'val_top5_dice': 0.25499165058135986, 'val_top10_dice': 0.3250928521156311, 'val_top1_overlap': 0.14846919476985931, 'val_top5_overlap': 0.25499165058135986, 'val_top10_overlap': 0.3250928521156311, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.7347201704978943, 'val_pred_mean': 0.050340309739112854, 'val_pred_max': 1.0, 'val_loss': 0.017209628596901894, 'val_latent_mse': 0.0018866817699745297, 'val_latent_cosine': 0.3672630190849304, 'val_latent_cosine_loss': 0.6327369809150696, 'val_total': 0.017209628596901894}
#
# epoch 200 train:   0%|          | 0/4 [00:00<?, ?batch/s]
# epoch 200 train:   0%|          | 0/4 [00:00<?, ?batch/s, loss=0.0145]
# epoch 200 train:  25%|██▌       | 1/4 [00:00<00:02,  1.18batch/s, loss=0.0145]
# epoch 200 train:  25%|██▌       | 1/4 [00:01<00:02,  1.18batch/s, loss=0.0149]
# epoch 200 train:  50%|█████     | 2/4 [00:01<00:01,  1.56batch/s, loss=0.0149]
# epoch 200 train:  50%|█████     | 2/4 [00:01<00:01,  1.56batch/s, loss=0.0149]
# epoch 200 train:  75%|███████▌  | 3/4 [00:01<00:00,  1.74batch/s, loss=0.0149]
# epoch 200 train:  75%|███████▌  | 3/4 [00:02<00:00,  1.74batch/s, loss=0.0133]
# epoch 200 train: 100%|██████████| 4/4 [00:02<00:00,  2.28batch/s, loss=0.0133]
#
# [timing] train_epoch epoch=200 seconds=2.07
#
# epoch 200 val:   0%|          | 0/1 [00:00<?, ?batch/s]
# epoch 200 val:   0%|          | 0/1 [00:00<?, ?batch/s, loss=0.0172]
# epoch 200 val: 100%|██████████| 1/1 [00:00<00:00,  3.73batch/s, loss=0.0172]
#
# [timing] validation_eval epoch=200 seconds=0.27
# [timing] artifact_save epoch=200 artifact=checkpoints seconds=0.01
# {'epoch': 200, 'train_loss': 0.014378316001966596, 'train_latent_mse': 0.002051431074505672, 'train_latent_cosine': 0.4099721759557724, 'train_latent_cosine_loss': 0.5900278240442276, 'train_reconstruction_mse': 0.012326884781941772, 'train_total': 0.014378316001966596, 'val_mse': 0.015321079641580582, 'val_reconstruction_mse': 0.01533212698996067, 'val_mae': 0.05168561264872551, 'val_foreground_mse': 0.05964263156056404, 'val_spatial_corr': 0.4459163546562195, 'val_top1_dice': 0.14922578632831573, 'val_top5_dice': 0.2554047405719757, 'val_top10_dice': 0.3254331946372986, 'val_top1_overlap': 0.14922578632831573, 'val_top5_overlap': 0.2554047405719757, 'val_top10_overlap': 0.3254331946372986, 'val_target_nonzero_fraction': 0.2046510875225067, 'val_pred_nonzero_fraction': 0.734711766242981, 'val_pred_mean': 0.04940350726246834, 'val_pred_max': 1.0, 'val_loss': 0.017217732965946198, 'val_latent_mse': 0.0018856065580621362, 'val_latent_cosine': 0.36796772480010986, 'val_latent_cosine_loss': 0.6320322751998901, 'val_total': 0.017217732965946198}
# [timing] artifact_save artifact=training_metadata seconds=0.02
#
# mixed_test:all test:   0%|          | 0/1 [00:00<?, ?batch/s]
# mixed_test:all test:   0%|          | 0/1 [00:03<?, ?batch/s, loss=0.0162]
# mixed_test:all test: 100%|██████████| 1/1 [00:03<00:00,  3.11s/batch, loss=0.0162]
#
#
# mixed_test:neurovault test:   0%|          | 0/1 [00:00<?, ?batch/s]
# mixed_test:neurovault test:   0%|          | 0/1 [00:01<?, ?batch/s, loss=0.0162]
# mixed_test:neurovault test: 100%|██████████| 1/1 [00:01<00:00,  1.25s/batch, loss=0.0162]
#
# [timing] final_eval split=mixed_test metric_family=spatial_generation seconds=4.85
# [timing] artifact_save artifact=generation_eval_metrics seconds=0.01
# [timing] total_branch seconds=537.49
# [timing] artifact_save artifact=timing_profile seconds=0.01
# Corrected Stage 4 spatial test evaluation is produced by the trainer; semantic AUC diagnostics are produced by Notebook 7.

# %% [markdown]
# ## Final Status and Comparison Files

# %%
STAGE3_STATUS_KEY = f"stage3_{TEXT_EMBEDDING_DIR_SUFFIX}"
STAGE4_STATUS_KEY = f"corrected_stage4_{TEXT_EMBEDDING_DIR_SUFFIX}"
stage_status = write_status_report(
    RUN_DIR,
    {
        "stage1_selection_integration": stage1_selection_status,
        STAGE3_STATUS_KEY: RUN_STAGE3_CONTRASTIVE,
        STAGE4_STATUS_KEY: RUN_STAGE4_TEXT_TO_BRAIN,
        "stage5": RUN_STAGE5_GENERATION_EVAL,
    },
    text_embedding_convention=TEXT_EMBEDDING_SPEC["convention"],
    ae_branch_mode=AE_BRANCH_MODE,
)

def read_json_if_exists(path: Path):
    try:
        return json.loads(path.read_text()) if path.exists() else {}
    except Exception:
        return {}

def current_selected_downstream_runs() -> list[dict]:
    if SELECTED_DOWNSTREAM_RUNS:
        return SELECTED_DOWNSTREAM_RUNS
    if STAGE2_STAGE3_STAGE4_INPUT_MANIFEST:
        manifest = json.loads(Path(STAGE2_STAGE3_STAGE4_INPUT_MANIFEST).read_text())
        return select_downstream_runs_from_manifest(manifest)
    return []


selected_summary_runs = current_selected_downstream_runs()
selected_branch_names = [run["run"] for run in selected_summary_runs]
selected_assignment_rows = [
    {
        "AE_BRANCH_MODE": AE_BRANCH_MODE,
        "Run": run["run"],
        "Domain": run["domain"],
        "Type": run["type"],
        "branch": run["branch"],
        "ae_registry_key": run["ae_registry_key"],
        "ae_checkpoint_path": run.get("ae_checkpoint_path", ""),
        "selection_reason": run.get("selection_reason", ""),
    }
    for run in selected_summary_runs
]
write_table(Path(paths["final"]) / "selected_ae_branch_assignment.csv", selected_assignment_rows)
write_table(Path(paths["final"]) / "final_summary_table.csv", [{"stage": s["stage"], "status": s["status"], "expected_runs": s.get("expected_runs", ""), "completed_runs": s.get("completed_runs", ""), "AE_BRANCH_MODE": s.get("ae_branch_mode", "")} for s in stage_status])

if STAGE1_SELECTION_INTEGRATION_DIR:
    assignment_csv = STAGE1_SELECTION_INTEGRATION_DIR / "03_downstream_usage/selected_ae_branch_assignment.csv"
    final_assignment = Path(paths["final"]) / "stage1_selection_ae_assignment.csv"
    if assignment_csv.exists():
        shutil.copy2(assignment_csv, final_assignment)
    write_json(Path(paths["final"]) / "stage1_selection_integration_pointer.json", {
        "integration_dir": str(STAGE1_SELECTION_INTEGRATION_DIR),
        "downstream_manifest": str(STAGE2_STAGE3_STAGE4_INPUT_MANIFEST),
        "AE_BRANCH_MODE": AE_BRANCH_MODE,
        "required_selection_keys": AE_BRANCH_REQUIRED_SELECTION_KEYS,
        "selected_run_count": len(selected_summary_runs),
    })

audit_rows = []
try:
    pair_fingerprints = {}
    for run in selected_summary_runs:
        domain = run["domain"]
        branch = run["branch"]
        branch_dir = RUN_DIR / domain_dirs[domain] / branch
        stage3_arch = read_json_if_exists(branch_dir / STAGE3_SPECTER_DIRNAME / "architecture_compatibility_report.json")
        stage3_train = read_json_if_exists(branch_dir / STAGE3_SPECTER_DIRNAME / "stage3_trainability_report.json")
        stage3_data = read_json_if_exists(branch_dir / STAGE3_SPECTER_DIRNAME / "domain_dataset_report.json")
        stage4_arch = read_json_if_exists(branch_dir / CORRECTED_STAGE4_SPECTER_DIRNAME / "stage4_architecture_compatibility_report.json")
        selected_arch = stage3_arch.get("selected_ae_checkpoint_architecture", {})
        instantiated = stage3_arch.get("instantiated_stage3_architecture", {})
        fps = stage3_data.get("split_fingerprints", {})
        stage4_domain = stage4_arch.get("domain_filter_report", {})
        stage4_fps = {name: stage4_domain.get(name, {}).get("fingerprint", "") for name in ["train", "val", "test"]}
        stage4_domain_filter_passed = bool(stage4_domain) and all(stage4_fps.get(name) == fps.get(name) for name in ["train", "val", "test"])
        pair_fingerprints.setdefault(domain, []).append(fps)
        audit_rows.append({
            "run_name": run["run"],
            "domain": domain,
            "baseline_or_specialized": run["type"],
            "AE checkpoint": run.get("ae_checkpoint_path", ""),
            "AE base channels": selected_arch.get("base_channels", ""),
            "Stage 3 base channels": instantiated.get("base_channels", ""),
            "number of blocks": instantiated.get("num_blocks", ""),
            "output dimension": instantiated.get("out_dim", ""),
            "norm": instantiated.get("norm", ""),
            "pooling": instantiated.get("pooling", ""),
            "dropout": instantiated.get("dropout", ""),
            "encoder architecture": instantiated.get("encoder_arch", ""),
            "strict encoder load passed": stage3_arch.get("strict_load_success", ""),
            "CNN encoder trainable": stage3_train.get("cnn_encoder_trainable", ""),
            "text projection pretrained": stage3_train.get("text_projection_pretrained", ""),
            "text projection trainable": stage3_train.get("text_projection_trainable", ""),
            "symmetric InfoNCE confirmed": stage3_train.get("loss", "") == "symmetric InfoNCE",
            "train source counts": json.dumps(stage3_data.get("source_value_counts", {}).get("train", {}), sort_keys=True),
            "validation source counts": json.dumps(stage3_data.get("source_value_counts", {}).get("val", {}), sort_keys=True),
            "test source counts": json.dumps(stage3_data.get("source_value_counts", {}).get("test", {}), sort_keys=True),
            "train fingerprint": fps.get("train", ""),
            "validation fingerprint": fps.get("val", ""),
            "test fingerprint": fps.get("test", ""),
            "matching-pair fingerprints equal": "pending",
            "Stage 4 decoder strict load passed": stage4_arch.get("strict_autoencoder_load", "") == "passed",
            "Stage 4 domain filter passed": stage4_domain_filter_passed,
            "warnings": json.dumps({"stage3_arch": stage3_arch.get("unexpected_differences", {}), "stage3_train": stage3_train.get("failures", [])}, sort_keys=True),
            "status": "passed" if stage3_arch.get("final_compatibility_status") == "passed" and stage3_train.get("status") == "passed" else "incomplete_or_failed",
        })
    for row in audit_rows:
        fps_group = pair_fingerprints.get(row["domain"], [])
        row["matching-pair fingerprints equal"] = (
            len(fps_group) == 2 and fps_group[0] == fps_group[1]
            if len(fps_group) == 2
            else "not_applicable_for_selected_branch_mode"
        )
    if audit_rows:
        write_table(Path(paths["final"]) / "architecture_and_data_audit.csv", audit_rows)
except Exception as exc:
    print("WARNING: could not write architecture_and_data_audit.csv:", exc)

for s in stage_status:
    print(f"{s['stage']}: {s['status']} ({s.get('completed_runs', '')}/{s.get('expected_runs', '')})")
print("Final comparison:", Path(paths["final"]))

summary_root = RUN_DIR / "03_all_domain_summary"
cache_audit_dir = RUN_DIR / f"00_{TEXT_EMBEDDING_DIR_SUFFIX}_text_cache_audit"
stage3_summary_dir = RUN_DIR / f"01_stage3_{TEXT_EMBEDDING_DIR_SUFFIX}"
stage4_summary_dir = RUN_DIR / f"02_corrected_stage4_{TEXT_EMBEDDING_DIR_SUFFIX}"
for d in [summary_root, cache_audit_dir, stage3_summary_dir, stage4_summary_dir]:
    d.mkdir(parents=True, exist_ok=True)
for src in [NORMALIZED_PATHS.get("metadata"), NORMALIZED_PATHS.get("validation"), NORMALIZED_PATHS.get("index")]:
    try:
        if src and Path(src).exists():
            shutil.copy2(src, cache_audit_dir / Path(src).name)
    except Exception as exc:
        print("Cache audit copy skipped:", exc)


def first_metric(payloads, names):
    for payload in payloads:
        if isinstance(payload, list):
            for row in payload:
                if isinstance(row, dict) and row.get("source") == "all":
                    value = first_metric([row], names)
                    if value != "":
                        return value
            continue
        if not isinstance(payload, dict):
            continue
        test = payload.get("test", payload)
        for name in names:
            value = test.get(name)
            if value not in {None, ""}:
                return value
    return ""


def to_float(value):
    try:
        return float(value)
    except Exception:
        return None


def delta(new_value, old_value):
    new_f = to_float(new_value)
    old_f = to_float(old_value)
    return "" if new_f is None or old_f is None else new_f - old_f


def load_stage3_metric_bundle(stage3_dir: Path) -> dict:
    payloads = [
        read_json_if_exists(stage3_dir / "eval_results.json"),
        read_json_if_exists(stage3_dir / "test_metrics.json"),
        read_json_if_exists(stage3_dir / "metrics/test_metrics.json"),
        read_json_if_exists(stage3_dir / "comparison_row.json"),
    ]
    t2b = first_metric(payloads, ["t2i_normalized_k_recall_curve_auc", "text_to_brain_normalized_auc", "text_to_image_auc", "t2i_auc"])
    b2t = first_metric(payloads, ["i2t_normalized_k_recall_curve_auc", "brain_to_text_normalized_auc", "image_to_text_auc", "i2t_auc"])
    mean_auc = first_metric(payloads, ["paper_recall_curve_auc", "mean_bidirectional_normalized_auc", "mean_normalized_k_recall_curve_auc", "normalized_k_recall_curve_auc", "full_recall_curve_auc"])
    if mean_auc == "" and to_float(t2b) is not None and to_float(b2t) is not None:
        mean_auc = (float(t2b) + float(b2t)) / 2.0
    return {"mean_auc": mean_auc, "text_to_brain_auc": t2b, "brain_to_text_auc": b2t}


def load_stage4_all_row(stage4_dir: Path) -> dict:
    payload = read_json_if_exists(stage4_dir / "generation_eval_metrics.json")
    if isinstance(payload, list):
        return next((r for r in payload if isinstance(r, dict) and r.get("source") == "all"), payload[0] if payload and isinstance(payload[0], dict) else {})
    return payload if isinstance(payload, dict) else {}

stage3_rows = []
stage4_rows = []
stage3_compare_rows = []
stage4_compare_rows = []
combined_rows = []
try:
    for run in selected_summary_runs:
        domain = run["domain"]
        branch_kind = run["type"]
        branch = run["branch"]
        branch_dir = RUN_DIR / domain_dirs[domain] / branch
        base_run = run["run"]
        stage3_dir = branch_dir / STAGE3_SPECTER_DIRNAME
        legacy_stage3_dir = COMPLETED_STAGE3_RUN_ROOT / domain_dirs[domain] / branch / "stage3"
        convention_stage3 = load_stage3_metric_bundle(stage3_dir)
        legacy_stage3 = load_stage3_metric_bundle(legacy_stage3_dir)
        stage3_arch = read_json_if_exists(stage3_dir / "architecture_compatibility_report.json")
        stage3_data = read_json_if_exists(stage3_dir / "domain_dataset_report.json")
        fps = stage3_data.get("split_fingerprints", {})
        split_fp = fps.get("test", SPLIT_FINGERPRINTS.get("test", {}).get("fingerprint", ""))
        stage3_row = {
            "run": f"{base_run}_{TEXT_EMBEDDING_DIR_SUFFIX}",
            "domain": domain,
            "branch": branch,
            "branch_kind": branch_kind,
            f"{TEXT_EMBEDDING_DIR_SUFFIX}_mean_bidirectional_auc": convention_stage3["mean_auc"],
            f"{TEXT_EMBEDDING_DIR_SUFFIX}_text_to_brain_auc": convention_stage3["text_to_brain_auc"],
            f"{TEXT_EMBEDDING_DIR_SUFFIX}_brain_to_text_auc": convention_stage3["brain_to_text_auc"],
            "checkpoint": str(stage3_dir / "checkpoints" / NORMALIZED_STAGE3_CHECKPOINT),
            "text_embedding_cache_sha256": TEXT_EMBEDDING_METADATA["text_embedding_cache_checksum"],
            **TEXT_EMBEDDING_METADATA,
            "split_fingerprint": split_fp,
            "architecture_match": stage3_arch.get("final_compatibility_status", "") == "passed" if stage3_arch else "",
            "text_preprocessing_change_only": True,
        }
        stage3_rows.append(stage3_row)
        stage3_compare_rows.append({
            "domain": domain,
            "branch": branch,
            "legacy_mean_bidirectional_auc": legacy_stage3["mean_auc"],
            f"{TEXT_EMBEDDING_DIR_SUFFIX}_mean_bidirectional_auc": convention_stage3["mean_auc"],
            f"delta_{TEXT_EMBEDDING_DIR_SUFFIX}_minus_legacy": delta(convention_stage3["mean_auc"], legacy_stage3["mean_auc"]),
            "legacy_text_to_brain_auc": legacy_stage3["text_to_brain_auc"],
            f"{TEXT_EMBEDDING_DIR_SUFFIX}_text_to_brain_auc": convention_stage3["text_to_brain_auc"],
            "legacy_brain_to_text_auc": legacy_stage3["brain_to_text_auc"],
            f"{TEXT_EMBEDDING_DIR_SUFFIX}_brain_to_text_auc": convention_stage3["brain_to_text_auc"],
            "split_fingerprint": split_fp,
            "architecture_match": stage3_row["architecture_match"],
            "text_preprocessing_change_only": True,
        })

        stage4_dir = branch_dir / CORRECTED_STAGE4_SPECTER_DIRNAME
        all_row = load_stage4_all_row(stage4_dir)
        corrected_auc = all_row.get("generation_mean_normalized_auc", all_row.get("generation_clamped_strict_map_mean_normalized_auc", ""))
        legacy_auc = ""
        primary_checkpoint = stage4_dir / "checkpoints" / STAGE4_PRIMARY_CHECKPOINT
        semantic_checkpoint = stage4_dir / "checkpoints" / STAGE4_SEMANTIC_CHECKPOINT_NAME
        stage4_row = {
            "run": f"{base_run}_corrected_{TEXT_EMBEDDING_DIR_SUFFIX}_stage4",
            "domain": domain,
            "branch": branch,
            "branch_kind": branch_kind,
            "corrected_generation_mean_auc": corrected_auc,
            "text_to_generated_brain_auc": all_row.get("generation_text_to_brain_normalized_auc", ""),
            "generated_brain_to_text_auc": all_row.get("generation_brain_to_text_normalized_auc", ""),
            "raw_strict_map_auc": all_row.get("generation_raw_strict_map_mean_normalized_auc", ""),
            "clamped_strict_map_auc": all_row.get("generation_clamped_strict_map_mean_normalized_auc", ""),
            "same_text_group_auc": all_row.get("generation_clamped_same_text_group_mean_normalized_auc", ""),
            "publication_group_auc": all_row.get("generation_clamped_publication_group_mean_normalized_auc", ""),
            "matched_contrastive_cosine": all_row.get("generation_matched_contrastive_cosine", all_row.get("generation_clamped_matched_contrastive_cosine", "")),
            "shuffled_null_contrastive_cosine": all_row.get("generation_shuffled_contrastive_cosine", all_row.get("generation_clamped_shuffled_contrastive_cosine", "")),
            "spatial_corr": all_row.get("spatial_corr", ""),
            "top1_dice": all_row.get("top1_dice", ""),
            "top5_dice": all_row.get("top5_dice", ""),
            "top10_dice": all_row.get("top10_dice", ""),
            "mse": all_row.get("mse", ""),
            "mae": all_row.get("mae", ""),
            "foreground_mse": all_row.get("foreground_mse", ""),
            "pred_nonzero_frac": all_row.get("pred_nonzero_fraction", all_row.get("pred_nonzero_frac", "")),
            "target_nonzero_frac": all_row.get("target_nonzero_fraction", all_row.get("target_nonzero_frac", "")),
            "stage4_training_semantic_auc": "enabled" if STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING else "disabled",
            "primary_checkpoint": str(primary_checkpoint),
            "semantic_checkpoint": str(semantic_checkpoint) if semantic_checkpoint.exists() else "not produced during training",
            "semantic_diagnostics": "available in Notebook 7 final evaluation",
        }
        stage4_rows.append(stage4_row)
        stage4_compare_rows.append({
            "domain": domain,
            "branch": branch,
            "legacy_generation_mean_auc": legacy_auc,
            "corrected_generation_mean_auc": corrected_auc,
            "delta_corrected_minus_legacy": delta(corrected_auc, legacy_auc),
            "corrected_raw_strict_map_auc": stage4_row["raw_strict_map_auc"],
            "corrected_clamped_strict_map_auc": stage4_row["clamped_strict_map_auc"],
            "corrected_same_text_group_auc": stage4_row["same_text_group_auc"],
            "corrected_publication_group_auc": stage4_row["publication_group_auc"],
            "corrected_spatial_corr": stage4_row["spatial_corr"],
            "corrected_top5_dice": stage4_row["top5_dice"],
            "corrected_pred_nonzero_frac": stage4_row["pred_nonzero_frac"],
            "corrected_target_nonzero_frac": stage4_row["target_nonzero_frac"],
            "legacy_checkpoint_name_or_source": "notebook6_saved_legacy_stage4_auc_constant",
            "corrected_checkpoint_name": STAGE4_PRIMARY_CHECKPOINT,
            "semantic_checkpoint_name": STAGE4_SEMANTIC_CHECKPOINT_NAME if semantic_checkpoint.exists() else "not produced during training",
        })
        combined_rows.append({"section": "stage3", **stage3_row})
        combined_rows.append({"section": "stage4", **stage4_row})
except Exception as exc:
    print("WARNING: summary packaging incomplete:", exc)

stage3_all_runs_csv = f"stage3_{TEXT_EMBEDDING_DIR_SUFFIX}_all_runs.csv"
stage4_all_runs_csv = f"stage4_corrected_{TEXT_EMBEDDING_DIR_SUFFIX}_all_runs.csv"
stage3_vs_legacy_csv = f"{TEXT_EMBEDDING_DIR_SUFFIX}_vs_legacy_stage3.csv"
stage4_vs_legacy_csv = f"{TEXT_EMBEDDING_DIR_SUFFIX}_corrected_vs_legacy_stage4.csv"
combined_summary_csv = f"stage1_stage3_stage4_{TEXT_EMBEDDING_DIR_SUFFIX}_summary.csv"
write_table(summary_root / stage3_all_runs_csv, stage3_rows)
write_table(summary_root / stage4_all_runs_csv, stage4_rows)
write_table(summary_root / stage3_vs_legacy_csv, stage3_compare_rows)
write_table(summary_root / stage4_vs_legacy_csv, stage4_compare_rows)
write_table(summary_root / combined_summary_csv, combined_rows)
write_table(stage3_summary_dir / stage3_vs_legacy_csv, stage3_compare_rows)
write_table(stage4_summary_dir / stage4_vs_legacy_csv, stage4_compare_rows)


def mean_delta(rows, key):
    vals = [to_float(r.get(key)) for r in rows]
    vals = [v for v in vals if v is not None]
    return None if not vals else sum(vals) / len(vals)


def answer_from_delta(value, positive_text, negative_text, missing_text="insufficient completed metrics"):
    if value is None:
        return missing_text
    if value > 0:
        return f"yes, mean delta {value:.6f} ({positive_text})"
    if value < 0:
        return f"no, mean delta {value:.6f} ({negative_text})"
    return "no material change, mean delta 0.000000"

stage3_delta = mean_delta(stage3_compare_rows, f"delta_{TEXT_EMBEDDING_DIR_SUFFIX}_minus_legacy")
stage4_delta = mean_delta(stage4_compare_rows, "delta_corrected_minus_legacy")
raw_clamped_changes = [
    abs(to_float(r.get("corrected_raw_strict_map_auc")) - to_float(r.get("corrected_clamped_strict_map_auc")))
    for r in stage4_compare_rows
    if to_float(r.get("corrected_raw_strict_map_auc")) is not None and to_float(r.get("corrected_clamped_strict_map_auc")) is not None
]
raw_clamped_answer = "insufficient corrected Stage 4 metrics"
if raw_clamped_changes:
    raw_clamped_answer = f"mean absolute raw-vs-clamped strict AUC difference {sum(raw_clamped_changes) / len(raw_clamped_changes):.6f}; inspect branches where this is nonzero"

neurovault_rows = [r for r in stage4_compare_rows if r.get("domain") == "neurovault"]
duplicate_answer = "insufficient NeuroVault corrected Stage 4 metrics"
if neurovault_rows:
    duplicate_answer = "; ".join(
        f"{r['branch']}: strict={r.get('corrected_clamped_strict_map_auc', '')}, same_text={r.get('corrected_same_text_group_auc', '')}, publication={r.get('corrected_publication_group_auc', '')}"
        for r in neurovault_rows
    )

best_by_domain = []
for domain in ["pubmed", "nilearn", "neurovault"]:
    candidates = [r for r in stage4_rows if r.get("domain") == domain and to_float(r.get("corrected_generation_mean_auc")) is not None]
    metric_name = "corrected Stage 4 generation AUC"
    if not candidates:
        candidates = [r for r in stage3_rows if r.get("domain") == domain and to_float(r.get(f"{TEXT_EMBEDDING_DIR_SUFFIX}_mean_bidirectional_auc")) is not None]
        metric_name = f"{TEXT_EMBEDDING_SUMMARY_LABEL} Stage 3 AUC"
    if candidates:
        best = max(candidates, key=lambda r: to_float(r.get("corrected_generation_mean_auc", r.get(f"{TEXT_EMBEDDING_DIR_SUFFIX}_mean_bidirectional_auc"))) or -1e9)
        score = best.get("corrected_generation_mean_auc", best.get(f"{TEXT_EMBEDDING_DIR_SUFFIX}_mean_bidirectional_auc", ""))
        best_by_domain.append(f"{domain}: {best['branch']} by {metric_name} ({score})")
    else:
        best_by_domain.append(f"{domain}: unavailable until metrics are exported")

recommend_stage3 = "yes" if stage3_delta is not None and stage3_delta > 0 else "not yet" if stage3_delta is not None else "unknown"
recommend_stage4 = "yes" if stage4_delta is not None and stage4_delta > 0 else "not yet" if stage4_delta is not None else "unknown"
comparison_record_label = "paired CSVs" if AE_BRANCH_MODE == "mixed_and_specialized" else "selected-branch CSVs"

README = f"""# 6a {TEXT_EMBEDDING_SUMMARY_LABEL} Corrected Summary

AE_BRANCH_MODE = {AE_BRANCH_MODE}
Selected branch count: {len(selected_summary_runs)}
Selected branches: {', '.join(selected_branch_names) if selected_branch_names else 'none'}
Stage 4 training semantic AUC: {'enabled' if STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING else 'disabled'}
Stage 4 primary checkpoint: {STAGE4_PRIMARY_CHECKPOINT}
Stage 4 semantic checkpoint: {STAGE4_SEMANTIC_CHECKPOINT_NAME if STAGE4_COMPUTE_SEMANTIC_AUC_DURING_TRAINING else 'not produced during training'}
Stage 4 semantic diagnostics: available in Notebook 7 final evaluation

1. Did {TEXT_EMBEDDING_SUMMARY_LABEL} improve Stage 3 normalized recall AUC? {answer_from_delta(stage3_delta, f'{TEXT_EMBEDDING_SUMMARY_LABEL} improved over saved legacy/raw Stage 3', f'{TEXT_EMBEDDING_SUMMARY_LABEL} trailed saved legacy/raw Stage 3')}.
2. Did the selected Stage 3 branches beat the saved legacy/raw Stage 3 baseline? {answer_from_delta(stage3_delta, 'selected current-convention rows beat the saved legacy rows on average', 'selected current-convention rows did not beat the saved legacy rows on average')}.
3. Did corrected independent Stage 4 improve generation semantic AUC? {answer_from_delta(stage4_delta, 'corrected Stage 4 improved over saved legacy Stage 4 constants', 'corrected Stage 4 trailed saved legacy Stage 4 constants')}.
4. Did raw-vs-clamped semantic AUC change the interpretation? {raw_clamped_answer}.
5. Did duplicate-aware NeuroVault evaluation change the interpretation? {duplicate_answer}.
6. Which AE initialization is best per domain? {'; '.join(best_by_domain)}.
7. Should this text convention become the default for Stage 3 and/or Stage 4? Stage 3: {recommend_stage3}; Stage 4: {recommend_stage4}. Use the {comparison_record_label} below as the decision record.

Primary files:
- `{stage3_all_runs_csv}`
- `{stage4_all_runs_csv}`
- `{stage3_vs_legacy_csv}`
- `{stage4_vs_legacy_csv}`
- `{combined_summary_csv}`

Text cache: `{NORMALIZED_SPECTER_CACHE}`
Cache SHA-256: `{TEXT_EMBEDDING_METADATA['text_embedding_cache_checksum']}`
Preprocessing: `{TEXT_EMBEDDING_PREPROCESSING}`
Convention: `{TEXT_EMBEDDING_CONVENTION}`
"""
(summary_root / "README_WHAT_TO_LOOK_AT.md").write_text(README)
print("6a packaged outputs:", RUN_DIR)
print("Summary:", summary_root)
# Out:
# stage1: not requested (/)
# stage1b: not requested (/)
# stage3: ran successfully (6/6)
# stage4: ran successfully (6/6)
# stage5: covered by stage4 trainer outputs (/)
# Final comparison: /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/05_all_domain_comparison
# 6a packaged outputs: /content/drive/MyDrive/neurovlm/6a_results_20260706_180022
# Summary: /content/drive/MyDrive/neurovlm/6a_results_20260706_180022/03_all_domain_summary
